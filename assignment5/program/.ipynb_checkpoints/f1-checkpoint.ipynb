# %% [markdown]
# # F1 Probability

# %%
class ProbDist(dict):
    """A Probability Distribution; an {outcome: probability} mapping."""
    def __init__(self, mapping=(), **kwargs):
        self.update(mapping, **kwargs)
        # Make probabilities sum to 1.0; assert no negative probabilities
        total = sum(self.values())
        for outcome in self:
            self[outcome] = self[outcome] / total
            assert self[outcome] >= 0

# %%
def p(event, space): 
    """The probability of an event, given a sample space of equiprobable outcomes. 
    event: a collection of outcomes, or a predicate that is true of outcomes in the event. 
    space: a set of outcomes or a probability distribution of {outcome: frequency} pairs."""
    if is_predicate(event):
        event = such_that(event, space)
    if isinstance(space, ProbDist):
        return sum(space[o] for o in space if o in event)
    else:
        return Fraction(len(event & space), len(space))

is_predicate = callable

def such_that(predicate, space): 
    """The outcomes in the sample pace for which the predicate is true.
    If space is a set, return a subset {outcome,...} with outcomes where predicate(element) is true;
    if space is a ProbDist, return a ProbDist {outcome: frequency,...} with outcomes where predicate(element) is true."""
    if isinstance(space, ProbDist):
        return ProbDist({o:space[o] for o in space if predicate(o)})
    else:
        return {o for o in space if predicate(o)}

# %% [markdown]
# Question 1.1 (20 points) There are a number of F1 races coming up:
# - Singapore GP: Date: Sun, Sep 22, 8:10 AM
# - Russian GP: Date: Sun, Sep 29, 7:10 AM
# - Japanese GP: Date: Sun, Oct 13, 1:10 AM
# - Mexican GP Date: Sun, Oct 13, 1:10 AM
#
# We are just before the Singaporean Grand Prix (this coming weekend) and the Russian Grand Prix the weekend after, as you can see [schedule](https://www.formula1.com/en/racing/2019.html).
#
# The 2019 driver standings are given [here](https://www.formula1.com/en/results.html/2019/drivers.html). Assume these standings for this weekend, even though they are final season standings. Given these standings (please do not use team standings given on the same Web site, use ***driver standings***), what is the Probability Distribution for each F1 driver to win the Singaporean Grand Prix? What is the Probability Distribution for each F1 driver to win *both* the Singaporean and Russian Grand Prix? What is the probability for Mercedes to win both races? What is the probability for Mercedes to win at least one race? Note that Mercedes, and each other racing team, has two drivers per race. Assume that Singaporean grand prix standings are not going to change driver standings by much, so you can use same standings for both races.
#
# Question 1.2 (30 points) If Mercedes wins the first race, what is the probability that Mercedes wins the next one? If Mercedes wins at least one of these two races, what is the probability Mercedes wins both races? How about Ferrari, Red Bull, and Renault?
#
# Question 1.3 (50 points) Mercedes wins at least one of these two races on a **rainy** day. What is the probability Mercedes wins both races, assuming races can be held on either rainy, sunny, cloudy, snowy or foggy days? Assume that rain, sun, clouds, snow, and fog are the *only possible weather conditions* on race tracks.
#
# You need to provide *proof* for your answers. `I think it's one in a million because Mercedes sucks and I like Ferrari a lot more` is not a good answer. Leverage the counting framework in this workbook!

# %% [markdown]
# Hint: Use SingaporeanGrandPrix, or `SGP` to denote the Probability Distribution given by F1 driver wins. Write driver initials as keys and driver wins as values in a dictionary that you pass to our function `ProbDist`..

# %% [markdown]
# # And condition is used if I need both of them to be true
# # Or condition when any one of them is True

# %% [markdown]
# ### Each car has 2 racers and I have named the racers as their initials
#
# ### First I am trying to get the probability distribution of all races of the Singaporean Grand Prix and the Russian Grand prix so that I can join these two and find the probability of each car winning in both the race and atleast one race.

# %% [markdown]
# ## Probability Distribution for all racers for Singaporean Grand Prix

# %%
SGP = ProbDist(LH = 413, VB = 326, MV = 278, CL = 264, SV = 240, CS = 96, PG = 95, 
               AA = 92, DR = 52, SP = 52, LN = 49, KR = 43, DK = 37, NH = 37, 
               LS = 21, KM = 20, AG = 14, RG = 8, RK = 1, GR = 0)
SGP
# Out:
# {'LH': 0.1931711880261927,
#  'VB': 0.15247895229186156,
#  'MV': 0.13002806361085126,
#  'CL': 0.1234798877455566,
#  'SV': 0.11225444340505145,
#  'CS': 0.04490177736202058,
#  'PG': 0.04443405051449953,
#  'AA': 0.04303086997193639,
#  'DR': 0.02432179607109448,
#  'SP': 0.02432179607109448,
#  'LN': 0.022918615528531337,
#  'KR': 0.020112254443405052,
#  'DK': 0.017305893358278764,
#  'NH': 0.017305893358278764,
#  'LS': 0.009822263797942002,
#  'KM': 0.009354536950420954,
#  'AG': 0.006548175865294668,
#  'RG': 0.0037418147801683817,
#  'RK': 0.0004677268475210477,
#  'GR': 0.0}

# %% [markdown]
# ## Probability Distribution for all racers for Russian Grand Prix

# %%
RGP = ProbDist(LH = 413, VB = 326, MV = 278, CL = 264, SV = 240, CS = 96, PG = 95, 
               AA = 92, DR = 52, SP = 52, LN = 49, KR = 43, DK = 37, NH = 37, 
               LS = 21, KM = 20, AG = 14, RG = 8, RK = 1, GR = 0)
RGP
# Out:
# {'LH': 0.1931711880261927,
#  'VB': 0.15247895229186156,
#  'MV': 0.13002806361085126,
#  'CL': 0.1234798877455566,
#  'SV': 0.11225444340505145,
#  'CS': 0.04490177736202058,
#  'PG': 0.04443405051449953,
#  'AA': 0.04303086997193639,
#  'DR': 0.02432179607109448,
#  'SP': 0.02432179607109448,
#  'LN': 0.022918615528531337,
#  'KR': 0.020112254443405052,
#  'DK': 0.017305893358278764,
#  'NH': 0.017305893358278764,
#  'LS': 0.009822263797942002,
#  'KM': 0.009354536950420954,
#  'AG': 0.006548175865294668,
#  'RG': 0.0037418147801683817,
#  'RK': 0.0004677268475210477,
#  'GR': 0.0}

# %% [markdown]
# ## Combined Singaporean and Russian Grand Prix

# %%
def joint(A, B, sep=' '):
    """The joint distribution of two independent probability distributions. 
    Result is all entries of the form {a+sep+b: P(a)*P(b)}"""
    return ProbDist({a + sep + b: A[a] * B[b]
                    for a in A
                    for b in B})

F = joint(SGP, RGP, ' ')
F
# Out:
# {'LH LH': 0.03731510788345061,
#  'LH VB': 0.029454540363207993,
#  'LH MV': 0.025117675524453438,
#  'LH CL': 0.02385275661315003,
#  'LH SV': 0.021684324193772753,
#  'LH CS': 0.0086737296775091,
#  'LH PG': 0.008583378326701713,
#  'LH AA': 0.008312324274279555,
#  'LH DR': 0.004698270241984097,
#  'LH SP': 0.004698270241984097,
#  'LH LN': 0.004427216189561938,
#  'LH KR': 0.0038851080847176183,
#  'LH DK': 0.0033429999798732994,
#  'LH NH': 0.0033429999798732994,
#  'LH LS': 0.001897378366955116,
#  'LH KM': 0.0018070270161477293,
#  'LH AG': 0.0012649189113034106,
#  'LH RG': 0.0007228108064590917,
#  'LH RK': 9.035135080738647e-05,
#  'LH GR': 0.0,
#  'VB LH': 0.029454540363207993,
#  'VB VB': 0.023249830892023742,
#  'VB MV': 0.019826542907922084,
#  'VB CL': 0.018828083912559104,
#  'VB SV': 0.017116439920508274,
#  'VB CS': 0.00684657596820331,
#  'VB PG': 0.006775257468534526,
#  'VB AA': 0.0065613019695281724,
#  'VB DR': 0.003708561982776793,
#  'VB SP': 0.003708561982776793,
#  'VB LN': 0.0034946064837704394,
#  'VB KR': 0.0030666954857577326,
#  'VB DK': 0.0026387844877450253,
#  'VB NH': 0.0026387844877450253,
#  'VB LS': 0.0014976884930444742,
#  'VB KM': 0.0014263699933756895,
#  'VB AG': 0.0009984589953629828,
#  'VB RG': 0.0005705479973502759,
#  'VB RK': 7.131849966878448e-05,
#  'VB GR': 0.0,
#  'MV LH': 0.025117675524453438,
#  'MV VB': 0.019826542907922084,
#  'MV MV': 0.016907297326387544,
#  'MV CL': 0.016055850698439973,
#  'MV SV': 0.014596227907672699,
#  'MV CS': 0.005838491163069079,
#  'MV PG': 0.00577767354678711,
#  'MV AA': 0.005595220697941202,
#  'MV DR': 0.0031625160466624185,
#  'MV SP': 0.0031625160466624185,
#  'MV LN': 0.0029800631978165095,
#  'MV KR': 0.0026151575001246924,
#  'MV DK': 0.002250251802432874,
#  'MV NH': 0.002250251802432874,
#  'MV LS': 0.0012771699419213613,
#  'MV KM': 0.0012163523256393917,
#  'MV AG': 0.0008514466279475742,
#  'MV RG': 0.0004865409302557567,
#  'MV RK': 6.0817616281969586e-05,
#  'MV GR': 0.0,
#  'CL LH': 0.02385275661315003,
#  'CL VB': 0.018828083912559104,
#  'CL MV': 0.016055850698439973,
#  'CL CL': 0.015247282677655224,
#  'CL SV': 0.013861166070595657,
#  'CL CS': 0.005544466428238263,
#  'CL PG': 0.005486711569610781,
#  'CL AA': 0.005313446993728336,
#  'CL DR': 0.0030032526486290594,
#  'CL SP': 0.0030032526486290594,
#  'CL LN': 0.0028299880727466137,
#  'CL KR': 0.002483458920981722,
#  'CL DK': 0.0021369297692168305,
#  'CL NH': 0.0021369297692168305,
#  'CL LS': 0.0012128520311771203,
#  'CL KM': 0.001155097172549638,
#  'CL AG': 0.0008085680207847467,
#  'CL RG': 0.00046203886901985527,
#  'CL RK': 5.775485862748191e-05,
#  'CL GR': 0.0,
#  'SV LH': 0.021684324193772753,
#  'SV VB': 0.017116439920508274,
#  'SV MV': 0.014596227907672699,
#  'SV CL': 0.013861166070595657,
#  'SV SV': 0.01260106006417787,
#  'SV CS': 0.0050404240256711474,
#  'SV PG': 0.004987919608737073,
#  'SV AA': 0.004830406357934851,
#  'SV DR': 0.002730229680571872,
#  'SV SP': 0.002730229680571872,
#  'SV LN': 0.0025727164297696483,
#  'SV KR': 0.0022576899281652016,
#  'SV DK': 0.0019426634265607549,
#  'SV NH': 0.0019426634265607549,
#  'SV LS': 0.0011025927556155637,
#  'SV KM': 0.0010500883386814891,
#  'SV AG': 0.0007350618370770425,
#  'SV RG': 0.0004200353354725957,
#  'SV RK': 5.250441693407446e-05,
#  'SV GR': 0.0,
#  'CS LH': 0.0086737296775091,
#  'CS VB': 0.00684657596820331,
#  'CS MV': 0.005838491163069079,
#  'CS CL': 0.005544466428238263,
#  'CS SV': 0.0050404240256711474,
#  'CS CS': 0.0020161696102684594,
#  'CS PG': 0.0019951678434948295,
#  'CS AA': 0.0019321625431739401,
#  'CS DR': 0.0010920918722287488,
#  'CS SP': 0.0010920918722287488,
#  'CS LN': 0.0010290865719078592,
#  'CS KR': 0.0009030759712660807,
#  'CS DK': 0.0007770653706243019,
#  'CS NH': 0.0007770653706243019,
#  'CS LS': 0.00044103710224622546,
#  'CS KM': 0.0004200353354725957,
#  'CS AG': 0.000294024734830817,
#  'CS RG': 0.00016801413418903827,
#  'CS RK': 2.1001766773629783e-05,
#  'CS GR': 0.0,
#  'PG LH': 0.008583378326701713,
#  'PG VB': 0.006775257468534526,
#  'PG MV': 0.00577767354678711,
#  'PG CL': 0.005486711569610781,
#  'PG SV': 0.004987919608737073,
#  'PG CS': 0.0019951678434948295,
#  'PG PG': 0.0019743848451250915,
#  'PG AA': 0.0019120358500158783,
#  'PG DR': 0.001080715915226366,
#  'PG SP': 0.001080715915226366,
#  'PG LN': 0.0010183669201171525,
#  'PG KR': 0.0008936689298987258,
#  'PG DK': 0.0007689709396802987,
#  'PG NH': 0.0007689709396802987,
#  'PG LS': 0.0004364429657644939,
#  'PG KM': 0.0004156599673947561,
#  'PG AG': 0.0002909619771763293,
#  'PG RG': 0.00016626398695790244,
#  'PG RK': 2.0782998369737805e-05,
#  'PG GR': 0.0,
#  'AA LH': 0.008312324274279555,
#  'AA VB': 0.0065613019695281724,
#  'AA MV': 0.005595220697941202,
#  'AA CL': 0.005313446993728336,
#  'AA SV': 0.004830406357934851,
#  'AA CS': 0.0019321625431739401,
#  'AA PG': 0.0019120358500158783,
#  'AA AA': 0.001851655770541693,
#  'AA DR': 0.0010465880442192177,
#  'AA SP': 0.0010465880442192177,
#  'AA LN': 0.000986207964745032,
#  'AA KR': 0.0008654478057966607,
#  'AA DK': 0.0007446876468482895,
#  'AA NH': 0.0007446876468482895,
#  'AA LS': 0.0004226605563192995,
#  'AA KM': 0.0004025338631612376,
#  'AA AG': 0.00028177370421286627,
#  'AA RG': 0.00016101354526449504,
#  'AA RK': 2.012669315806188e-05,
#  'AA GR': 0.0,
#  'DR LH': 0.004698270241984097,
#  'DR VB': 0.003708561982776793,
#  'DR MV': 0.0031625160466624185,
#  'DR CL': 0.0030032526486290594,
#  'DR SV': 0.002730229680571872,
#  'DR CS': 0.0010920918722287488,
#  'DR PG': 0.001080715915226366,
#  'DR AA': 0.0010465880442192177,
#  'DR DR': 0.0005915497641239057,
#  'DR SP': 0.0005915497641239057,
#  'DR LN': 0.0005574218931167572,
#  'DR KR': 0.0004891661511024604,
#  'DR DK': 0.00042091040908816355,
#  'DR NH': 0.00042091040908816355,
#  'DR LS': 0.0002388950970500388,
#  'DR KM': 0.00022751914004765598,
#  'DR AG': 0.0001592633980333592,
#  'DR RG': 9.10076560190624e-05,
#  'DR RK': 1.13759570023828e-05,
#  'DR GR': 0.0,
#  'SP LH': 0.004698270241984097,
#  'SP VB': 0.003708561982776793,
#  'SP MV': 0.0031625160466624185,
#  'SP CL': 0.0030032526486290594,
#  'SP SV': 0.002730229680571872,
#  'SP CS': 0.0010920918722287488,
#  'SP PG': 0.001080715915226366,
#  'SP AA': 0.0010465880442192177,
#  'SP DR': 0.0005915497641239057,
#  'SP SP': 0.0005915497641239057,
#  'SP LN': 0.0005574218931167572,
#  'SP KR': 0.0004891661511024604,
#  'SP DK': 0.00042091040908816355,
#  'SP NH': 0.00042091040908816355,
#  'SP LS': 0.0002388950970500388,
#  'SP KM': 0.00022751914004765598,
#  'SP AG': 0.0001592633980333592,
#  'SP RG': 9.10076560190624e-05,
#  'SP RK': 1.13759570023828e-05,
#  'SP GR': 0.0,
#  'LN LH': 0.004427216189561938,
#  'LN VB': 0.0034946064837704394,
#  'LN MV': 0.0029800631978165095,
#  'LN CL': 0.0028299880727466137,
#  'LN SV': 0.0025727164297696483,
#  'LN CS': 0.0010290865719078592,
#  'LN PG': 0.0010183669201171525,
#  'LN AA': 0.000986207964745032,
#  'LN DR': 0.0005574218931167572,
#  'LN SP': 0.0005574218931167572,
#  'LN LN': 0.0005252629377446365,
#  'LN KR': 0.00046094502700039534,
#  'LN DK': 0.0003966271162561541,
#  'LN NH': 0.0003966271162561541,
#  'LN LS': 0.00022511268760484426,
#  'LN KM': 0.00021439303581413736,
#  'LN AG': 0.00015007512506989617,
#  'LN RG': 8.575721432565495e-05,
#  'LN RK': 1.0719651790706868e-05,
#  'LN GR': 0.0,
#  'KR LH': 0.0038851080847176183,
#  'KR VB': 0.0030666954857577326,
#  'KR MV': 0.0026151575001246924,
#  'KR CL': 0.002483458920981722,
#  'KR SV': 0.0022576899281652016,
#  'KR CS': 0.0009030759712660807,
#  'KR PG': 0.0008936689298987258,
#  'KR AA': 0.0008654478057966607,
#  'KR DR': 0.0004891661511024604,
#  'KR SP': 0.0004891661511024604,
#  'KR LN': 0.00046094502700039534,
#  'KR KR': 0.0004045027787962653,
#  'KR DK': 0.0003480605305921353,
#  'KR NH': 0.0003480605305921353,
#  'KR LS': 0.00019754786871445517,
#  'KR KM': 0.00018814082734710017,
#  'KR AG': 0.00013169857914297012,
#  'KR RG': 7.525633093884007e-05,
#  'KR RK': 9.407041367355008e-06,
#  'KR GR': 0.0,
#  'DK LH': 0.0033429999798732994,
#  'DK VB': 0.0026387844877450253,
#  'DK MV': 0.002250251802432874,
#  'DK CL': 0.0021369297692168305,
#  'DK SV': 0.0019426634265607549,
#  'DK CS': 0.0007770653706243019,
#  'DK PG': 0.0007689709396802987,
#  'DK AA': 0.0007446876468482895,
#  'DK DR': 0.00042091040908816355,
#  'DK SP': 0.00042091040908816355,
#  'DK LN': 0.0003966271162561541,
#  'DK KR': 0.0003480605305921353,
#  'DK DK': 0.00029949394492811634,
#  'DK NH': 0.00029949394492811634,
#  'DK LS': 0.00016998304982406606,
#  'DK KM': 0.00016188861888006293,
#  'DK AG': 0.00011332203321604403,
#  'DK RG': 6.475544755202516e-05,
#  'DK RK': 8.094430944003145e-06,
#  'DK GR': 0.0,
#  'NH LH': 0.0033429999798732994,
#  'NH VB': 0.0026387844877450253,
#  'NH MV': 0.002250251802432874,
#  'NH CL': 0.0021369297692168305,
#  'NH SV': 0.0019426634265607549,
#  'NH CS': 0.0007770653706243019,
#  'NH PG': 0.0007689709396802987,
#  'NH AA': 0.0007446876468482895,
#  'NH DR': 0.00042091040908816355,
#  'NH SP': 0.00042091040908816355,
#  'NH LN': 0.0003966271162561541,
#  'NH KR': 0.0003480605305921353,
#  'NH DK': 0.00029949394492811634,
#  'NH NH': 0.00029949394492811634,
#  'NH LS': 0.00016998304982406606,
#  'NH KM': 0.00016188861888006293,
#  'NH AG': 0.00011332203321604403,
#  'NH RG': 6.475544755202516e-05,
#  'NH RK': 8.094430944003145e-06,
#  'NH GR': 0.0,
#  'LS LH': 0.001897378366955116,
#  'LS VB': 0.0014976884930444742,
#  'LS MV': 0.0012771699419213613,
#  'LS CL': 0.0012128520311771203,
#  'LS SV': 0.0011025927556155637,
#  'LS CS': 0.00044103710224622546,
#  'LS PG': 0.0004364429657644939,
#  'LS AA': 0.0004226605563192995,
#  'LS DR': 0.0002388950970500388,
#  'LS SP': 0.0002388950970500388,
#  'LS LN': 0.00022511268760484426,
#  'LS KR': 0.00019754786871445517,
#  'LS DK': 0.00016998304982406606,
#  'LS NH': 0.00016998304982406606,
#  'LS LS': 9.647686611636182e-05,
#  'LS KM': 9.18827296346303e-05,
#  'LS AG': 6.431791074424121e-05,
#  'LS RG': 3.6753091853852126e-05,
#  'LS RK': 4.594136481731516e-06,
#  'LS GR': 0.0,
#  'KM LH': 0.0018070270161477293,
#  'KM VB': 0.0014263699933756895,
#  'KM MV': 0.0012163523256393917,
#  'KM CL': 0.001155097172549638,
#  'KM SV': 0.0010500883386814891,
#  'KM CS': 0.0004200353354725957,
#  'KM PG': 0.0004156599673947561,
#  'KM AA': 0.0004025338631612376,
#  'KM DR': 0.00022751914004765598,
#  'KM SP': 0.00022751914004765598,
#  'KM LN': 0.00021439303581413736,
#  'KM KR': 0.00018814082734710017,
#  'KM DK': 0.00016188861888006293,
#  'KM NH': 0.00016188861888006293,
#  'KM LS': 9.18827296346303e-05,
#  'KM KM': 8.750736155679077e-05,
#  'KM AG': 6.125515308975354e-05,
#  'KM RG': 3.500294462271631e-05,
#  'KM RK': 4.375368077839539e-06,
#  'KM GR': 0.0,
#  'AG LH': 0.0012649189113034106,
#  'AG VB': 0.0009984589953629828,
#  'AG MV': 0.0008514466279475742,
#  'AG CL': 0.0008085680207847467,
#  'AG SV': 0.0007350618370770425,
#  'AG CS': 0.000294024734830817,
#  'AG PG': 0.0002909619771763293,
#  'AG AA': 0.00028177370421286627,
#  'AG DR': 0.0001592633980333592,
#  'AG SP': 0.0001592633980333592,
#  'AG LN': 0.00015007512506989617,
#  'AG KR': 0.00013169857914297012,
#  'AG DK': 0.00011332203321604403,
#  'AG NH': 0.00011332203321604403,
#  'AG LS': 6.431791074424121e-05,
#  'AG KM': 6.125515308975354e-05,
#  'AG AG': 4.287860716282748e-05,
#  'AG RG': 2.4502061235901417e-05,
#  'AG RK': 3.062757654487677e-06,
#  'AG GR': 0.0,
#  'RG LH': 0.0007228108064590917,
#  'RG VB': 0.0005705479973502759,
#  'RG MV': 0.0004865409302557567,
#  'RG CL': 0.00046203886901985527,
#  'RG SV': 0.0004200353354725957,
#  'RG CS': 0.00016801413418903827,
#  'RG PG': 0.00016626398695790244,
#  'RG AA': 0.00016101354526449504,
#  'RG DR': 9.10076560190624e-05,
#  'RG SP': 9.10076560190624e-05,
#  'RG LN': 8.575721432565495e-05,
#  'RG KR': 7.525633093884007e-05,
#  'RG DK': 6.475544755202516e-05,
#  'RG NH': 6.475544755202516e-05,
#  'RG LS': 3.6753091853852126e-05,
#  'RG KM': 3.500294462271631e-05,
#  'RG AG': 2.4502061235901417e-05,
#  'RG RG': 1.4001177849086524e-05,
#  'RG RK': 1.7501472311358155e-06,
#  'RG GR': 0.0,
#  'RK LH': 9.035135080738647e-05,
#  'RK VB': 7.131849966878448e-05,
#  'RK MV': 6.0817616281969586e-05,
#  'RK CL': 5.775485862748191e-05,
#  'RK SV': 5.250441693407446e-05,
#  'RK CS': 2.1001766773629783e-05,
#  'RK PG': 2.0782998369737805e-05,
#  'RK AA': 2.012669315806188e-05,
#  'RK DR': 1.13759570023828e-05,
#  'RK SP': 1.13759570023828e-05,
#  'RK LN': 1.0719651790706868e-05,
#  'RK KR': 9.407041367355008e-06,
#  'RK DK': 8.094430944003145e-06,
#  'RK NH': 8.094430944003145e-06,
#  'RK LS': 4.594136481731516e-06,
#  'RK KM': 4.375368077839539e-06,
#  'RK AG': 3.062757654487677e-06,
#  'RK RG': 1.7501472311358155e-06,
#  'RK RK': 2.1876840389197694e-07,
#  'RK GR': 0.0,
#  'GR LH': 0.0,
#  'GR VB': 0.0,
#  'GR MV': 0.0,
#  'GR CL': 0.0,
#  'GR SV': 0.0,
#  'GR CS': 0.0,
#  'GR PG': 0.0,
#  'GR AA': 0.0,
#  'GR DR': 0.0,
#  'GR SP': 0.0,
#  'GR LN': 0.0,
#  'GR KR': 0.0,
#  'GR DK': 0.0,
#  'GR NH': 0.0,
#  'GR LS': 0.0,
#  'GR KM': 0.0,
#  'GR AG': 0.0,
#  'GR RG': 0.0,
#  'GR RK': 0.0,
#  'GR GR': 0.0}

# %% [markdown]
# #### Probability for Mercedes to win at both race

# %% [markdown]
# #### Now, if I need probability of Mercedes winning both races, I need both the racers to win on both days so, the logic is applied below

# %%
def mercedeswinfirst(outcome) : 
    return (outcome.startswith('LH') or outcome.startswith('VB')) and (outcome.endswith('LH') or outcome.endswith('VB'))

# %%
MercedesWinsBoth = p(mercedeswinfirst,F)
MercedesWinsBoth
# Out:
# 0.11947401950189034

# %% [markdown]
# #### Probability for Mercedes to atleast a race

# %% [markdown]
# #### If I need probability of Mercedes winning atleast one race, I need any one racer winning any day so, the logic is applied below

# %%
def mercedeswinatleastone(outcome) : 
    return (outcome.startswith('LH') or outcome.startswith('VB')) or (outcome.endswith('LH') or outcome.endswith('VB'))

# %%
MercedesWinsAtLeastOne = p(mercedeswinatleastone, F)
MercedesWinsAtLeastOne
# Out:
# 0.5718262611342168

# %% [markdown]
# #### Now, I need to figure out the probability of cars winning the second one based on the condition that it has already won the first one.
# #### So, first I am getting the probability of car winning on first day, and later based on first win, getting the probability of second win

# %% [markdown]
# #### Condition if Mercedes wins the first Probability for winning the second one

# %%
def mercedeswinfirst(outcome):
    return (outcome.startswith('LH') or outcome.startswith('VB'))
def mercedeswinsecond(outcome):
    return (outcome.endswith('LH') or outcome.endswith('VB'))
MercdesWinSecond = p(mercedeswinsecond, such_that(mercedeswinfirst,F))
MercdesWinSecond
# Out:
# 0.3456501403180543

# %% [markdown]
# #### Condition if Ferrari wins the first Probability for winning the second one

# %%
def ferrariwinfirst(outcome):
    return (outcome.startswith('CL') or outcome.startswith('SV'))
def ferrariwinsecond(outcome):
    return (outcome.endswith('CL') or outcome.endswith('SV'))
FerrariWinSecond = p(ferrariwinsecond, such_that(ferrariwinfirst,F))
FerrariWinSecond
# Out:
# 0.23573433115060805

# %% [markdown]
# #### Condition if Redbull wins the first Probability for winning the second one

# %%
def redbullwinfirst(outcome):
    return (outcome.startswith('MV') or outcome.startswith('AA'))
def redbullwinsecond(outcome):
    return (outcome.endswith('MV') or outcome.endswith('AA'))
RedBullWinSecond = p(redbullwinsecond, such_that(redbullwinfirst,F))
RedBullWinSecond
# Out:
# 0.17305893358278765

# %% [markdown]
# #### Condition if Renault wins the first Probability for winning the second one

# %%
def renaultwinfirst(outcome):
    return (outcome.startswith('NH') or outcome.startswith('DR'))
def renaultwinsecond(outcome):
    return (outcome.endswith('NH') or outcome.endswith('DR'))
RenaultWinSecond = p(renaultwinsecond, such_that(renaultwinfirst,F))
RenaultWinSecond
# Out:
# 0.041627689429373234

# %% [markdown]
# #### Condition if Alfa Romeo wins the first Probability for winning the second one

# %%
def renaultwinfirst(outcome):
    return (outcome.startswith('AG') or outcome.startswith('KR'))
def renaultwinsecond(outcome):
    return (outcome.endswith('AG') or outcome.endswith('KR'))
RenaultWinSecond = p(renaultwinsecond, such_that(renaultwinfirst,F))
RenaultWinSecond
# Out:
# 0.02666043030869972

# %% [markdown]
# #### Condition if McLaren wins the first Probability for winning the second one

# %%
def renaultwinfirst(outcome):
    return (outcome.startswith('CS') or outcome.startswith('LN'))
def renaultwinsecond(outcome):
    return (outcome.endswith('CS') or outcome.endswith('LN'))
RenaultWinSecond = p(renaultwinsecond, such_that(renaultwinfirst,F))
RenaultWinSecond
# Out:
# 0.0678203928905519

# %% [markdown]
# #### Now I need to find the probability of winning a race based on weather conditions. So, I've taken all weather conditions equiprobable.

# %% [markdown]
# #### Probability of rainy, sunny, cloudy, snowy, and foggy weather conditions on race tracks

# %%
weather = ProbDist(rainy = 1, cloudy = 1, foggy = 1, sunny = 1, snowy = 1)
weather
# Out:
# {'rainy': 0.2, 'cloudy': 0.2, 'foggy': 0.2, 'sunny': 0.2, 'snowy': 0.2}

# %% [markdown]
# #### Now, I joined 1st day with all weather conditions and seond day with all weather conditions and joined them both to find the probability of winning a race on both days on these weather conditions

# %% [markdown]
# #### Probability of each winning the 1st day in all weather conditions

# %%
def joint(A, B, sep=' '):
    """The joint distribution of two independent probability distributions. 
    Result is all entries of the form {a+sep+b: P(a)*P(b)}"""
    return ProbDist({a + sep + b: A[a] * B[b]
                    for a in A
                    for b in B})

FirstDayWeather = joint(SGP, weather, ' ')
FirstDayWeather
# Out:
# {'LH rainy': 0.0386342376052385,
#  'LH cloudy': 0.0386342376052385,
#  'LH foggy': 0.0386342376052385,
#  'LH sunny': 0.0386342376052385,
#  'LH snowy': 0.0386342376052385,
#  'VB rainy': 0.03049579045837228,
#  'VB cloudy': 0.03049579045837228,
#  'VB foggy': 0.03049579045837228,
#  'VB sunny': 0.03049579045837228,
#  'VB snowy': 0.03049579045837228,
#  'MV rainy': 0.026005612722170224,
#  'MV cloudy': 0.026005612722170224,
#  'MV foggy': 0.026005612722170224,
#  'MV sunny': 0.026005612722170224,
#  'MV snowy': 0.026005612722170224,
#  'CL rainy': 0.024695977549111292,
#  'CL cloudy': 0.024695977549111292,
#  'CL foggy': 0.024695977549111292,
#  'CL sunny': 0.024695977549111292,
#  'CL snowy': 0.024695977549111292,
#  'SV rainy': 0.022450888681010268,
#  'SV cloudy': 0.022450888681010268,
#  'SV foggy': 0.022450888681010268,
#  'SV sunny': 0.022450888681010268,
#  'SV snowy': 0.022450888681010268,
#  'CS rainy': 0.008980355472404106,
#  'CS cloudy': 0.008980355472404106,
#  'CS foggy': 0.008980355472404106,
#  'CS sunny': 0.008980355472404106,
#  'CS snowy': 0.008980355472404106,
#  'PG rainy': 0.008886810102899895,
#  'PG cloudy': 0.008886810102899895,
#  'PG foggy': 0.008886810102899895,
#  'PG sunny': 0.008886810102899895,
#  'PG snowy': 0.008886810102899895,
#  'AA rainy': 0.008606173994387269,
#  'AA cloudy': 0.008606173994387269,
#  'AA foggy': 0.008606173994387269,
#  'AA sunny': 0.008606173994387269,
#  'AA snowy': 0.008606173994387269,
#  'DR rainy': 0.004864359214218891,
#  'DR cloudy': 0.004864359214218891,
#  'DR foggy': 0.004864359214218891,
#  'DR sunny': 0.004864359214218891,
#  'DR snowy': 0.004864359214218891,
#  'SP rainy': 0.004864359214218891,
#  'SP cloudy': 0.004864359214218891,
#  'SP foggy': 0.004864359214218891,
#  'SP sunny': 0.004864359214218891,
#  'SP snowy': 0.004864359214218891,
#  'LN rainy': 0.004583723105706262,
#  'LN cloudy': 0.004583723105706262,
#  'LN foggy': 0.004583723105706262,
#  'LN sunny': 0.004583723105706262,
#  'LN snowy': 0.004583723105706262,
#  'KR rainy': 0.004022450888681006,
#  'KR cloudy': 0.004022450888681006,
#  'KR foggy': 0.004022450888681006,
#  'KR sunny': 0.004022450888681006,
#  'KR snowy': 0.004022450888681006,
#  'DK rainy': 0.003461178671655749,
#  'DK cloudy': 0.003461178671655749,
#  'DK foggy': 0.003461178671655749,
#  'DK sunny': 0.003461178671655749,
#  'DK snowy': 0.003461178671655749,
#  'NH rainy': 0.003461178671655749,
#  'NH cloudy': 0.003461178671655749,
#  'NH foggy': 0.003461178671655749,
#  'NH sunny': 0.003461178671655749,
#  'NH snowy': 0.003461178671655749,
#  'LS rainy': 0.0019644527595883985,
#  'LS cloudy': 0.0019644527595883985,
#  'LS foggy': 0.0019644527595883985,
#  'LS sunny': 0.0019644527595883985,
#  'LS snowy': 0.0019644527595883985,
#  'KM rainy': 0.0018709073900841887,
#  'KM cloudy': 0.0018709073900841887,
#  'KM foggy': 0.0018709073900841887,
#  'KM sunny': 0.0018709073900841887,
#  'KM snowy': 0.0018709073900841887,
#  'AG rainy': 0.0013096351730589322,
#  'AG cloudy': 0.0013096351730589322,
#  'AG foggy': 0.0013096351730589322,
#  'AG sunny': 0.0013096351730589322,
#  'AG snowy': 0.0013096351730589322,
#  'RG rainy': 0.0007483629560336755,
#  'RG cloudy': 0.0007483629560336755,
#  'RG foggy': 0.0007483629560336755,
#  'RG sunny': 0.0007483629560336755,
#  'RG snowy': 0.0007483629560336755,
#  'RK rainy': 9.354536950420944e-05,
#  'RK cloudy': 9.354536950420944e-05,
#  'RK foggy': 9.354536950420944e-05,
#  'RK sunny': 9.354536950420944e-05,
#  'RK snowy': 9.354536950420944e-05,
#  'GR rainy': 0.0,
#  'GR cloudy': 0.0,
#  'GR foggy': 0.0,
#  'GR sunny': 0.0,
#  'GR snowy': 0.0}

# %% [markdown]
# #### Probability of each winning the second day in all weather conditions

# %%
def joint(A, B, sep=' '):
    """The joint distribution of two independent probability distributions. 
    Result is all entries of the form {a+sep+b: P(a)*P(b)}"""
    return ProbDist({a + sep + b: A[a] * B[b]
                    for a in A
                    for b in B})

SecondDayWeather = joint(RGP, weather, ' ')
SecondDayWeather
# Out:
# {'LH rainy': 0.0386342376052385,
#  'LH cloudy': 0.0386342376052385,
#  'LH foggy': 0.0386342376052385,
#  'LH sunny': 0.0386342376052385,
#  'LH snowy': 0.0386342376052385,
#  'VB rainy': 0.03049579045837228,
#  'VB cloudy': 0.03049579045837228,
#  'VB foggy': 0.03049579045837228,
#  'VB sunny': 0.03049579045837228,
#  'VB snowy': 0.03049579045837228,
#  'MV rainy': 0.026005612722170224,
#  'MV cloudy': 0.026005612722170224,
#  'MV foggy': 0.026005612722170224,
#  'MV sunny': 0.026005612722170224,
#  'MV snowy': 0.026005612722170224,
#  'CL rainy': 0.024695977549111292,
#  'CL cloudy': 0.024695977549111292,
#  'CL foggy': 0.024695977549111292,
#  'CL sunny': 0.024695977549111292,
#  'CL snowy': 0.024695977549111292,
#  'SV rainy': 0.022450888681010268,
#  'SV cloudy': 0.022450888681010268,
#  'SV foggy': 0.022450888681010268,
#  'SV sunny': 0.022450888681010268,
#  'SV snowy': 0.022450888681010268,
#  'CS rainy': 0.008980355472404106,
#  'CS cloudy': 0.008980355472404106,
#  'CS foggy': 0.008980355472404106,
#  'CS sunny': 0.008980355472404106,
#  'CS snowy': 0.008980355472404106,
#  'PG rainy': 0.008886810102899895,
#  'PG cloudy': 0.008886810102899895,
#  'PG foggy': 0.008886810102899895,
#  'PG sunny': 0.008886810102899895,
#  'PG snowy': 0.008886810102899895,
#  'AA rainy': 0.008606173994387269,
#  'AA cloudy': 0.008606173994387269,
#  'AA foggy': 0.008606173994387269,
#  'AA sunny': 0.008606173994387269,
#  'AA snowy': 0.008606173994387269,
#  'DR rainy': 0.004864359214218891,
#  'DR cloudy': 0.004864359214218891,
#  'DR foggy': 0.004864359214218891,
#  'DR sunny': 0.004864359214218891,
#  'DR snowy': 0.004864359214218891,
#  'SP rainy': 0.004864359214218891,
#  'SP cloudy': 0.004864359214218891,
#  'SP foggy': 0.004864359214218891,
#  'SP sunny': 0.004864359214218891,
#  'SP snowy': 0.004864359214218891,
#  'LN rainy': 0.004583723105706262,
#  'LN cloudy': 0.004583723105706262,
#  'LN foggy': 0.004583723105706262,
#  'LN sunny': 0.004583723105706262,
#  'LN snowy': 0.004583723105706262,
#  'KR rainy': 0.004022450888681006,
#  'KR cloudy': 0.004022450888681006,
#  'KR foggy': 0.004022450888681006,
#  'KR sunny': 0.004022450888681006,
#  'KR snowy': 0.004022450888681006,
#  'DK rainy': 0.003461178671655749,
#  'DK cloudy': 0.003461178671655749,
#  'DK foggy': 0.003461178671655749,
#  'DK sunny': 0.003461178671655749,
#  'DK snowy': 0.003461178671655749,
#  'NH rainy': 0.003461178671655749,
#  'NH cloudy': 0.003461178671655749,
#  'NH foggy': 0.003461178671655749,
#  'NH sunny': 0.003461178671655749,
#  'NH snowy': 0.003461178671655749,
#  'LS rainy': 0.0019644527595883985,
#  'LS cloudy': 0.0019644527595883985,
#  'LS foggy': 0.0019644527595883985,
#  'LS sunny': 0.0019644527595883985,
#  'LS snowy': 0.0019644527595883985,
#  'KM rainy': 0.0018709073900841887,
#  'KM cloudy': 0.0018709073900841887,
#  'KM foggy': 0.0018709073900841887,
#  'KM sunny': 0.0018709073900841887,
#  'KM snowy': 0.0018709073900841887,
#  'AG rainy': 0.0013096351730589322,
#  'AG cloudy': 0.0013096351730589322,
#  'AG foggy': 0.0013096351730589322,
#  'AG sunny': 0.0013096351730589322,
#  'AG snowy': 0.0013096351730589322,
#  'RG rainy': 0.0007483629560336755,
#  'RG cloudy': 0.0007483629560336755,
#  'RG foggy': 0.0007483629560336755,
#  'RG sunny': 0.0007483629560336755,
#  'RG snowy': 0.0007483629560336755,
#  'RK rainy': 9.354536950420944e-05,
#  'RK cloudy': 9.354536950420944e-05,
#  'RK foggy': 9.354536950420944e-05,
#  'RK sunny': 9.354536950420944e-05,
#  'RK snowy': 9.354536950420944e-05,
#  'GR rainy': 0.0,
#  'GR cloudy': 0.0,
#  'GR foggy': 0.0,
#  'GR sunny': 0.0,
#  'GR snowy': 0.0}

# %% [markdown]
# #### Combining two days

# %%
def joint(A, B, sep=' '):
    """The joint distribution of two independent probability distributions. 
    Result is all entries of the form {a+sep+b: P(a)*P(b)}"""
    return ProbDist({a + sep + b: A[a] * B[b]
                    for a in A
                    for b in B})

CombinedWeather = joint(FirstDayWeather, SecondDayWeather, ' ')
CombinedWeather
# Out:
# {'LH rainy LH rainy': 0.001492604315338075,
#  'LH rainy LH cloudy': 0.001492604315338075,
#  'LH rainy LH foggy': 0.001492604315338075,
#  'LH rainy LH sunny': 0.001492604315338075,
#  'LH rainy LH snowy': 0.001492604315338075,
#  'LH rainy VB rainy': 0.0011781816145283593,
#  'LH rainy VB cloudy': 0.0011781816145283593,
#  'LH rainy VB foggy': 0.0011781816145283593,
#  'LH rainy VB sunny': 0.0011781816145283593,
#  'LH rainy VB snowy': 0.0011781816145283593,
#  'LH rainy MV rainy': 0.0010047070209781715,
#  'LH rainy MV cloudy': 0.0010047070209781715,
#  'LH rainy MV foggy': 0.0010047070209781715,
#  'LH rainy MV sunny': 0.0010047070209781715,
#  'LH rainy MV snowy': 0.0010047070209781715,
#  'LH rainy CL rainy': 0.0009541102645260334,
#  'LH rainy CL cloudy': 0.0009541102645260334,
#  'LH rainy CL foggy': 0.0009541102645260334,
#  'LH rainy CL sunny': 0.0009541102645260334,
#  'LH rainy CL snowy': 0.0009541102645260334,
#  'LH rainy SV rainy': 0.0008673729677509395,
#  'LH rainy SV cloudy': 0.0008673729677509395,
#  'LH rainy SV foggy': 0.0008673729677509395,
#  'LH rainy SV sunny': 0.0008673729677509395,
#  'LH rainy SV snowy': 0.0008673729677509395,
#  'LH rainy CS rainy': 0.00034694918710037576,
#  'LH rainy CS cloudy': 0.00034694918710037576,
#  'LH rainy CS foggy': 0.00034694918710037576,
#  'LH rainy CS sunny': 0.00034694918710037576,
#  'LH rainy CS snowy': 0.00034694918710037576,
#  'LH rainy PG rainy': 0.00034333513306808016,
#  'LH rainy PG cloudy': 0.00034333513306808016,
#  'LH rainy PG foggy': 0.00034333513306808016,
#  'LH rainy PG sunny': 0.00034333513306808016,
#  'LH rainy PG snowy': 0.00034333513306808016,
#  'LH rainy AA rainy': 0.00033249297097119346,
#  'LH rainy AA cloudy': 0.00033249297097119346,
#  'LH rainy AA foggy': 0.00033249297097119346,
#  'LH rainy AA sunny': 0.00033249297097119346,
#  'LH rainy AA snowy': 0.00033249297097119346,
#  'LH rainy DR rainy': 0.00018793080967937023,
#  'LH rainy DR cloudy': 0.00018793080967937023,
#  'LH rainy DR foggy': 0.00018793080967937023,
#  'LH rainy DR sunny': 0.00018793080967937023,
#  'LH rainy DR snowy': 0.00018793080967937023,
#  'LH rainy SP rainy': 0.00018793080967937023,
#  'LH rainy SP cloudy': 0.00018793080967937023,
#  'LH rainy SP foggy': 0.00018793080967937023,
#  'LH rainy SP sunny': 0.00018793080967937023,
#  'LH rainy SP snowy': 0.00018793080967937023,
#  'LH rainy LN rainy': 0.00017708864758248346,
#  'LH rainy LN cloudy': 0.00017708864758248346,
#  'LH rainy LN foggy': 0.00017708864758248346,
#  'LH rainy LN sunny': 0.00017708864758248346,
#  'LH rainy LN snowy': 0.00017708864758248346,
#  'LH rainy KR rainy': 0.00015540432338871,
#  'LH rainy KR cloudy': 0.00015540432338871,
#  'LH rainy KR foggy': 0.00015540432338871,
#  'LH rainy KR sunny': 0.00015540432338871,
#  'LH rainy KR snowy': 0.00015540432338871,
#  'LH rainy DK rainy': 0.0001337199991949365,
#  'LH rainy DK cloudy': 0.0001337199991949365,
#  'LH rainy DK foggy': 0.0001337199991949365,
#  'LH rainy DK sunny': 0.0001337199991949365,
#  'LH rainy DK snowy': 0.0001337199991949365,
#  'LH rainy NH rainy': 0.0001337199991949365,
#  'LH rainy NH cloudy': 0.0001337199991949365,
#  'LH rainy NH foggy': 0.0001337199991949365,
#  'LH rainy NH sunny': 0.0001337199991949365,
#  'LH rainy NH snowy': 0.0001337199991949365,
#  'LH rainy LS rainy': 7.589513467820722e-05,
#  'LH rainy LS cloudy': 7.589513467820722e-05,
#  'LH rainy LS foggy': 7.589513467820722e-05,
#  'LH rainy LS sunny': 7.589513467820722e-05,
#  'LH rainy LS snowy': 7.589513467820722e-05,
#  'LH rainy KM rainy': 7.228108064591161e-05,
#  'LH rainy KM cloudy': 7.228108064591161e-05,
#  'LH rainy KM foggy': 7.228108064591161e-05,
#  'LH rainy KM sunny': 7.228108064591161e-05,
#  'LH rainy KM snowy': 7.228108064591161e-05,
#  'LH rainy AG rainy': 5.059675645213813e-05,
#  'LH rainy AG cloudy': 5.059675645213813e-05,
#  'LH rainy AG foggy': 5.059675645213813e-05,
#  'LH rainy AG sunny': 5.059675645213813e-05,
#  'LH rainy AG snowy': 5.059675645213813e-05,
#  'LH rainy RG rainy': 2.8912432258364648e-05,
#  'LH rainy RG cloudy': 2.8912432258364648e-05,
#  'LH rainy RG foggy': 2.8912432258364648e-05,
#  'LH rainy RG sunny': 2.8912432258364648e-05,
#  'LH rainy RG snowy': 2.8912432258364648e-05,
#  'LH rainy RK rainy': 3.614054032295581e-06,
#  'LH rainy RK cloudy': 3.614054032295581e-06,
#  'LH rainy RK foggy': 3.614054032295581e-06,
#  'LH rainy RK sunny': 3.614054032295581e-06,
#  'LH rainy RK snowy': 3.614054032295581e-06,
#  'LH rainy GR rainy': 0.0,
#  'LH rainy GR cloudy': 0.0,
#  'LH rainy GR foggy': 0.0,
#  'LH rainy GR sunny': 0.0,
#  'LH rainy GR snowy': 0.0,
#  'LH cloudy LH rainy': 0.001492604315338075,
#  'LH cloudy LH cloudy': 0.001492604315338075,
#  'LH cloudy LH foggy': 0.001492604315338075,
#  'LH cloudy LH sunny': 0.001492604315338075,
#  'LH cloudy LH snowy': 0.001492604315338075,
#  'LH cloudy VB rainy': 0.0011781816145283593,
#  'LH cloudy VB cloudy': 0.0011781816145283593,
#  'LH cloudy VB foggy': 0.0011781816145283593,
#  'LH cloudy VB sunny': 0.0011781816145283593,
#  'LH cloudy VB snowy': 0.0011781816145283593,
#  'LH cloudy MV rainy': 0.0010047070209781715,
#  'LH cloudy MV cloudy': 0.0010047070209781715,
#  'LH cloudy MV foggy': 0.0010047070209781715,
#  'LH cloudy MV sunny': 0.0010047070209781715,
#  'LH cloudy MV snowy': 0.0010047070209781715,
#  'LH cloudy CL rainy': 0.0009541102645260334,
#  'LH cloudy CL cloudy': 0.0009541102645260334,
#  'LH cloudy CL foggy': 0.0009541102645260334,
#  'LH cloudy CL sunny': 0.0009541102645260334,
#  'LH cloudy CL snowy': 0.0009541102645260334,
#  'LH cloudy SV rainy': 0.0008673729677509395,
#  'LH cloudy SV cloudy': 0.0008673729677509395,
#  'LH cloudy SV foggy': 0.0008673729677509395,
#  'LH cloudy SV sunny': 0.0008673729677509395,
#  'LH cloudy SV snowy': 0.0008673729677509395,
#  'LH cloudy CS rainy': 0.00034694918710037576,
#  'LH cloudy CS cloudy': 0.00034694918710037576,
#  'LH cloudy CS foggy': 0.00034694918710037576,
#  'LH cloudy CS sunny': 0.00034694918710037576,
#  'LH cloudy CS snowy': 0.00034694918710037576,
#  'LH cloudy PG rainy': 0.00034333513306808016,
#  'LH cloudy PG cloudy': 0.00034333513306808016,
#  'LH cloudy PG foggy': 0.00034333513306808016,
#  'LH cloudy PG sunny': 0.00034333513306808016,
#  'LH cloudy PG snowy': 0.00034333513306808016,
#  'LH cloudy AA rainy': 0.00033249297097119346,
#  'LH cloudy AA cloudy': 0.00033249297097119346,
#  'LH cloudy AA foggy': 0.00033249297097119346,
#  'LH cloudy AA sunny': 0.00033249297097119346,
#  'LH cloudy AA snowy': 0.00033249297097119346,
#  'LH cloudy DR rainy': 0.00018793080967937023,
#  'LH cloudy DR cloudy': 0.00018793080967937023,
#  'LH cloudy DR foggy': 0.00018793080967937023,
#  'LH cloudy DR sunny': 0.00018793080967937023,
#  'LH cloudy DR snowy': 0.00018793080967937023,
#  'LH cloudy SP rainy': 0.00018793080967937023,
#  'LH cloudy SP cloudy': 0.00018793080967937023,
#  'LH cloudy SP foggy': 0.00018793080967937023,
#  'LH cloudy SP sunny': 0.00018793080967937023,
#  'LH cloudy SP snowy': 0.00018793080967937023,
#  'LH cloudy LN rainy': 0.00017708864758248346,
#  'LH cloudy LN cloudy': 0.00017708864758248346,
#  'LH cloudy LN foggy': 0.00017708864758248346,
#  'LH cloudy LN sunny': 0.00017708864758248346,
#  'LH cloudy LN snowy': 0.00017708864758248346,
#  'LH cloudy KR rainy': 0.00015540432338871,
#  'LH cloudy KR cloudy': 0.00015540432338871,
#  'LH cloudy KR foggy': 0.00015540432338871,
#  'LH cloudy KR sunny': 0.00015540432338871,
#  'LH cloudy KR snowy': 0.00015540432338871,
#  'LH cloudy DK rainy': 0.0001337199991949365,
#  'LH cloudy DK cloudy': 0.0001337199991949365,
#  'LH cloudy DK foggy': 0.0001337199991949365,
#  'LH cloudy DK sunny': 0.0001337199991949365,
#  'LH cloudy DK snowy': 0.0001337199991949365,
#  'LH cloudy NH rainy': 0.0001337199991949365,
#  'LH cloudy NH cloudy': 0.0001337199991949365,
#  'LH cloudy NH foggy': 0.0001337199991949365,
#  'LH cloudy NH sunny': 0.0001337199991949365,
#  'LH cloudy NH snowy': 0.0001337199991949365,
#  'LH cloudy LS rainy': 7.589513467820722e-05,
#  'LH cloudy LS cloudy': 7.589513467820722e-05,
#  'LH cloudy LS foggy': 7.589513467820722e-05,
#  'LH cloudy LS sunny': 7.589513467820722e-05,
#  'LH cloudy LS snowy': 7.589513467820722e-05,
#  'LH cloudy KM rainy': 7.228108064591161e-05,
#  'LH cloudy KM cloudy': 7.228108064591161e-05,
#  'LH cloudy KM foggy': 7.228108064591161e-05,
#  'LH cloudy KM sunny': 7.228108064591161e-05,
#  'LH cloudy KM snowy': 7.228108064591161e-05,
#  'LH cloudy AG rainy': 5.059675645213813e-05,
#  'LH cloudy AG cloudy': 5.059675645213813e-05,
#  'LH cloudy AG foggy': 5.059675645213813e-05,
#  'LH cloudy AG sunny': 5.059675645213813e-05,
#  'LH cloudy AG snowy': 5.059675645213813e-05,
#  'LH cloudy RG rainy': 2.8912432258364648e-05,
#  'LH cloudy RG cloudy': 2.8912432258364648e-05,
#  'LH cloudy RG foggy': 2.8912432258364648e-05,
#  'LH cloudy RG sunny': 2.8912432258364648e-05,
#  'LH cloudy RG snowy': 2.8912432258364648e-05,
#  'LH cloudy RK rainy': 3.614054032295581e-06,
#  'LH cloudy RK cloudy': 3.614054032295581e-06,
#  'LH cloudy RK foggy': 3.614054032295581e-06,
#  'LH cloudy RK sunny': 3.614054032295581e-06,
#  'LH cloudy RK snowy': 3.614054032295581e-06,
#  'LH cloudy GR rainy': 0.0,
#  'LH cloudy GR cloudy': 0.0,
#  'LH cloudy GR foggy': 0.0,
#  'LH cloudy GR sunny': 0.0,
#  'LH cloudy GR snowy': 0.0,
#  'LH foggy LH rainy': 0.001492604315338075,
#  'LH foggy LH cloudy': 0.001492604315338075,
#  'LH foggy LH foggy': 0.001492604315338075,
#  'LH foggy LH sunny': 0.001492604315338075,
#  'LH foggy LH snowy': 0.001492604315338075,
#  'LH foggy VB rainy': 0.0011781816145283593,
#  'LH foggy VB cloudy': 0.0011781816145283593,
#  'LH foggy VB foggy': 0.0011781816145283593,
#  'LH foggy VB sunny': 0.0011781816145283593,
#  'LH foggy VB snowy': 0.0011781816145283593,
#  'LH foggy MV rainy': 0.0010047070209781715,
#  'LH foggy MV cloudy': 0.0010047070209781715,
#  'LH foggy MV foggy': 0.0010047070209781715,
#  'LH foggy MV sunny': 0.0010047070209781715,
#  'LH foggy MV snowy': 0.0010047070209781715,
#  'LH foggy CL rainy': 0.0009541102645260334,
#  'LH foggy CL cloudy': 0.0009541102645260334,
#  'LH foggy CL foggy': 0.0009541102645260334,
#  'LH foggy CL sunny': 0.0009541102645260334,
#  'LH foggy CL snowy': 0.0009541102645260334,
#  'LH foggy SV rainy': 0.0008673729677509395,
#  'LH foggy SV cloudy': 0.0008673729677509395,
#  'LH foggy SV foggy': 0.0008673729677509395,
#  'LH foggy SV sunny': 0.0008673729677509395,
#  'LH foggy SV snowy': 0.0008673729677509395,
#  'LH foggy CS rainy': 0.00034694918710037576,
#  'LH foggy CS cloudy': 0.00034694918710037576,
#  'LH foggy CS foggy': 0.00034694918710037576,
#  'LH foggy CS sunny': 0.00034694918710037576,
#  'LH foggy CS snowy': 0.00034694918710037576,
#  'LH foggy PG rainy': 0.00034333513306808016,
#  'LH foggy PG cloudy': 0.00034333513306808016,
#  'LH foggy PG foggy': 0.00034333513306808016,
#  'LH foggy PG sunny': 0.00034333513306808016,
#  'LH foggy PG snowy': 0.00034333513306808016,
#  'LH foggy AA rainy': 0.00033249297097119346,
#  'LH foggy AA cloudy': 0.00033249297097119346,
#  'LH foggy AA foggy': 0.00033249297097119346,
#  'LH foggy AA sunny': 0.00033249297097119346,
#  'LH foggy AA snowy': 0.00033249297097119346,
#  'LH foggy DR rainy': 0.00018793080967937023,
#  'LH foggy DR cloudy': 0.00018793080967937023,
#  'LH foggy DR foggy': 0.00018793080967937023,
#  'LH foggy DR sunny': 0.00018793080967937023,
#  'LH foggy DR snowy': 0.00018793080967937023,
#  'LH foggy SP rainy': 0.00018793080967937023,
#  'LH foggy SP cloudy': 0.00018793080967937023,
#  'LH foggy SP foggy': 0.00018793080967937023,
#  'LH foggy SP sunny': 0.00018793080967937023,
#  'LH foggy SP snowy': 0.00018793080967937023,
#  'LH foggy LN rainy': 0.00017708864758248346,
#  'LH foggy LN cloudy': 0.00017708864758248346,
#  'LH foggy LN foggy': 0.00017708864758248346,
#  'LH foggy LN sunny': 0.00017708864758248346,
#  'LH foggy LN snowy': 0.00017708864758248346,
#  'LH foggy KR rainy': 0.00015540432338871,
#  'LH foggy KR cloudy': 0.00015540432338871,
#  'LH foggy KR foggy': 0.00015540432338871,
#  'LH foggy KR sunny': 0.00015540432338871,
#  'LH foggy KR snowy': 0.00015540432338871,
#  'LH foggy DK rainy': 0.0001337199991949365,
#  'LH foggy DK cloudy': 0.0001337199991949365,
#  'LH foggy DK foggy': 0.0001337199991949365,
#  'LH foggy DK sunny': 0.0001337199991949365,
#  'LH foggy DK snowy': 0.0001337199991949365,
#  'LH foggy NH rainy': 0.0001337199991949365,
#  'LH foggy NH cloudy': 0.0001337199991949365,
#  'LH foggy NH foggy': 0.0001337199991949365,
#  'LH foggy NH sunny': 0.0001337199991949365,
#  'LH foggy NH snowy': 0.0001337199991949365,
#  'LH foggy LS rainy': 7.589513467820722e-05,
#  'LH foggy LS cloudy': 7.589513467820722e-05,
#  'LH foggy LS foggy': 7.589513467820722e-05,
#  'LH foggy LS sunny': 7.589513467820722e-05,
#  'LH foggy LS snowy': 7.589513467820722e-05,
#  'LH foggy KM rainy': 7.228108064591161e-05,
#  'LH foggy KM cloudy': 7.228108064591161e-05,
#  'LH foggy KM foggy': 7.228108064591161e-05,
#  'LH foggy KM sunny': 7.228108064591161e-05,
#  'LH foggy KM snowy': 7.228108064591161e-05,
#  'LH foggy AG rainy': 5.059675645213813e-05,
#  'LH foggy AG cloudy': 5.059675645213813e-05,
#  'LH foggy AG foggy': 5.059675645213813e-05,
#  'LH foggy AG sunny': 5.059675645213813e-05,
#  'LH foggy AG snowy': 5.059675645213813e-05,
#  'LH foggy RG rainy': 2.8912432258364648e-05,
#  'LH foggy RG cloudy': 2.8912432258364648e-05,
#  'LH foggy RG foggy': 2.8912432258364648e-05,
#  'LH foggy RG sunny': 2.8912432258364648e-05,
#  'LH foggy RG snowy': 2.8912432258364648e-05,
#  'LH foggy RK rainy': 3.614054032295581e-06,
#  'LH foggy RK cloudy': 3.614054032295581e-06,
#  'LH foggy RK foggy': 3.614054032295581e-06,
#  'LH foggy RK sunny': 3.614054032295581e-06,
#  'LH foggy RK snowy': 3.614054032295581e-06,
#  'LH foggy GR rainy': 0.0,
#  'LH foggy GR cloudy': 0.0,
#  'LH foggy GR foggy': 0.0,
#  'LH foggy GR sunny': 0.0,
#  'LH foggy GR snowy': 0.0,
#  'LH sunny LH rainy': 0.001492604315338075,
#  'LH sunny LH cloudy': 0.001492604315338075,
#  'LH sunny LH foggy': 0.001492604315338075,
#  'LH sunny LH sunny': 0.001492604315338075,
#  'LH sunny LH snowy': 0.001492604315338075,
#  'LH sunny VB rainy': 0.0011781816145283593,
#  'LH sunny VB cloudy': 0.0011781816145283593,
#  'LH sunny VB foggy': 0.0011781816145283593,
#  'LH sunny VB sunny': 0.0011781816145283593,
#  'LH sunny VB snowy': 0.0011781816145283593,
#  'LH sunny MV rainy': 0.0010047070209781715,
#  'LH sunny MV cloudy': 0.0010047070209781715,
#  'LH sunny MV foggy': 0.0010047070209781715,
#  'LH sunny MV sunny': 0.0010047070209781715,
#  'LH sunny MV snowy': 0.0010047070209781715,
#  'LH sunny CL rainy': 0.0009541102645260334,
#  'LH sunny CL cloudy': 0.0009541102645260334,
#  'LH sunny CL foggy': 0.0009541102645260334,
#  'LH sunny CL sunny': 0.0009541102645260334,
#  'LH sunny CL snowy': 0.0009541102645260334,
#  'LH sunny SV rainy': 0.0008673729677509395,
#  'LH sunny SV cloudy': 0.0008673729677509395,
#  'LH sunny SV foggy': 0.0008673729677509395,
#  'LH sunny SV sunny': 0.0008673729677509395,
#  'LH sunny SV snowy': 0.0008673729677509395,
#  'LH sunny CS rainy': 0.00034694918710037576,
#  'LH sunny CS cloudy': 0.00034694918710037576,
#  'LH sunny CS foggy': 0.00034694918710037576,
#  'LH sunny CS sunny': 0.00034694918710037576,
#  'LH sunny CS snowy': 0.00034694918710037576,
#  'LH sunny PG rainy': 0.00034333513306808016,
#  'LH sunny PG cloudy': 0.00034333513306808016,
#  'LH sunny PG foggy': 0.00034333513306808016,
#  'LH sunny PG sunny': 0.00034333513306808016,
#  'LH sunny PG snowy': 0.00034333513306808016,
#  'LH sunny AA rainy': 0.00033249297097119346,
#  'LH sunny AA cloudy': 0.00033249297097119346,
#  'LH sunny AA foggy': 0.00033249297097119346,
#  'LH sunny AA sunny': 0.00033249297097119346,
#  'LH sunny AA snowy': 0.00033249297097119346,
#  'LH sunny DR rainy': 0.00018793080967937023,
#  'LH sunny DR cloudy': 0.00018793080967937023,
#  'LH sunny DR foggy': 0.00018793080967937023,
#  'LH sunny DR sunny': 0.00018793080967937023,
#  'LH sunny DR snowy': 0.00018793080967937023,
#  'LH sunny SP rainy': 0.00018793080967937023,
#  'LH sunny SP cloudy': 0.00018793080967937023,
#  'LH sunny SP foggy': 0.00018793080967937023,
#  'LH sunny SP sunny': 0.00018793080967937023,
#  'LH sunny SP snowy': 0.00018793080967937023,
#  'LH sunny LN rainy': 0.00017708864758248346,
#  'LH sunny LN cloudy': 0.00017708864758248346,
#  'LH sunny LN foggy': 0.00017708864758248346,
#  'LH sunny LN sunny': 0.00017708864758248346,
#  'LH sunny LN snowy': 0.00017708864758248346,
#  'LH sunny KR rainy': 0.00015540432338871,
#  'LH sunny KR cloudy': 0.00015540432338871,
#  'LH sunny KR foggy': 0.00015540432338871,
#  'LH sunny KR sunny': 0.00015540432338871,
#  'LH sunny KR snowy': 0.00015540432338871,
#  'LH sunny DK rainy': 0.0001337199991949365,
#  'LH sunny DK cloudy': 0.0001337199991949365,
#  'LH sunny DK foggy': 0.0001337199991949365,
#  'LH sunny DK sunny': 0.0001337199991949365,
#  'LH sunny DK snowy': 0.0001337199991949365,
#  'LH sunny NH rainy': 0.0001337199991949365,
#  'LH sunny NH cloudy': 0.0001337199991949365,
#  'LH sunny NH foggy': 0.0001337199991949365,
#  'LH sunny NH sunny': 0.0001337199991949365,
#  'LH sunny NH snowy': 0.0001337199991949365,
#  'LH sunny LS rainy': 7.589513467820722e-05,
#  'LH sunny LS cloudy': 7.589513467820722e-05,
#  'LH sunny LS foggy': 7.589513467820722e-05,
#  'LH sunny LS sunny': 7.589513467820722e-05,
#  'LH sunny LS snowy': 7.589513467820722e-05,
#  'LH sunny KM rainy': 7.228108064591161e-05,
#  'LH sunny KM cloudy': 7.228108064591161e-05,
#  'LH sunny KM foggy': 7.228108064591161e-05,
#  'LH sunny KM sunny': 7.228108064591161e-05,
#  'LH sunny KM snowy': 7.228108064591161e-05,
#  'LH sunny AG rainy': 5.059675645213813e-05,
#  'LH sunny AG cloudy': 5.059675645213813e-05,
#  'LH sunny AG foggy': 5.059675645213813e-05,
#  'LH sunny AG sunny': 5.059675645213813e-05,
#  'LH sunny AG snowy': 5.059675645213813e-05,
#  'LH sunny RG rainy': 2.8912432258364648e-05,
#  'LH sunny RG cloudy': 2.8912432258364648e-05,
#  'LH sunny RG foggy': 2.8912432258364648e-05,
#  'LH sunny RG sunny': 2.8912432258364648e-05,
#  'LH sunny RG snowy': 2.8912432258364648e-05,
#  'LH sunny RK rainy': 3.614054032295581e-06,
#  'LH sunny RK cloudy': 3.614054032295581e-06,
#  'LH sunny RK foggy': 3.614054032295581e-06,
#  'LH sunny RK sunny': 3.614054032295581e-06,
#  'LH sunny RK snowy': 3.614054032295581e-06,
#  'LH sunny GR rainy': 0.0,
#  'LH sunny GR cloudy': 0.0,
#  'LH sunny GR foggy': 0.0,
#  'LH sunny GR sunny': 0.0,
#  'LH sunny GR snowy': 0.0,
#  'LH snowy LH rainy': 0.001492604315338075,
#  'LH snowy LH cloudy': 0.001492604315338075,
#  'LH snowy LH foggy': 0.001492604315338075,
#  'LH snowy LH sunny': 0.001492604315338075,
#  'LH snowy LH snowy': 0.001492604315338075,
#  'LH snowy VB rainy': 0.0011781816145283593,
#  'LH snowy VB cloudy': 0.0011781816145283593,
#  'LH snowy VB foggy': 0.0011781816145283593,
#  'LH snowy VB sunny': 0.0011781816145283593,
#  'LH snowy VB snowy': 0.0011781816145283593,
#  'LH snowy MV rainy': 0.0010047070209781715,
#  'LH snowy MV cloudy': 0.0010047070209781715,
#  'LH snowy MV foggy': 0.0010047070209781715,
#  'LH snowy MV sunny': 0.0010047070209781715,
#  'LH snowy MV snowy': 0.0010047070209781715,
#  'LH snowy CL rainy': 0.0009541102645260334,
#  'LH snowy CL cloudy': 0.0009541102645260334,
#  'LH snowy CL foggy': 0.0009541102645260334,
#  'LH snowy CL sunny': 0.0009541102645260334,
#  'LH snowy CL snowy': 0.0009541102645260334,
#  'LH snowy SV rainy': 0.0008673729677509395,
#  'LH snowy SV cloudy': 0.0008673729677509395,
#  'LH snowy SV foggy': 0.0008673729677509395,
#  'LH snowy SV sunny': 0.0008673729677509395,
#  'LH snowy SV snowy': 0.0008673729677509395,
#  'LH snowy CS rainy': 0.00034694918710037576,
#  'LH snowy CS cloudy': 0.00034694918710037576,
#  'LH snowy CS foggy': 0.00034694918710037576,
#  'LH snowy CS sunny': 0.00034694918710037576,
#  'LH snowy CS snowy': 0.00034694918710037576,
#  'LH snowy PG rainy': 0.00034333513306808016,
#  'LH snowy PG cloudy': 0.00034333513306808016,
#  'LH snowy PG foggy': 0.00034333513306808016,
#  'LH snowy PG sunny': 0.00034333513306808016,
#  'LH snowy PG snowy': 0.00034333513306808016,
#  'LH snowy AA rainy': 0.00033249297097119346,
#  'LH snowy AA cloudy': 0.00033249297097119346,
#  'LH snowy AA foggy': 0.00033249297097119346,
#  'LH snowy AA sunny': 0.00033249297097119346,
#  'LH snowy AA snowy': 0.00033249297097119346,
#  'LH snowy DR rainy': 0.00018793080967937023,
#  'LH snowy DR cloudy': 0.00018793080967937023,
#  'LH snowy DR foggy': 0.00018793080967937023,
#  'LH snowy DR sunny': 0.00018793080967937023,
#  'LH snowy DR snowy': 0.00018793080967937023,
#  'LH snowy SP rainy': 0.00018793080967937023,
#  'LH snowy SP cloudy': 0.00018793080967937023,
#  'LH snowy SP foggy': 0.00018793080967937023,
#  'LH snowy SP sunny': 0.00018793080967937023,
#  'LH snowy SP snowy': 0.00018793080967937023,
#  'LH snowy LN rainy': 0.00017708864758248346,
#  'LH snowy LN cloudy': 0.00017708864758248346,
#  'LH snowy LN foggy': 0.00017708864758248346,
#  'LH snowy LN sunny': 0.00017708864758248346,
#  'LH snowy LN snowy': 0.00017708864758248346,
#  'LH snowy KR rainy': 0.00015540432338871,
#  'LH snowy KR cloudy': 0.00015540432338871,
#  'LH snowy KR foggy': 0.00015540432338871,
#  'LH snowy KR sunny': 0.00015540432338871,
#  'LH snowy KR snowy': 0.00015540432338871,
#  'LH snowy DK rainy': 0.0001337199991949365,
#  'LH snowy DK cloudy': 0.0001337199991949365,
#  'LH snowy DK foggy': 0.0001337199991949365,
#  'LH snowy DK sunny': 0.0001337199991949365,
#  'LH snowy DK snowy': 0.0001337199991949365,
#  'LH snowy NH rainy': 0.0001337199991949365,
#  'LH snowy NH cloudy': 0.0001337199991949365,
#  'LH snowy NH foggy': 0.0001337199991949365,
#  'LH snowy NH sunny': 0.0001337199991949365,
#  'LH snowy NH snowy': 0.0001337199991949365,
#  'LH snowy LS rainy': 7.589513467820722e-05,
#  'LH snowy LS cloudy': 7.589513467820722e-05,
#  'LH snowy LS foggy': 7.589513467820722e-05,
#  'LH snowy LS sunny': 7.589513467820722e-05,
#  'LH snowy LS snowy': 7.589513467820722e-05,
#  'LH snowy KM rainy': 7.228108064591161e-05,
#  'LH snowy KM cloudy': 7.228108064591161e-05,
#  'LH snowy KM foggy': 7.228108064591161e-05,
#  'LH snowy KM sunny': 7.228108064591161e-05,
#  'LH snowy KM snowy': 7.228108064591161e-05,
#  'LH snowy AG rainy': 5.059675645213813e-05,
#  'LH snowy AG cloudy': 5.059675645213813e-05,
#  'LH snowy AG foggy': 5.059675645213813e-05,
#  'LH snowy AG sunny': 5.059675645213813e-05,
#  'LH snowy AG snowy': 5.059675645213813e-05,
#  'LH snowy RG rainy': 2.8912432258364648e-05,
#  'LH snowy RG cloudy': 2.8912432258364648e-05,
#  'LH snowy RG foggy': 2.8912432258364648e-05,
#  'LH snowy RG sunny': 2.8912432258364648e-05,
#  'LH snowy RG snowy': 2.8912432258364648e-05,
#  'LH snowy RK rainy': 3.614054032295581e-06,
#  'LH snowy RK cloudy': 3.614054032295581e-06,
#  'LH snowy RK foggy': 3.614054032295581e-06,
#  'LH snowy RK sunny': 3.614054032295581e-06,
#  'LH snowy RK snowy': 3.614054032295581e-06,
#  'LH snowy GR rainy': 0.0,
#  'LH snowy GR cloudy': 0.0,
#  'LH snowy GR foggy': 0.0,
#  'LH snowy GR sunny': 0.0,
#  'LH snowy GR snowy': 0.0,
#  'VB rainy LH rainy': 0.0011781816145283593,
#  'VB rainy LH cloudy': 0.0011781816145283593,
#  'VB rainy LH foggy': 0.0011781816145283593,
#  'VB rainy LH sunny': 0.0011781816145283593,
#  'VB rainy LH snowy': 0.0011781816145283593,
#  'VB rainy VB rainy': 0.0009299932356809812,
#  'VB rainy VB cloudy': 0.0009299932356809812,
#  'VB rainy VB foggy': 0.0009299932356809812,
#  'VB rainy VB sunny': 0.0009299932356809812,
#  'VB rainy VB snowy': 0.0009299932356809812,
#  'VB rainy MV rainy': 0.0007930617163169103,
#  'VB rainy MV cloudy': 0.0007930617163169103,
#  'VB rainy MV foggy': 0.0007930617163169103,
#  'VB rainy MV sunny': 0.0007930617163169103,
#  'VB rainy MV snowy': 0.0007930617163169103,
#  'VB rainy CL rainy': 0.0007531233565023895,
#  'VB rainy CL cloudy': 0.0007531233565023895,
#  'VB rainy CL foggy': 0.0007531233565023895,
#  'VB rainy CL sunny': 0.0007531233565023895,
#  'VB rainy CL snowy': 0.0007531233565023895,
#  'VB rainy SV rainy': 0.0006846575968203542,
#  'VB rainy SV cloudy': 0.0006846575968203542,
#  'VB rainy SV foggy': 0.0006846575968203542,
#  'VB rainy SV sunny': 0.0006846575968203542,
#  'VB rainy SV snowy': 0.0006846575968203542,
#  'VB rainy CS rainy': 0.0002738630387281417,
#  'VB rainy CS cloudy': 0.0002738630387281417,
#  'VB rainy CS foggy': 0.0002738630387281417,
#  'VB rainy CS sunny': 0.0002738630387281417,
#  'VB rainy CS snowy': 0.0002738630387281417,
#  'VB rainy PG rainy': 0.00027101029874139016,
#  'VB rainy PG cloudy': 0.00027101029874139016,
#  'VB rainy PG foggy': 0.00027101029874139016,
#  'VB rainy PG sunny': 0.00027101029874139016,
#  'VB rainy PG snowy': 0.00027101029874139016,
#  'VB rainy AA rainy': 0.00026245207878113574,
#  'VB rainy AA cloudy': 0.00026245207878113574,
#  'VB rainy AA foggy': 0.00026245207878113574,
#  'VB rainy AA sunny': 0.00026245207878113574,
#  'VB rainy AA snowy': 0.00026245207878113574,
#  'VB rainy DR rainy': 0.00014834247931107676,
#  'VB rainy DR cloudy': 0.00014834247931107676,
#  'VB rainy DR foggy': 0.00014834247931107676,
#  'VB rainy DR sunny': 0.00014834247931107676,
#  'VB rainy DR snowy': 0.00014834247931107676,
#  'VB rainy SP rainy': 0.00014834247931107676,
#  'VB rainy SP cloudy': 0.00014834247931107676,
#  'VB rainy SP foggy': 0.00014834247931107676,
#  'VB rainy SP sunny': 0.00014834247931107676,
#  'VB rainy SP snowy': 0.00014834247931107676,
#  'VB rainy LN rainy': 0.0001397842593508223,
#  'VB rainy LN cloudy': 0.0001397842593508223,
#  'VB rainy LN foggy': 0.0001397842593508223,
#  'VB rainy LN sunny': 0.0001397842593508223,
#  'VB rainy LN snowy': 0.0001397842593508223,
#  'VB rainy KR rainy': 0.00012266781943031345,
#  'VB rainy KR cloudy': 0.00012266781943031345,
#  'VB rainy KR foggy': 0.00012266781943031345,
#  'VB rainy KR sunny': 0.00012266781943031345,
#  'VB rainy KR snowy': 0.00012266781943031345,
#  'VB rainy DK rainy': 0.0001055513795098046,
#  'VB rainy DK cloudy': 0.0001055513795098046,
#  'VB rainy DK foggy': 0.0001055513795098046,
#  'VB rainy DK sunny': 0.0001055513795098046,
#  'VB rainy DK snowy': 0.0001055513795098046,
#  'VB rainy NH rainy': 0.0001055513795098046,
#  'VB rainy NH cloudy': 0.0001055513795098046,
#  'VB rainy NH foggy': 0.0001055513795098046,
#  'VB rainy NH sunny': 0.0001055513795098046,
#  'VB rainy NH snowy': 0.0001055513795098046,
#  'VB rainy LS rainy': 5.9907539721780995e-05,
#  'VB rainy LS cloudy': 5.9907539721780995e-05,
#  'VB rainy LS foggy': 5.9907539721780995e-05,
#  'VB rainy LS sunny': 5.9907539721780995e-05,
#  'VB rainy LS snowy': 5.9907539721780995e-05,
#  'VB rainy KM rainy': 5.705479973502951e-05,
#  'VB rainy KM cloudy': 5.705479973502951e-05,
#  'VB rainy KM foggy': 5.705479973502951e-05,
#  'VB rainy KM sunny': 5.705479973502951e-05,
#  'VB rainy KM snowy': 5.705479973502951e-05,
#  'VB rainy AG rainy': 3.993835981452066e-05,
#  'VB rainy AG cloudy': 3.993835981452066e-05,
#  'VB rainy AG foggy': 3.993835981452066e-05,
#  'VB rainy AG sunny': 3.993835981452066e-05,
#  'VB rainy AG snowy': 3.993835981452066e-05,
#  'VB rainy RG rainy': 2.2821919894011805e-05,
#  'VB rainy RG cloudy': 2.2821919894011805e-05,
#  'VB rainy RG foggy': 2.2821919894011805e-05,
#  'VB rainy RG sunny': 2.2821919894011805e-05,
#  'VB rainy RG snowy': 2.2821919894011805e-05,
#  'VB rainy RK rainy': 2.8527399867514756e-06,
#  'VB rainy RK cloudy': 2.8527399867514756e-06,
#  'VB rainy RK foggy': 2.8527399867514756e-06,
#  'VB rainy RK sunny': 2.8527399867514756e-06,
#  'VB rainy RK snowy': 2.8527399867514756e-06,
#  'VB rainy GR rainy': 0.0,
#  'VB rainy GR cloudy': 0.0,
#  'VB rainy GR foggy': 0.0,
#  'VB rainy GR sunny': 0.0,
#  'VB rainy GR snowy': 0.0,
#  'VB cloudy LH rainy': 0.0011781816145283593,
#  'VB cloudy LH cloudy': 0.0011781816145283593,
#  'VB cloudy LH foggy': 0.0011781816145283593,
#  'VB cloudy LH sunny': 0.0011781816145283593,
#  'VB cloudy LH snowy': 0.0011781816145283593,
#  'VB cloudy VB rainy': 0.0009299932356809812,
#  'VB cloudy VB cloudy': 0.0009299932356809812,
#  'VB cloudy VB foggy': 0.0009299932356809812,
#  'VB cloudy VB sunny': 0.0009299932356809812,
#  'VB cloudy VB snowy': 0.0009299932356809812,
#  'VB cloudy MV rainy': 0.0007930617163169103,
#  'VB cloudy MV cloudy': 0.0007930617163169103,
#  'VB cloudy MV foggy': 0.0007930617163169103,
#  'VB cloudy MV sunny': 0.0007930617163169103,
#  'VB cloudy MV snowy': 0.0007930617163169103,
#  'VB cloudy CL rainy': 0.0007531233565023895,
#  'VB cloudy CL cloudy': 0.0007531233565023895,
#  'VB cloudy CL foggy': 0.0007531233565023895,
#  'VB cloudy CL sunny': 0.0007531233565023895,
#  'VB cloudy CL snowy': 0.0007531233565023895,
#  'VB cloudy SV rainy': 0.0006846575968203542,
#  'VB cloudy SV cloudy': 0.0006846575968203542,
#  'VB cloudy SV foggy': 0.0006846575968203542,
#  'VB cloudy SV sunny': 0.0006846575968203542,
#  'VB cloudy SV snowy': 0.0006846575968203542,
#  'VB cloudy CS rainy': 0.0002738630387281417,
#  'VB cloudy CS cloudy': 0.0002738630387281417,
#  'VB cloudy CS foggy': 0.0002738630387281417,
#  'VB cloudy CS sunny': 0.0002738630387281417,
#  'VB cloudy CS snowy': 0.0002738630387281417,
#  'VB cloudy PG rainy': 0.00027101029874139016,
#  'VB cloudy PG cloudy': 0.00027101029874139016,
#  'VB cloudy PG foggy': 0.00027101029874139016,
#  'VB cloudy PG sunny': 0.00027101029874139016,
#  'VB cloudy PG snowy': 0.00027101029874139016,
#  'VB cloudy AA rainy': 0.00026245207878113574,
#  'VB cloudy AA cloudy': 0.00026245207878113574,
#  'VB cloudy AA foggy': 0.00026245207878113574,
#  'VB cloudy AA sunny': 0.00026245207878113574,
#  'VB cloudy AA snowy': 0.00026245207878113574,
#  'VB cloudy DR rainy': 0.00014834247931107676,
#  'VB cloudy DR cloudy': 0.00014834247931107676,
#  'VB cloudy DR foggy': 0.00014834247931107676,
#  'VB cloudy DR sunny': 0.00014834247931107676,
#  'VB cloudy DR snowy': 0.00014834247931107676,
#  'VB cloudy SP rainy': 0.00014834247931107676,
#  'VB cloudy SP cloudy': 0.00014834247931107676,
#  'VB cloudy SP foggy': 0.00014834247931107676,
#  'VB cloudy SP sunny': 0.00014834247931107676,
#  'VB cloudy SP snowy': 0.00014834247931107676,
#  'VB cloudy LN rainy': 0.0001397842593508223,
#  'VB cloudy LN cloudy': 0.0001397842593508223,
#  'VB cloudy LN foggy': 0.0001397842593508223,
#  'VB cloudy LN sunny': 0.0001397842593508223,
#  'VB cloudy LN snowy': 0.0001397842593508223,
#  'VB cloudy KR rainy': 0.00012266781943031345,
#  'VB cloudy KR cloudy': 0.00012266781943031345,
#  'VB cloudy KR foggy': 0.00012266781943031345,
#  'VB cloudy KR sunny': 0.00012266781943031345,
#  'VB cloudy KR snowy': 0.00012266781943031345,
#  'VB cloudy DK rainy': 0.0001055513795098046,
#  'VB cloudy DK cloudy': 0.0001055513795098046,
#  'VB cloudy DK foggy': 0.0001055513795098046,
#  'VB cloudy DK sunny': 0.0001055513795098046,
#  'VB cloudy DK snowy': 0.0001055513795098046,
#  'VB cloudy NH rainy': 0.0001055513795098046,
#  'VB cloudy NH cloudy': 0.0001055513795098046,
#  'VB cloudy NH foggy': 0.0001055513795098046,
#  'VB cloudy NH sunny': 0.0001055513795098046,
#  'VB cloudy NH snowy': 0.0001055513795098046,
#  'VB cloudy LS rainy': 5.9907539721780995e-05,
#  'VB cloudy LS cloudy': 5.9907539721780995e-05,
#  'VB cloudy LS foggy': 5.9907539721780995e-05,
#  'VB cloudy LS sunny': 5.9907539721780995e-05,
#  'VB cloudy LS snowy': 5.9907539721780995e-05,
#  'VB cloudy KM rainy': 5.705479973502951e-05,
#  'VB cloudy KM cloudy': 5.705479973502951e-05,
#  'VB cloudy KM foggy': 5.705479973502951e-05,
#  'VB cloudy KM sunny': 5.705479973502951e-05,
#  'VB cloudy KM snowy': 5.705479973502951e-05,
#  'VB cloudy AG rainy': 3.993835981452066e-05,
#  'VB cloudy AG cloudy': 3.993835981452066e-05,
#  'VB cloudy AG foggy': 3.993835981452066e-05,
#  'VB cloudy AG sunny': 3.993835981452066e-05,
#  'VB cloudy AG snowy': 3.993835981452066e-05,
#  'VB cloudy RG rainy': 2.2821919894011805e-05,
#  'VB cloudy RG cloudy': 2.2821919894011805e-05,
#  'VB cloudy RG foggy': 2.2821919894011805e-05,
#  'VB cloudy RG sunny': 2.2821919894011805e-05,
#  'VB cloudy RG snowy': 2.2821919894011805e-05,
#  'VB cloudy RK rainy': 2.8527399867514756e-06,
#  'VB cloudy RK cloudy': 2.8527399867514756e-06,
#  'VB cloudy RK foggy': 2.8527399867514756e-06,
#  'VB cloudy RK sunny': 2.8527399867514756e-06,
#  'VB cloudy RK snowy': 2.8527399867514756e-06,
#  'VB cloudy GR rainy': 0.0,
#  'VB cloudy GR cloudy': 0.0,
#  'VB cloudy GR foggy': 0.0,
#  'VB cloudy GR sunny': 0.0,
#  'VB cloudy GR snowy': 0.0,
#  'VB foggy LH rainy': 0.0011781816145283593,
#  'VB foggy LH cloudy': 0.0011781816145283593,
#  'VB foggy LH foggy': 0.0011781816145283593,
#  'VB foggy LH sunny': 0.0011781816145283593,
#  'VB foggy LH snowy': 0.0011781816145283593,
#  'VB foggy VB rainy': 0.0009299932356809812,
#  'VB foggy VB cloudy': 0.0009299932356809812,
#  'VB foggy VB foggy': 0.0009299932356809812,
#  'VB foggy VB sunny': 0.0009299932356809812,
#  'VB foggy VB snowy': 0.0009299932356809812,
#  'VB foggy MV rainy': 0.0007930617163169103,
#  'VB foggy MV cloudy': 0.0007930617163169103,
#  'VB foggy MV foggy': 0.0007930617163169103,
#  'VB foggy MV sunny': 0.0007930617163169103,
#  'VB foggy MV snowy': 0.0007930617163169103,
#  'VB foggy CL rainy': 0.0007531233565023895,
#  'VB foggy CL cloudy': 0.0007531233565023895,
#  'VB foggy CL foggy': 0.0007531233565023895,
#  'VB foggy CL sunny': 0.0007531233565023895,
#  'VB foggy CL snowy': 0.0007531233565023895,
#  'VB foggy SV rainy': 0.0006846575968203542,
#  'VB foggy SV cloudy': 0.0006846575968203542,
#  'VB foggy SV foggy': 0.0006846575968203542,
#  'VB foggy SV sunny': 0.0006846575968203542,
#  'VB foggy SV snowy': 0.0006846575968203542,
#  'VB foggy CS rainy': 0.0002738630387281417,
#  'VB foggy CS cloudy': 0.0002738630387281417,
#  'VB foggy CS foggy': 0.0002738630387281417,
#  'VB foggy CS sunny': 0.0002738630387281417,
#  'VB foggy CS snowy': 0.0002738630387281417,
#  'VB foggy PG rainy': 0.00027101029874139016,
#  'VB foggy PG cloudy': 0.00027101029874139016,
#  'VB foggy PG foggy': 0.00027101029874139016,
#  'VB foggy PG sunny': 0.00027101029874139016,
#  'VB foggy PG snowy': 0.00027101029874139016,
#  'VB foggy AA rainy': 0.00026245207878113574,
#  'VB foggy AA cloudy': 0.00026245207878113574,
#  'VB foggy AA foggy': 0.00026245207878113574,
#  'VB foggy AA sunny': 0.00026245207878113574,
#  'VB foggy AA snowy': 0.00026245207878113574,
#  'VB foggy DR rainy': 0.00014834247931107676,
#  'VB foggy DR cloudy': 0.00014834247931107676,
#  'VB foggy DR foggy': 0.00014834247931107676,
#  'VB foggy DR sunny': 0.00014834247931107676,
#  'VB foggy DR snowy': 0.00014834247931107676,
#  'VB foggy SP rainy': 0.00014834247931107676,
#  'VB foggy SP cloudy': 0.00014834247931107676,
#  'VB foggy SP foggy': 0.00014834247931107676,
#  'VB foggy SP sunny': 0.00014834247931107676,
#  'VB foggy SP snowy': 0.00014834247931107676,
#  'VB foggy LN rainy': 0.0001397842593508223,
#  'VB foggy LN cloudy': 0.0001397842593508223,
#  'VB foggy LN foggy': 0.0001397842593508223,
#  'VB foggy LN sunny': 0.0001397842593508223,
#  'VB foggy LN snowy': 0.0001397842593508223,
#  'VB foggy KR rainy': 0.00012266781943031345,
#  'VB foggy KR cloudy': 0.00012266781943031345,
#  'VB foggy KR foggy': 0.00012266781943031345,
#  'VB foggy KR sunny': 0.00012266781943031345,
#  'VB foggy KR snowy': 0.00012266781943031345,
#  'VB foggy DK rainy': 0.0001055513795098046,
#  'VB foggy DK cloudy': 0.0001055513795098046,
#  'VB foggy DK foggy': 0.0001055513795098046,
#  'VB foggy DK sunny': 0.0001055513795098046,
#  'VB foggy DK snowy': 0.0001055513795098046,
#  'VB foggy NH rainy': 0.0001055513795098046,
#  'VB foggy NH cloudy': 0.0001055513795098046,
#  'VB foggy NH foggy': 0.0001055513795098046,
#  'VB foggy NH sunny': 0.0001055513795098046,
#  'VB foggy NH snowy': 0.0001055513795098046,
#  'VB foggy LS rainy': 5.9907539721780995e-05,
#  'VB foggy LS cloudy': 5.9907539721780995e-05,
#  'VB foggy LS foggy': 5.9907539721780995e-05,
#  'VB foggy LS sunny': 5.9907539721780995e-05,
#  'VB foggy LS snowy': 5.9907539721780995e-05,
#  'VB foggy KM rainy': 5.705479973502951e-05,
#  'VB foggy KM cloudy': 5.705479973502951e-05,
#  'VB foggy KM foggy': 5.705479973502951e-05,
#  'VB foggy KM sunny': 5.705479973502951e-05,
#  'VB foggy KM snowy': 5.705479973502951e-05,
#  'VB foggy AG rainy': 3.993835981452066e-05,
#  'VB foggy AG cloudy': 3.993835981452066e-05,
#  'VB foggy AG foggy': 3.993835981452066e-05,
#  'VB foggy AG sunny': 3.993835981452066e-05,
#  'VB foggy AG snowy': 3.993835981452066e-05,
#  'VB foggy RG rainy': 2.2821919894011805e-05,
#  'VB foggy RG cloudy': 2.2821919894011805e-05,
#  'VB foggy RG foggy': 2.2821919894011805e-05,
#  'VB foggy RG sunny': 2.2821919894011805e-05,
#  'VB foggy RG snowy': 2.2821919894011805e-05,
#  'VB foggy RK rainy': 2.8527399867514756e-06,
#  'VB foggy RK cloudy': 2.8527399867514756e-06,
#  'VB foggy RK foggy': 2.8527399867514756e-06,
#  'VB foggy RK sunny': 2.8527399867514756e-06,
#  'VB foggy RK snowy': 2.8527399867514756e-06,
#  'VB foggy GR rainy': 0.0,
#  'VB foggy GR cloudy': 0.0,
#  'VB foggy GR foggy': 0.0,
#  'VB foggy GR sunny': 0.0,
#  'VB foggy GR snowy': 0.0,
#  'VB sunny LH rainy': 0.0011781816145283593,
#  'VB sunny LH cloudy': 0.0011781816145283593,
#  'VB sunny LH foggy': 0.0011781816145283593,
#  'VB sunny LH sunny': 0.0011781816145283593,
#  'VB sunny LH snowy': 0.0011781816145283593,
#  'VB sunny VB rainy': 0.0009299932356809812,
#  'VB sunny VB cloudy': 0.0009299932356809812,
#  'VB sunny VB foggy': 0.0009299932356809812,
#  'VB sunny VB sunny': 0.0009299932356809812,
#  'VB sunny VB snowy': 0.0009299932356809812,
#  'VB sunny MV rainy': 0.0007930617163169103,
#  'VB sunny MV cloudy': 0.0007930617163169103,
#  'VB sunny MV foggy': 0.0007930617163169103,
#  'VB sunny MV sunny': 0.0007930617163169103,
#  'VB sunny MV snowy': 0.0007930617163169103,
#  'VB sunny CL rainy': 0.0007531233565023895,
#  'VB sunny CL cloudy': 0.0007531233565023895,
#  'VB sunny CL foggy': 0.0007531233565023895,
#  'VB sunny CL sunny': 0.0007531233565023895,
#  'VB sunny CL snowy': 0.0007531233565023895,
#  'VB sunny SV rainy': 0.0006846575968203542,
#  'VB sunny SV cloudy': 0.0006846575968203542,
#  'VB sunny SV foggy': 0.0006846575968203542,
#  'VB sunny SV sunny': 0.0006846575968203542,
#  'VB sunny SV snowy': 0.0006846575968203542,
#  'VB sunny CS rainy': 0.0002738630387281417,
#  'VB sunny CS cloudy': 0.0002738630387281417,
#  'VB sunny CS foggy': 0.0002738630387281417,
#  'VB sunny CS sunny': 0.0002738630387281417,
#  'VB sunny CS snowy': 0.0002738630387281417,
#  'VB sunny PG rainy': 0.00027101029874139016,
#  'VB sunny PG cloudy': 0.00027101029874139016,
#  'VB sunny PG foggy': 0.00027101029874139016,
#  'VB sunny PG sunny': 0.00027101029874139016,
#  'VB sunny PG snowy': 0.00027101029874139016,
#  'VB sunny AA rainy': 0.00026245207878113574,
#  'VB sunny AA cloudy': 0.00026245207878113574,
#  'VB sunny AA foggy': 0.00026245207878113574,
#  'VB sunny AA sunny': 0.00026245207878113574,
#  'VB sunny AA snowy': 0.00026245207878113574,
#  'VB sunny DR rainy': 0.00014834247931107676,
#  'VB sunny DR cloudy': 0.00014834247931107676,
#  'VB sunny DR foggy': 0.00014834247931107676,
#  'VB sunny DR sunny': 0.00014834247931107676,
#  'VB sunny DR snowy': 0.00014834247931107676,
#  'VB sunny SP rainy': 0.00014834247931107676,
#  'VB sunny SP cloudy': 0.00014834247931107676,
#  'VB sunny SP foggy': 0.00014834247931107676,
#  'VB sunny SP sunny': 0.00014834247931107676,
#  'VB sunny SP snowy': 0.00014834247931107676,
#  'VB sunny LN rainy': 0.0001397842593508223,
#  'VB sunny LN cloudy': 0.0001397842593508223,
#  'VB sunny LN foggy': 0.0001397842593508223,
#  'VB sunny LN sunny': 0.0001397842593508223,
#  'VB sunny LN snowy': 0.0001397842593508223,
#  'VB sunny KR rainy': 0.00012266781943031345,
#  'VB sunny KR cloudy': 0.00012266781943031345,
#  'VB sunny KR foggy': 0.00012266781943031345,
#  'VB sunny KR sunny': 0.00012266781943031345,
#  'VB sunny KR snowy': 0.00012266781943031345,
#  'VB sunny DK rainy': 0.0001055513795098046,
#  'VB sunny DK cloudy': 0.0001055513795098046,
#  'VB sunny DK foggy': 0.0001055513795098046,
#  'VB sunny DK sunny': 0.0001055513795098046,
#  'VB sunny DK snowy': 0.0001055513795098046,
#  'VB sunny NH rainy': 0.0001055513795098046,
#  'VB sunny NH cloudy': 0.0001055513795098046,
#  'VB sunny NH foggy': 0.0001055513795098046,
#  'VB sunny NH sunny': 0.0001055513795098046,
#  'VB sunny NH snowy': 0.0001055513795098046,
#  'VB sunny LS rainy': 5.9907539721780995e-05,
#  'VB sunny LS cloudy': 5.9907539721780995e-05,
#  'VB sunny LS foggy': 5.9907539721780995e-05,
#  'VB sunny LS sunny': 5.9907539721780995e-05,
#  'VB sunny LS snowy': 5.9907539721780995e-05,
#  'VB sunny KM rainy': 5.705479973502951e-05,
#  'VB sunny KM cloudy': 5.705479973502951e-05,
#  'VB sunny KM foggy': 5.705479973502951e-05,
#  'VB sunny KM sunny': 5.705479973502951e-05,
#  'VB sunny KM snowy': 5.705479973502951e-05,
#  'VB sunny AG rainy': 3.993835981452066e-05,
#  'VB sunny AG cloudy': 3.993835981452066e-05,
#  'VB sunny AG foggy': 3.993835981452066e-05,
#  'VB sunny AG sunny': 3.993835981452066e-05,
#  'VB sunny AG snowy': 3.993835981452066e-05,
#  'VB sunny RG rainy': 2.2821919894011805e-05,
#  'VB sunny RG cloudy': 2.2821919894011805e-05,
#  'VB sunny RG foggy': 2.2821919894011805e-05,
#  'VB sunny RG sunny': 2.2821919894011805e-05,
#  'VB sunny RG snowy': 2.2821919894011805e-05,
#  'VB sunny RK rainy': 2.8527399867514756e-06,
#  'VB sunny RK cloudy': 2.8527399867514756e-06,
#  'VB sunny RK foggy': 2.8527399867514756e-06,
#  'VB sunny RK sunny': 2.8527399867514756e-06,
#  'VB sunny RK snowy': 2.8527399867514756e-06,
#  'VB sunny GR rainy': 0.0,
#  'VB sunny GR cloudy': 0.0,
#  'VB sunny GR foggy': 0.0,
#  'VB sunny GR sunny': 0.0,
#  'VB sunny GR snowy': 0.0,
#  'VB snowy LH rainy': 0.0011781816145283593,
#  'VB snowy LH cloudy': 0.0011781816145283593,
#  'VB snowy LH foggy': 0.0011781816145283593,
#  'VB snowy LH sunny': 0.0011781816145283593,
#  'VB snowy LH snowy': 0.0011781816145283593,
#  'VB snowy VB rainy': 0.0009299932356809812,
#  'VB snowy VB cloudy': 0.0009299932356809812,
#  'VB snowy VB foggy': 0.0009299932356809812,
#  'VB snowy VB sunny': 0.0009299932356809812,
#  'VB snowy VB snowy': 0.0009299932356809812,
#  'VB snowy MV rainy': 0.0007930617163169103,
#  'VB snowy MV cloudy': 0.0007930617163169103,
#  'VB snowy MV foggy': 0.0007930617163169103,
#  'VB snowy MV sunny': 0.0007930617163169103,
#  'VB snowy MV snowy': 0.0007930617163169103,
#  'VB snowy CL rainy': 0.0007531233565023895,
#  'VB snowy CL cloudy': 0.0007531233565023895,
#  'VB snowy CL foggy': 0.0007531233565023895,
#  'VB snowy CL sunny': 0.0007531233565023895,
#  'VB snowy CL snowy': 0.0007531233565023895,
#  'VB snowy SV rainy': 0.0006846575968203542,
#  'VB snowy SV cloudy': 0.0006846575968203542,
#  'VB snowy SV foggy': 0.0006846575968203542,
#  'VB snowy SV sunny': 0.0006846575968203542,
#  'VB snowy SV snowy': 0.0006846575968203542,
#  'VB snowy CS rainy': 0.0002738630387281417,
#  'VB snowy CS cloudy': 0.0002738630387281417,
#  'VB snowy CS foggy': 0.0002738630387281417,
#  'VB snowy CS sunny': 0.0002738630387281417,
#  'VB snowy CS snowy': 0.0002738630387281417,
#  'VB snowy PG rainy': 0.00027101029874139016,
#  'VB snowy PG cloudy': 0.00027101029874139016,
#  'VB snowy PG foggy': 0.00027101029874139016,
#  'VB snowy PG sunny': 0.00027101029874139016,
#  'VB snowy PG snowy': 0.00027101029874139016,
#  'VB snowy AA rainy': 0.00026245207878113574,
#  'VB snowy AA cloudy': 0.00026245207878113574,
#  'VB snowy AA foggy': 0.00026245207878113574,
#  'VB snowy AA sunny': 0.00026245207878113574,
#  'VB snowy AA snowy': 0.00026245207878113574,
#  'VB snowy DR rainy': 0.00014834247931107676,
#  'VB snowy DR cloudy': 0.00014834247931107676,
#  'VB snowy DR foggy': 0.00014834247931107676,
#  'VB snowy DR sunny': 0.00014834247931107676,
#  'VB snowy DR snowy': 0.00014834247931107676,
#  'VB snowy SP rainy': 0.00014834247931107676,
#  'VB snowy SP cloudy': 0.00014834247931107676,
#  'VB snowy SP foggy': 0.00014834247931107676,
#  'VB snowy SP sunny': 0.00014834247931107676,
#  'VB snowy SP snowy': 0.00014834247931107676,
#  'VB snowy LN rainy': 0.0001397842593508223,
#  'VB snowy LN cloudy': 0.0001397842593508223,
#  'VB snowy LN foggy': 0.0001397842593508223,
#  'VB snowy LN sunny': 0.0001397842593508223,
#  'VB snowy LN snowy': 0.0001397842593508223,
#  'VB snowy KR rainy': 0.00012266781943031345,
#  'VB snowy KR cloudy': 0.00012266781943031345,
#  'VB snowy KR foggy': 0.00012266781943031345,
#  'VB snowy KR sunny': 0.00012266781943031345,
#  'VB snowy KR snowy': 0.00012266781943031345,
#  'VB snowy DK rainy': 0.0001055513795098046,
#  'VB snowy DK cloudy': 0.0001055513795098046,
#  'VB snowy DK foggy': 0.0001055513795098046,
#  'VB snowy DK sunny': 0.0001055513795098046,
#  'VB snowy DK snowy': 0.0001055513795098046,
#  'VB snowy NH rainy': 0.0001055513795098046,
#  'VB snowy NH cloudy': 0.0001055513795098046,
#  'VB snowy NH foggy': 0.0001055513795098046,
#  'VB snowy NH sunny': 0.0001055513795098046,
#  'VB snowy NH snowy': 0.0001055513795098046,
#  'VB snowy LS rainy': 5.9907539721780995e-05,
#  'VB snowy LS cloudy': 5.9907539721780995e-05,
#  'VB snowy LS foggy': 5.9907539721780995e-05,
#  'VB snowy LS sunny': 5.9907539721780995e-05,
#  'VB snowy LS snowy': 5.9907539721780995e-05,
#  'VB snowy KM rainy': 5.705479973502951e-05,
#  'VB snowy KM cloudy': 5.705479973502951e-05,
#  'VB snowy KM foggy': 5.705479973502951e-05,
#  'VB snowy KM sunny': 5.705479973502951e-05,
#  'VB snowy KM snowy': 5.705479973502951e-05,
#  'VB snowy AG rainy': 3.993835981452066e-05,
#  'VB snowy AG cloudy': 3.993835981452066e-05,
#  'VB snowy AG foggy': 3.993835981452066e-05,
#  'VB snowy AG sunny': 3.993835981452066e-05,
#  'VB snowy AG snowy': 3.993835981452066e-05,
#  'VB snowy RG rainy': 2.2821919894011805e-05,
#  'VB snowy RG cloudy': 2.2821919894011805e-05,
#  'VB snowy RG foggy': 2.2821919894011805e-05,
#  'VB snowy RG sunny': 2.2821919894011805e-05,
#  'VB snowy RG snowy': 2.2821919894011805e-05,
#  'VB snowy RK rainy': 2.8527399867514756e-06,
#  'VB snowy RK cloudy': 2.8527399867514756e-06,
#  'VB snowy RK foggy': 2.8527399867514756e-06,
#  'VB snowy RK sunny': 2.8527399867514756e-06,
#  'VB snowy RK snowy': 2.8527399867514756e-06,
#  'VB snowy GR rainy': 0.0,
#  'VB snowy GR cloudy': 0.0,
#  'VB snowy GR foggy': 0.0,
#  'VB snowy GR sunny': 0.0,
#  'VB snowy GR snowy': 0.0,
#  ...}

# %% [markdown]
# #### Mercede winning at least one of these two races on a rainy day.

# %%
def rainyweather(outcome):
    return ('LH rainy' in outcome or 'VB rainy' in outcome)

RainyCombo = such_that(rainyweather, CombinedWeather)
RainyCombo
# Out:
# {'LH rainy LH rainy': 0.011182140148432206,
#  'LH rainy LH cloudy': 0.011182140148432206,
#  'LH rainy LH foggy': 0.011182140148432206,
#  'LH rainy LH sunny': 0.011182140148432206,
#  'LH rainy LH snowy': 0.011182140148432206,
#  'LH rainy VB rainy': 0.008826580359295155,
#  'LH rainy VB cloudy': 0.008826580359295155,
#  'LH rainy VB foggy': 0.008826580359295155,
#  'LH rainy VB sunny': 0.008826580359295155,
#  'LH rainy VB snowy': 0.008826580359295155,
#  'LH rainy MV rainy': 0.007526961165288507,
#  'LH rainy MV cloudy': 0.007526961165288507,
#  'LH rainy MV foggy': 0.007526961165288507,
#  'LH rainy MV sunny': 0.007526961165288507,
#  'LH rainy MV snowy': 0.007526961165288507,
#  'LH rainy CL rainy': 0.007147905567036568,
#  'LH rainy CL cloudy': 0.007147905567036568,
#  'LH rainy CL foggy': 0.007147905567036568,
#  'LH rainy CL sunny': 0.007147905567036568,
#  'LH rainy CL snowy': 0.007147905567036568,
#  'LH rainy SV rainy': 0.0064980959700332444,
#  'LH rainy SV cloudy': 0.0064980959700332444,
#  'LH rainy SV foggy': 0.0064980959700332444,
#  'LH rainy SV sunny': 0.0064980959700332444,
#  'LH rainy SV snowy': 0.0064980959700332444,
#  'LH rainy CS rainy': 0.0025992383880132975,
#  'LH rainy CS cloudy': 0.0025992383880132975,
#  'LH rainy CS foggy': 0.0025992383880132975,
#  'LH rainy CS sunny': 0.0025992383880132975,
#  'LH rainy CS snowy': 0.0025992383880132975,
#  'LH rainy PG rainy': 0.0025721629881381588,
#  'LH rainy PG cloudy': 0.0025721629881381588,
#  'LH rainy PG foggy': 0.0025721629881381588,
#  'LH rainy PG sunny': 0.0025721629881381588,
#  'LH rainy PG snowy': 0.0025721629881381588,
#  'LH rainy AA rainy': 0.0024909367885127434,
#  'LH rainy AA cloudy': 0.0024909367885127434,
#  'LH rainy AA foggy': 0.0024909367885127434,
#  'LH rainy AA sunny': 0.0024909367885127434,
#  'LH rainy AA snowy': 0.0024909367885127434,
#  'LH rainy DR rainy': 0.0014079207935072029,
#  'LH rainy DR cloudy': 0.0014079207935072029,
#  'LH rainy DR foggy': 0.0014079207935072029,
#  'LH rainy DR sunny': 0.0014079207935072029,
#  'LH rainy DR snowy': 0.0014079207935072029,
#  'LH rainy SP rainy': 0.0014079207935072029,
#  'LH rainy SP cloudy': 0.0014079207935072029,
#  'LH rainy SP foggy': 0.0014079207935072029,
#  'LH rainy SP sunny': 0.0014079207935072029,
#  'LH rainy SP snowy': 0.0014079207935072029,
#  'LH rainy LN rainy': 0.001326694593881787,
#  'LH rainy LN cloudy': 0.001326694593881787,
#  'LH rainy LN foggy': 0.001326694593881787,
#  'LH rainy LN sunny': 0.001326694593881787,
#  'LH rainy LN snowy': 0.001326694593881787,
#  'LH rainy KR rainy': 0.0011642421946309563,
#  'LH rainy KR cloudy': 0.0011642421946309563,
#  'LH rainy KR foggy': 0.0011642421946309563,
#  'LH rainy KR sunny': 0.0011642421946309563,
#  'LH rainy KR snowy': 0.0011642421946309563,
#  'LH rainy DK rainy': 0.0010017897953801252,
#  'LH rainy DK cloudy': 0.0010017897953801252,
#  'LH rainy DK foggy': 0.0010017897953801252,
#  'LH rainy DK sunny': 0.0010017897953801252,
#  'LH rainy DK snowy': 0.0010017897953801252,
#  'LH rainy NH rainy': 0.0010017897953801252,
#  'LH rainy NH cloudy': 0.0010017897953801252,
#  'LH rainy NH foggy': 0.0010017897953801252,
#  'LH rainy NH sunny': 0.0010017897953801252,
#  'LH rainy NH snowy': 0.0010017897953801252,
#  'LH rainy LS rainy': 0.0005685833973779089,
#  'LH rainy LS cloudy': 0.0005685833973779089,
#  'LH rainy LS foggy': 0.0005685833973779089,
#  'LH rainy LS sunny': 0.0005685833973779089,
#  'LH rainy LS snowy': 0.0005685833973779089,
#  'LH rainy KM rainy': 0.0005415079975027703,
#  'LH rainy KM cloudy': 0.0005415079975027703,
#  'LH rainy KM foggy': 0.0005415079975027703,
#  'LH rainy KM sunny': 0.0005415079975027703,
#  'LH rainy KM snowy': 0.0005415079975027703,
#  'LH rainy AG rainy': 0.0003790555982519392,
#  'LH rainy AG cloudy': 0.0003790555982519392,
#  'LH rainy AG foggy': 0.0003790555982519392,
#  'LH rainy AG sunny': 0.0003790555982519392,
#  'LH rainy AG snowy': 0.0003790555982519392,
#  'LH rainy RG rainy': 0.00021660319900110813,
#  'LH rainy RG cloudy': 0.00021660319900110813,
#  'LH rainy RG foggy': 0.00021660319900110813,
#  'LH rainy RG sunny': 0.00021660319900110813,
#  'LH rainy RG snowy': 0.00021660319900110813,
#  'LH rainy RK rainy': 2.7075399875138516e-05,
#  'LH rainy RK cloudy': 2.7075399875138516e-05,
#  'LH rainy RK foggy': 2.7075399875138516e-05,
#  'LH rainy RK sunny': 2.7075399875138516e-05,
#  'LH rainy RK snowy': 2.7075399875138516e-05,
#  'LH rainy GR rainy': 0.0,
#  'LH rainy GR cloudy': 0.0,
#  'LH rainy GR foggy': 0.0,
#  'LH rainy GR sunny': 0.0,
#  'LH rainy GR snowy': 0.0,
#  'LH cloudy LH rainy': 0.011182140148432206,
#  'LH cloudy VB rainy': 0.008826580359295155,
#  'LH foggy LH rainy': 0.011182140148432206,
#  'LH foggy VB rainy': 0.008826580359295155,
#  'LH sunny LH rainy': 0.011182140148432206,
#  'LH sunny VB rainy': 0.008826580359295155,
#  'LH snowy LH rainy': 0.011182140148432206,
#  'LH snowy VB rainy': 0.008826580359295155,
#  'VB rainy LH rainy': 0.008826580359295155,
#  'VB rainy LH cloudy': 0.008826580359295155,
#  'VB rainy LH foggy': 0.008826580359295155,
#  'VB rainy LH sunny': 0.008826580359295155,
#  'VB rainy LH snowy': 0.008826580359295155,
#  'VB rainy VB rainy': 0.006967228080218453,
#  'VB rainy VB cloudy': 0.006967228080218453,
#  'VB rainy VB foggy': 0.006967228080218453,
#  'VB rainy VB sunny': 0.006967228080218453,
#  'VB rainy VB snowy': 0.006967228080218453,
#  'VB rainy MV rainy': 0.005941378546934754,
#  'VB rainy MV cloudy': 0.005941378546934754,
#  'VB rainy MV foggy': 0.005941378546934754,
#  'VB rainy MV sunny': 0.005941378546934754,
#  'VB rainy MV snowy': 0.005941378546934754,
#  'VB rainy CL rainy': 0.005642172433060342,
#  'VB rainy CL cloudy': 0.005642172433060342,
#  'VB rainy CL foggy': 0.005642172433060342,
#  'VB rainy CL sunny': 0.005642172433060342,
#  'VB rainy CL snowy': 0.005642172433060342,
#  'VB rainy SV rainy': 0.005129247666418493,
#  'VB rainy SV cloudy': 0.005129247666418493,
#  'VB rainy SV foggy': 0.005129247666418493,
#  'VB rainy SV sunny': 0.005129247666418493,
#  'VB rainy SV snowy': 0.005129247666418493,
#  'VB rainy CS rainy': 0.002051699066567397,
#  'VB rainy CS cloudy': 0.002051699066567397,
#  'VB rainy CS foggy': 0.002051699066567397,
#  'VB rainy CS sunny': 0.002051699066567397,
#  'VB rainy CS snowy': 0.002051699066567397,
#  'VB rainy PG rainy': 0.002030327201290653,
#  'VB rainy PG cloudy': 0.002030327201290653,
#  'VB rainy PG foggy': 0.002030327201290653,
#  'VB rainy PG sunny': 0.002030327201290653,
#  'VB rainy PG snowy': 0.002030327201290653,
#  'VB rainy AA rainy': 0.001966211605460422,
#  'VB rainy AA cloudy': 0.001966211605460422,
#  'VB rainy AA foggy': 0.001966211605460422,
#  'VB rainy AA sunny': 0.001966211605460422,
#  'VB rainy AA snowy': 0.001966211605460422,
#  'VB rainy DR rainy': 0.0011113369943906736,
#  'VB rainy DR cloudy': 0.0011113369943906736,
#  'VB rainy DR foggy': 0.0011113369943906736,
#  'VB rainy DR sunny': 0.0011113369943906736,
#  'VB rainy DR snowy': 0.0011113369943906736,
#  'VB rainy SP rainy': 0.0011113369943906736,
#  'VB rainy SP cloudy': 0.0011113369943906736,
#  'VB rainy SP foggy': 0.0011113369943906736,
#  'VB rainy SP sunny': 0.0011113369943906736,
#  'VB rainy SP snowy': 0.0011113369943906736,
#  'VB rainy LN rainy': 0.0010472213985604421,
#  'VB rainy LN cloudy': 0.0010472213985604421,
#  'VB rainy LN foggy': 0.0010472213985604421,
#  'VB rainy LN sunny': 0.0010472213985604421,
#  'VB rainy LN snowy': 0.0010472213985604421,
#  'VB rainy KR rainy': 0.00091899020689998,
#  'VB rainy KR cloudy': 0.00091899020689998,
#  'VB rainy KR foggy': 0.00091899020689998,
#  'VB rainy KR sunny': 0.00091899020689998,
#  'VB rainy KR snowy': 0.00091899020689998,
#  'VB rainy DK rainy': 0.0007907590152395176,
#  'VB rainy DK cloudy': 0.0007907590152395176,
#  'VB rainy DK foggy': 0.0007907590152395176,
#  'VB rainy DK sunny': 0.0007907590152395176,
#  'VB rainy DK snowy': 0.0007907590152395176,
#  'VB rainy NH rainy': 0.0007907590152395176,
#  'VB rainy NH cloudy': 0.0007907590152395176,
#  'VB rainy NH foggy': 0.0007907590152395176,
#  'VB rainy NH sunny': 0.0007907590152395176,
#  'VB rainy NH snowy': 0.0007907590152395176,
#  'VB rainy LS rainy': 0.00044880917081161815,
#  'VB rainy LS cloudy': 0.00044880917081161815,
#  'VB rainy LS foggy': 0.00044880917081161815,
#  'VB rainy LS sunny': 0.00044880917081161815,
#  'VB rainy LS snowy': 0.00044880917081161815,
#  'VB rainy KM rainy': 0.00042743730553487433,
#  'VB rainy KM cloudy': 0.00042743730553487433,
#  'VB rainy KM foggy': 0.00042743730553487433,
#  'VB rainy KM sunny': 0.00042743730553487433,
#  'VB rainy KM snowy': 0.00042743730553487433,
#  'VB rainy AG rainy': 0.0002992061138744121,
#  'VB rainy AG cloudy': 0.0002992061138744121,
#  'VB rainy AG foggy': 0.0002992061138744121,
#  'VB rainy AG sunny': 0.0002992061138744121,
#  'VB rainy AG snowy': 0.0002992061138744121,
#  'VB rainy RG rainy': 0.00017097492221394974,
#  'VB rainy RG cloudy': 0.00017097492221394974,
#  'VB rainy RG foggy': 0.00017097492221394974,
#  'VB rainy RG sunny': 0.00017097492221394974,
#  'VB rainy RG snowy': 0.00017097492221394974,
#  'VB rainy RK rainy': 2.1371865276743718e-05,
#  'VB rainy RK cloudy': 2.1371865276743718e-05,
#  'VB rainy RK foggy': 2.1371865276743718e-05,
#  'VB rainy RK sunny': 2.1371865276743718e-05,
#  'VB rainy RK snowy': 2.1371865276743718e-05,
#  'VB rainy GR rainy': 0.0,
#  'VB rainy GR cloudy': 0.0,
#  'VB rainy GR foggy': 0.0,
#  'VB rainy GR sunny': 0.0,
#  'VB rainy GR snowy': 0.0,
#  'VB cloudy LH rainy': 0.008826580359295155,
#  'VB cloudy VB rainy': 0.006967228080218453,
#  'VB foggy LH rainy': 0.008826580359295155,
#  'VB foggy VB rainy': 0.006967228080218453,
#  'VB sunny LH rainy': 0.008826580359295155,
#  'VB sunny VB rainy': 0.006967228080218453,
#  'VB snowy LH rainy': 0.008826580359295155,
#  'VB snowy VB rainy': 0.006967228080218453,
#  'MV rainy LH rainy': 0.007526961165288507,
#  'MV rainy VB rainy': 0.005941378546934754,
#  'MV cloudy LH rainy': 0.007526961165288507,
#  'MV cloudy VB rainy': 0.005941378546934754,
#  'MV foggy LH rainy': 0.007526961165288507,
#  'MV foggy VB rainy': 0.005941378546934754,
#  'MV sunny LH rainy': 0.007526961165288507,
#  'MV sunny VB rainy': 0.005941378546934754,
#  'MV snowy LH rainy': 0.007526961165288507,
#  'MV snowy VB rainy': 0.005941378546934754,
#  'CL rainy LH rainy': 0.007147905567036568,
#  'CL rainy VB rainy': 0.005642172433060342,
#  'CL cloudy LH rainy': 0.007147905567036568,
#  'CL cloudy VB rainy': 0.005642172433060342,
#  'CL foggy LH rainy': 0.007147905567036568,
#  'CL foggy VB rainy': 0.005642172433060342,
#  'CL sunny LH rainy': 0.007147905567036568,
#  'CL sunny VB rainy': 0.005642172433060342,
#  'CL snowy LH rainy': 0.007147905567036568,
#  'CL snowy VB rainy': 0.005642172433060342,
#  'SV rainy LH rainy': 0.0064980959700332444,
#  'SV rainy VB rainy': 0.005129247666418493,
#  'SV cloudy LH rainy': 0.0064980959700332444,
#  'SV cloudy VB rainy': 0.005129247666418493,
#  'SV foggy LH rainy': 0.0064980959700332444,
#  'SV foggy VB rainy': 0.005129247666418493,
#  'SV sunny LH rainy': 0.0064980959700332444,
#  'SV sunny VB rainy': 0.005129247666418493,
#  'SV snowy LH rainy': 0.0064980959700332444,
#  'SV snowy VB rainy': 0.005129247666418493,
#  'CS rainy LH rainy': 0.0025992383880132975,
#  'CS rainy VB rainy': 0.002051699066567397,
#  'CS cloudy LH rainy': 0.0025992383880132975,
#  'CS cloudy VB rainy': 0.002051699066567397,
#  'CS foggy LH rainy': 0.0025992383880132975,
#  'CS foggy VB rainy': 0.002051699066567397,
#  'CS sunny LH rainy': 0.0025992383880132975,
#  'CS sunny VB rainy': 0.002051699066567397,
#  'CS snowy LH rainy': 0.0025992383880132975,
#  'CS snowy VB rainy': 0.002051699066567397,
#  'PG rainy LH rainy': 0.0025721629881381588,
#  'PG rainy VB rainy': 0.002030327201290653,
#  'PG cloudy LH rainy': 0.0025721629881381588,
#  'PG cloudy VB rainy': 0.002030327201290653,
#  'PG foggy LH rainy': 0.0025721629881381588,
#  'PG foggy VB rainy': 0.002030327201290653,
#  'PG sunny LH rainy': 0.0025721629881381588,
#  'PG sunny VB rainy': 0.002030327201290653,
#  'PG snowy LH rainy': 0.0025721629881381588,
#  'PG snowy VB rainy': 0.002030327201290653,
#  'AA rainy LH rainy': 0.0024909367885127434,
#  'AA rainy VB rainy': 0.001966211605460422,
#  'AA cloudy LH rainy': 0.0024909367885127434,
#  'AA cloudy VB rainy': 0.001966211605460422,
#  'AA foggy LH rainy': 0.0024909367885127434,
#  'AA foggy VB rainy': 0.001966211605460422,
#  'AA sunny LH rainy': 0.0024909367885127434,
#  'AA sunny VB rainy': 0.001966211605460422,
#  'AA snowy LH rainy': 0.0024909367885127434,
#  'AA snowy VB rainy': 0.001966211605460422,
#  'DR rainy LH rainy': 0.0014079207935072029,
#  'DR rainy VB rainy': 0.0011113369943906736,
#  'DR cloudy LH rainy': 0.0014079207935072029,
#  'DR cloudy VB rainy': 0.0011113369943906736,
#  'DR foggy LH rainy': 0.0014079207935072029,
#  'DR foggy VB rainy': 0.0011113369943906736,
#  'DR sunny LH rainy': 0.0014079207935072029,
#  'DR sunny VB rainy': 0.0011113369943906736,
#  'DR snowy LH rainy': 0.0014079207935072029,
#  'DR snowy VB rainy': 0.0011113369943906736,
#  'SP rainy LH rainy': 0.0014079207935072029,
#  'SP rainy VB rainy': 0.0011113369943906736,
#  'SP cloudy LH rainy': 0.0014079207935072029,
#  'SP cloudy VB rainy': 0.0011113369943906736,
#  'SP foggy LH rainy': 0.0014079207935072029,
#  'SP foggy VB rainy': 0.0011113369943906736,
#  'SP sunny LH rainy': 0.0014079207935072029,
#  'SP sunny VB rainy': 0.0011113369943906736,
#  'SP snowy LH rainy': 0.0014079207935072029,
#  'SP snowy VB rainy': 0.0011113369943906736,
#  'LN rainy LH rainy': 0.001326694593881787,
#  'LN rainy VB rainy': 0.0010472213985604421,
#  'LN cloudy LH rainy': 0.001326694593881787,
#  'LN cloudy VB rainy': 0.0010472213985604421,
#  'LN foggy LH rainy': 0.001326694593881787,
#  'LN foggy VB rainy': 0.0010472213985604421,
#  'LN sunny LH rainy': 0.001326694593881787,
#  'LN sunny VB rainy': 0.0010472213985604421,
#  'LN snowy LH rainy': 0.001326694593881787,
#  'LN snowy VB rainy': 0.0010472213985604421,
#  'KR rainy LH rainy': 0.0011642421946309563,
#  'KR rainy VB rainy': 0.00091899020689998,
#  'KR cloudy LH rainy': 0.0011642421946309563,
#  'KR cloudy VB rainy': 0.00091899020689998,
#  'KR foggy LH rainy': 0.0011642421946309563,
#  'KR foggy VB rainy': 0.00091899020689998,
#  'KR sunny LH rainy': 0.0011642421946309563,
#  'KR sunny VB rainy': 0.00091899020689998,
#  'KR snowy LH rainy': 0.0011642421946309563,
#  'KR snowy VB rainy': 0.00091899020689998,
#  'DK rainy LH rainy': 0.0010017897953801252,
#  'DK rainy VB rainy': 0.0007907590152395176,
#  'DK cloudy LH rainy': 0.0010017897953801252,
#  'DK cloudy VB rainy': 0.0007907590152395176,
#  'DK foggy LH rainy': 0.0010017897953801252,
#  'DK foggy VB rainy': 0.0007907590152395176,
#  'DK sunny LH rainy': 0.0010017897953801252,
#  'DK sunny VB rainy': 0.0007907590152395176,
#  'DK snowy LH rainy': 0.0010017897953801252,
#  'DK snowy VB rainy': 0.0007907590152395176,
#  'NH rainy LH rainy': 0.0010017897953801252,
#  'NH rainy VB rainy': 0.0007907590152395176,
#  'NH cloudy LH rainy': 0.0010017897953801252,
#  'NH cloudy VB rainy': 0.0007907590152395176,
#  'NH foggy LH rainy': 0.0010017897953801252,
#  'NH foggy VB rainy': 0.0007907590152395176,
#  'NH sunny LH rainy': 0.0010017897953801252,
#  'NH sunny VB rainy': 0.0007907590152395176,
#  'NH snowy LH rainy': 0.0010017897953801252,
#  'NH snowy VB rainy': 0.0007907590152395176,
#  'LS rainy LH rainy': 0.0005685833973779089,
#  'LS rainy VB rainy': 0.00044880917081161815,
#  'LS cloudy LH rainy': 0.0005685833973779089,
#  'LS cloudy VB rainy': 0.00044880917081161815,
#  'LS foggy LH rainy': 0.0005685833973779089,
#  'LS foggy VB rainy': 0.00044880917081161815,
#  'LS sunny LH rainy': 0.0005685833973779089,
#  'LS sunny VB rainy': 0.00044880917081161815,
#  'LS snowy LH rainy': 0.0005685833973779089,
#  'LS snowy VB rainy': 0.00044880917081161815,
#  'KM rainy LH rainy': 0.0005415079975027703,
#  'KM rainy VB rainy': 0.00042743730553487433,
#  'KM cloudy LH rainy': 0.0005415079975027703,
#  'KM cloudy VB rainy': 0.00042743730553487433,
#  'KM foggy LH rainy': 0.0005415079975027703,
#  'KM foggy VB rainy': 0.00042743730553487433,
#  'KM sunny LH rainy': 0.0005415079975027703,
#  'KM sunny VB rainy': 0.00042743730553487433,
#  'KM snowy LH rainy': 0.0005415079975027703,
#  'KM snowy VB rainy': 0.00042743730553487433,
#  'AG rainy LH rainy': 0.0003790555982519392,
#  'AG rainy VB rainy': 0.0002992061138744121,
#  'AG cloudy LH rainy': 0.0003790555982519392,
#  'AG cloudy VB rainy': 0.0002992061138744121,
#  'AG foggy LH rainy': 0.0003790555982519392,
#  'AG foggy VB rainy': 0.0002992061138744121,
#  'AG sunny LH rainy': 0.0003790555982519392,
#  'AG sunny VB rainy': 0.0002992061138744121,
#  'AG snowy LH rainy': 0.0003790555982519392,
#  'AG snowy VB rainy': 0.0002992061138744121,
#  'RG rainy LH rainy': 0.00021660319900110813,
#  'RG rainy VB rainy': 0.00017097492221394974,
#  'RG cloudy LH rainy': 0.00021660319900110813,
#  'RG cloudy VB rainy': 0.00017097492221394974,
#  'RG foggy LH rainy': 0.00021660319900110813,
#  'RG foggy VB rainy': 0.00017097492221394974,
#  'RG sunny LH rainy': 0.00021660319900110813,
#  'RG sunny VB rainy': 0.00017097492221394974,
#  'RG snowy LH rainy': 0.00021660319900110813,
#  'RG snowy VB rainy': 0.00017097492221394974,
#  'RK rainy LH rainy': 2.7075399875138516e-05,
#  'RK rainy VB rainy': 2.1371865276743718e-05,
#  'RK cloudy LH rainy': 2.7075399875138516e-05,
#  'RK cloudy VB rainy': 2.1371865276743718e-05,
#  'RK foggy LH rainy': 2.7075399875138516e-05,
#  'RK foggy VB rainy': 2.1371865276743718e-05,
#  'RK sunny LH rainy': 2.7075399875138516e-05,
#  'RK sunny VB rainy': 2.1371865276743718e-05,
#  'RK snowy LH rainy': 2.7075399875138516e-05,
#  'RK snowy VB rainy': 2.1371865276743718e-05,
#  'GR rainy LH rainy': 0.0,
#  'GR rainy VB rainy': 0.0,
#  'GR cloudy LH rainy': 0.0,
#  'GR cloudy VB rainy': 0.0,
#  'GR foggy LH rainy': 0.0,
#  'GR foggy VB rainy': 0.0,
#  'GR sunny LH rainy': 0.0,
#  'GR sunny VB rainy': 0.0,
#  'GR snowy LH rainy': 0.0,
#  'GR snowy VB rainy': 0.0}

# %% [markdown]
# #### Now, I am getting the probability of Mercedes winning both races on rainy day

# %%
def merciwinsboth(outcome):
    return ('LH' in outcome and 'VB' in outcome)

MerciWinsBoth = p(merciwinsboth, RainyCombo)
MerciWinsBoth
# Out:
# 0.15887844646731275
