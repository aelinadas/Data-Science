# %% [markdown]
# # Translation models using MFC and HMM Models

# %%
# !pip install pomegranate
# Out:
# Requirement already satisfied: pomegranate in /Users/aelinadas/opt/anaconda3/lib/python3.7/site-packages (0.12.0)
# Requirement already satisfied: scipy>=0.17.0 in /Users/aelinadas/opt/anaconda3/lib/python3.7/site-packages (from pomegranate) (1.4.1)
# Requirement already satisfied: joblib>=0.9.0b4 in /Users/aelinadas/opt/anaconda3/lib/python3.7/site-packages (from pomegranate) (0.13.2)
# Requirement already satisfied: pyyaml in /Users/aelinadas/opt/anaconda3/lib/python3.7/site-packages (from pomegranate) (5.1.2)
# Requirement already satisfied: numpy>=1.8.0 in /Users/aelinadas/opt/anaconda3/lib/python3.7/site-packages (from pomegranate) (1.17.2)
# Requirement already satisfied: networkx>=2.0 in /Users/aelinadas/opt/anaconda3/lib/python3.7/site-packages (from pomegranate) (2.3)
# Requirement already satisfied: decorator>=4.3.0 in /Users/aelinadas/opt/anaconda3/lib/python3.7/site-packages (from networkx>=2.0->pomegranate) (4.4.0)

# %%
import matplotlib.pyplot as plt
import numpy as np
from IPython.core.display import HTML
from itertools import chain
from collections import Counter, defaultdict, namedtuple, OrderedDict
from pomegranate import State, HiddenMarkovModel, DiscreteDistribution
import os
from io import BytesIO
from itertools import chain
import random

# %% [markdown]
# # Functions to read data sets

# %%
def read_data(filename):
    """Read tagged sentence data"""
    with open(filename, 'r', encoding="UTF-8") as f:
        sentence_lines = [l.split("\n") for l in f.read().split("\n\n")]
    return OrderedDict(((s[0], Sentence(*zip(*[l.strip().split("\t")
                        for l in s[1:]]))) for s in sentence_lines if s[0]))

def read_tags(filename):
    """Read a list of word tag classes"""
    with open(filename, 'r', encoding="UTF-8") as f:
        tags = f.read().split("\n")
    return frozenset(tags)

Sentence = namedtuple("Sentence", "words tags")

# %% [markdown]
# # Read text files containing data

# %%
tagset = read_tags("data/Final-Tags.txt")
sentences = read_data("data/final-docs.txt")

# %%
class Dataset(namedtuple("_Dataset", "sentences keys vocab X tagset Y training_set testing_set N stream")):
    def __new__(cls, tagfile, datafile, train_test_split=0.8, seed=112890):
        tagset = read_tags(tagfile)
        sentences = read_data(datafile)
        keys = tuple(sentences.keys())
        wordset = frozenset(chain(*[s.words for s in sentences.values()]))
        word_sequences = tuple([sentences[k].words for k in keys])
        tag_sequences = tuple([sentences[k].tags for k in keys])
        N = sum(1 for _ in chain(*(s.words for s in sentences.values())))
        
        # split data into train/test sets
        _keys = list(keys)
        if seed is not None: random.seed(seed)
        random.shuffle(_keys)
        split = int(train_test_split * len(_keys))
        training_data = Subset(sentences, _keys[:split])
        testing_data = Subset(sentences, _keys[split:])
        stream = tuple(zip(chain(*word_sequences), chain(*tag_sequences)))
        return super().__new__(cls, dict(sentences), keys, wordset, word_sequences, tagset,
                               tag_sequences, training_data, testing_data, N, stream.__iter__)

    def __len__(self):
        return len(self.sentences)

    def __iter__(self):
        return iter(self.sentences.items())
    
    
class Subset(namedtuple("BaseSet", "sentences keys vocab X tagset Y N stream")):
    def __new__(cls, sentences, keys):
        word_sequences = tuple([sentences[k].words for k in keys])
        tag_sequences = tuple([sentences[k].tags for k in keys])
        wordset = frozenset(chain(*word_sequences))
        tagset = frozenset(chain(*tag_sequences))
        N = sum(1 for _ in chain(*(sentences[k].words for k in keys)))
        stream = tuple(zip(chain(*word_sequences), chain(*tag_sequences)))
        return super().__new__(cls, {k: sentences[k] for k in keys}, keys, wordset, word_sequences,
                               tagset, tag_sequences, N, stream.__iter__)

    def __len__(self):
        return len(self.sentences)

    def __iter__(self):
        return iter(self.sentences.items())

# %%
data = Dataset("data/Final-Tags.txt", "data/final-docs.txt", train_test_split=0.8)

print("There are {} sentences in the corpus.".format(len(data)))
print("There are {} sentences in the training set.".format(len(data.training_set)))
print("There are {} sentences in the testing set.".format(len(data.testing_set)))

assert len(data) == len(data.training_set) + len(data.testing_set), \
       "The number of sentences in the training set + testing set should sum to the number of sentences in the corpus"
# Out:
# There are 116 sentences in the corpus.
# There are 92 sentences in the training set.
# There are 24 sentences in the testing set.

# %%
print("There are a total of {} samples of {} unique words in the corpus."
      .format(data.N, len(data.vocab)))
print("There are {} samples of {} unique words in the training set."
      .format(data.training_set.N, len(data.training_set.vocab)))
print("There are {} samples of {} unique words in the testing set."
      .format(data.testing_set.N, len(data.testing_set.vocab)))
print("There are {} words in the test set that are missing in the training set."
      .format(len(data.testing_set.vocab - data.training_set.vocab)))

assert data.N == data.training_set.N + data.testing_set.N, \
       "The number of training + test samples should sum to the total number of samples"
# Out:
# There are a total of 236 samples of 55 unique words in the corpus.
# There are 188 samples of 50 unique words in the training set.
# There are 48 samples of 20 unique words in the testing set.
# There are 5 words in the test set that are missing in the training set.

# %%
# accessing words with Dataset.X and tags with Dataset.Y 
for i in range(2):    
    print("Sentence {}:".format(i + 1), data.X[i])
    print()
    print("Labels {}:".format(i + 1), data.Y[i])
    print()
# Out:
# Sentence 1: ('वाह!', '.')
#
# Labels 1: ('Wow!', '.')
#
# Sentence 2: ('बचाओ!', '.')
#
# Labels 2: ('Help!', '.')

# %%
class Dataset(namedtuple("_Dataset", "sentences keys vocab X tagset Y training_set testing_set N stream")):
    def __new__(cls, tagfile, datafile, train_test_split=0.8, seed=112890):
        tagset = read_tags(tagfile)
        sentences = read_data(datafile)
        keys = tuple(sentences.keys())
        wordset = frozenset(chain(*[s.words for s in sentences.values()]))
        word_sequences = tuple([sentences[k].words for k in keys])
        tag_sequences = tuple([sentences[k].tags for k in keys])
        N = sum(1 for _ in chain(*(s.words for s in sentences.values())))
        
        # split data into train/test sets
        _keys = list(keys)
        if seed is not None: random.seed(seed)
        random.shuffle(_keys)
        split = int(train_test_split * len(_keys))
        training_data = Subset(sentences, _keys[:split])
        testing_data = Subset(sentences, _keys[split:])
        stream = tuple(zip(chain(*word_sequences), chain(*tag_sequences)))
        return super().__new__(cls, dict(sentences), keys, wordset, word_sequences, tagset,
                               tag_sequences, training_data, testing_data, N, stream.__iter__)

    def __len__(self):
        return len(self.sentences)

    def __iter__(self):
        return iter(self.sentences.items())
    
    
class Subset(namedtuple("BaseSet", "sentences keys vocab X tagset Y N stream")):
    def __new__(cls, sentences, keys):
        word_sequences = tuple([sentences[k].words for k in keys])
        tag_sequences = tuple([sentences[k].tags for k in keys])
        wordset = frozenset(chain(*word_sequences))
        tagset = frozenset(chain(*tag_sequences))
        N = sum(1 for _ in chain(*(sentences[k].words for k in keys)))
        stream = tuple(zip(chain(*word_sequences), chain(*tag_sequences)))
        return super().__new__(cls, {k: sentences[k] for k in keys}, keys, wordset, word_sequences,
                               tagset, tag_sequences, N, stream.__iter__)

    def __len__(self):
        return len(self.sentences)

    def __iter__(self):
        return iter(self.sentences.items())

# %%
data = Dataset("data/Final-Tags.txt", "data/final-docs.txt", train_test_split=0.8)

print("There are {} sentences in the corpus.".format(len(data)))
print("There are {} sentences in the training set.".format(len(data.training_set)))
print("There are {} sentences in the testing set.".format(len(data.testing_set)))

assert len(data) == len(data.training_set) + len(data.testing_set), \
       "The number of sentences in the training set + testing set should sum to the number of sentences in the corpus"
# Out:
# There are 116 sentences in the corpus.
# There are 92 sentences in the training set.
# There are 24 sentences in the testing set.

# %%
print("There are a total of {} samples of {} unique words in the corpus."
      .format(data.N, len(data.vocab)))
print("There are {} samples of {} unique words in the training set."
      .format(data.training_set.N, len(data.training_set.vocab)))
print("There are {} samples of {} unique words in the testing set."
      .format(data.testing_set.N, len(data.testing_set.vocab)))
print("There are {} words in the test set that are missing in the training set."
      .format(len(data.testing_set.vocab - data.training_set.vocab)))

assert data.N == data.training_set.N + data.testing_set.N, \
       "The number of training + test samples should sum to the total number of samples"
# Out:
# There are a total of 236 samples of 55 unique words in the corpus.
# There are 188 samples of 50 unique words in the training set.
# There are 48 samples of 20 unique words in the testing set.
# There are 5 words in the test set that are missing in the training set.

# %%
for i in range(2):    
    print("Sentence {}:".format(i + 1), data.X[i])
    print()
    print("Labels {}:".format(i + 1), data.Y[i])
    print()
# Out:
# Sentence 1: ('वाह!', '.')
#
# Labels 1: ('Wow!', '.')
#
# Sentence 2: ('बचाओ!', '.')
#
# Labels 2: ('Help!', '.')

# %%
print("\nStream (word, tag) pairs:\n")
for i, pair in enumerate(data.stream()):
    print("\t", pair)
    if i > 3: break
# Out:
# Stream (word, tag) pairs:
#
# 	 ('वाह!', 'Wow!')
# 	 ('.', '.')
# 	 ('बचाओ!', 'Help!')
# 	 ('.', '.')
# 	 ('उछलो.', 'Jump.')

# %%
words = [word for i, (word, tag) in enumerate(data.training_set.stream())]
tags = [tag for i, (word, tag) in enumerate(data.training_set.stream())]
words[0:4], tags[0:4]
# Out:
# (['बहुत बढ़िया!', '.', 'भयानक', '.'], ['Awesome!', '.', 'Awesome!', '.'])

# %%
def pair_counts(tags, words):
    d = defaultdict(lambda: defaultdict(int))
    for tag, word in zip(tags, words):
        d[tag][word] += 1
    return d
        
word_counts = pair_counts(words, tags)

# %%
mfc_table = dict((word, max(tags.keys(), key=lambda key: tags[key])) for word, tags in word_counts.items())

# %%
i = 0
for key, value in mfc_table.items():
    print(key, value)
    i += 1
    if i > 3: break
# Out:
# बहुत बढ़िया! Awesome!
# . .
# भयानक Awesome!
# कूद. Jump.

# %%
FakeState = namedtuple('FakeState', 'name')

class MFCTagger:
    missing = FakeState(name = '<MISSING>')
    
    def __init__(self, table):
        self.table = defaultdict(lambda: MFCTagger.missing)
        self.table.update({word: FakeState(name=tag) for word, tag in table.items()})
        
    def viterbi(self, seq):
        """This method simplifies predictions by matching the Pomegranate viterbi() interface"""
        return 0., list(enumerate(["<start>"] + [self.table[w] for w in seq] + ["<end>"]))

# %%
mfc_model = MFCTagger(mfc_table)

# %%
def replace_unknown(sequence):
    return [w if w in data.training_set.vocab else 'nan' for w in sequence]

def simplify_decoding(X, model):    
    _, state_path = model.viterbi(replace_unknown(X))
    return [state[1].name for state in state_path[1:-1]]

# %%
for key in data.testing_set.keys[:3]:
    print("Sentence Key: {}\n".format(key))
    print("Sentence: {}\n".format(data.sentences[key].words))
    print("Predicted labels:\n-----------------")
    print(simplify_decoding(data.sentences[key].words, mfc_model))
    print()
    print("Actual labels:\n--------------")
    print(data.sentences[key].tags)
    print("\n")
# Out:
# Sentence Key: B100-0020
#
# Sentence: ('कूद.', '.')
#
# Predicted labels:
# -----------------
# ['Jump.', '.']
#
# Actual labels:
# --------------
# ('Jump.', '.')
#
#
# Sentence Key: B100-00902
#
# Sentence: ('समझे कि नहीं?', '.')
#
# Predicted labels:
# -----------------
# ['Got it?', '.']
#
# Actual labels:
# --------------
# ('Got it?', '.')
#
#
# Sentence Key: B100-0152
#
# Sentence: ('ख़ुदा हाफ़िज़।', '.')
#
# Predicted labels:
# -----------------
# ['Goodbye!', '.']
#
# Actual labels:
# --------------
# ('Goodbye!', '.')

# %%
def accuracy(X, Y, model):
    
    correct = total_predictions = 0
    for observations, actual_tags in zip(X, Y):
        
        # The model.viterbi call in simplify_decoding will return None if the HMM
        # raises an error (for example, if a test sentence contains a word that
        # is out of vocabulary for the training set). Any exception counts the
        # full sentence as an error (which makes this a conservative estimate).
        try:
            most_likely_tags = simplify_decoding(observations, model)
            correct += sum(p == t for p, t in zip(most_likely_tags, actual_tags))
        except:
            pass
        total_predictions += len(observations)
    return correct / total_predictions

# %% [markdown]
# # MFC Model Accuracy

# %%
mfc_training_acc = accuracy(data.training_set.X, data.training_set.Y, mfc_model)
print("training accuracy mfc_model: {:.2f}%".format(100 * mfc_training_acc))

mfc_testing_acc = accuracy(data.testing_set.X, data.testing_set.Y, mfc_model)
print("testing accuracy mfc_model: {:.2f}%".format(100 * mfc_testing_acc))
# Out:
# training accuracy mfc_model: 98.94%
# testing accuracy mfc_model: 89.58%

# %% [markdown]
# # Hidden Markov Model (HMM)

# %%
def unigram_counts(sequences):
    return Counter(sequences)

tags = [tag for i, (word, tag) in enumerate(data.training_set.stream())]
tag_unigrams = unigram_counts(tags)
tag_unigrams

# %%
def bigram_counts(sequences):
    return Counter(sequences)

tags = [tag for i, (word, tag) in enumerate(data.stream())]
o = [(tags[i],tags[i+1]) for i in range(0,len(tags)-2,2)]
tag_bigrams = bigram_counts(o)
tag_bigrams
# Out:
# Counter({('Wow!', '.'): 2,
#          ('Help!', '.'): 2,
#          ('Jump.', '.'): 8,
#          ('Hello!', '.'): 5,
#          ('Cheers!', '.'): 4,
#          ('Got it?', '.'): 3,
#          ("I'm OK.", '.'): 3,
#          ('Awesome!', '.'): 2,
#          ('Come in.', '.'): 3,
#          ('Get out!', '.'): 2,
#          ('Go away!', '.'): 2,
#          ('Goodbye!', '.'): 2,
#          ("What's your name?", '.'): 1,
#          ("Don't touch it.", '.'): 1,
#          ('Happy New Year!', '.'): 1,
#          ('Clean the room.', '.'): 1,
#          ("Don't touch it.", 'Get out of bed!'): 1,
#          ('.', 'I like history.'): 1,
#          ('I like the dog.', 'I must buy one.'): 1,
#          ('.', 'Wow!'): 4,
#          ('.', 'Help!'): 4,
#          ('.', 'Jump.'): 10,
#          ('.', 'Hello!'): 7,
#          ('.', 'Cheers!'): 8,
#          ('.', 'I feel nauseous.'): 1,
#          ('I go every year.', '.'): 1,
#          ('Congratulations!', 'Congratulations!'): 1,
#          ('.', 'Got it?'): 3,
#          ('.', "I'm OK."): 3,
#          ('.', 'Awesome!'): 4,
#          ('.', 'Come in.'): 3,
#          ('.', 'Get out!'): 4,
#          ('.', 'Go away!'): 3,
#          ('.', 'Goodbye!'): 4,
#          ('.', 'I want a guitar.'): 1,
#          ('I was assaulted.', '.'): 1,
#          ("I'm a good cook.", '.'): 2,
#          ("I'm lucky today.", '.'): 1,
#          ('Is anybody here?', '.'): 1,
#          ("I don't know him.", '.'): 1,
#          ('I have a problem.', '.'): 1,
#          ('I have to go now.', 'Go away!'): 1,
#          ('.', 'I saw him running.'): 1,
#          ('.', 'I truly loved her.'): 1,
#          ('.', 'I listen to music.'): 1})

# %%
def starting_counts(sequences):
    return Counter(sequences)

tags = [tag for i, (word, tag) in enumerate(data.stream())]
starts_tag = [i[0] for i in data.Y]
tag_starts = starting_counts(starts_tag)
tag_starts
# Out:
# Counter({'Wow!': 6,
#          'Help!': 6,
#          'Jump.': 18,
#          'Hello!': 12,
#          'Cheers!': 12,
#          'Got it?': 6,
#          "I'm OK.": 6,
#          'Awesome!': 6,
#          'Come in.': 6,
#          'Get out!': 6,
#          'Go away!': 6,
#          'Goodbye!': 6,
#          "What's your name?": 1,
#          "Don't touch it.": 2,
#          'Happy New Year!': 1,
#          'Clean the room.': 1,
#          'I like history.': 1,
#          'I feel nauseous.': 1,
#          'Congratulations!': 1,
#          'I want a guitar.': 1,
#          "I'm a good cook.": 2,
#          "I'm lucky today.": 1,
#          'Is anybody here?': 1,
#          "I don't know him.": 1,
#          'I have a problem.': 1,
#          'I have to go now.': 1,
#          'I saw him running.': 1,
#          'I truly loved her.': 1,
#          'I listen to music.': 1,
#          "I haven't met him.": 1})

# %%
def ending_counts(sequences):    
    return Counter(sequences)

end_tag = [i[len(i)-1] for i in data.Y]
tag_ends = ending_counts(end_tag)
tag_ends
# Out:
# Counter({'.': 114, 'I have to go now.': 1, "I haven't met him.": 1})

# %%
end_tag = [i[len(i)-2] for i in data.Y]
tag_ends = ending_counts(end_tag)
tag_ends
# Out:
# Counter({'Wow!': 6,
#          'Help!': 6,
#          'Jump.': 18,
#          'Hello!': 12,
#          'Cheers!': 12,
#          'Got it?': 6,
#          "I'm OK.": 6,
#          'Awesome!': 6,
#          'Come in.': 6,
#          'Get out!': 6,
#          'Go away!': 6,
#          'Goodbye!': 6,
#          "What's your name?": 1,
#          "Don't touch it.": 1,
#          'Happy New Year!': 1,
#          'Clean the room.': 1,
#          'Get out of bed!': 1,
#          'I must buy one.': 1,
#          'I go every year.': 1,
#          'Congratulations!': 1,
#          'I was assaulted.': 1,
#          "I'm a good cook.": 2,
#          "I'm lucky today.": 1,
#          'Is anybody here?': 1,
#          "I don't know him.": 1,
#          'I have a problem.': 1,
#          'I have to go now.': 1,
#          'I saw him running.': 1,
#          'I truly loved her.': 1,
#          'I listen to music.': 1,
#          "I haven't met him.": 1})

# %%
hmm_model = HiddenMarkovModel(name="base-hmm-tagger")

tags = [tag for i, (word, tag) in enumerate(data.stream())]
words = [word for i, (word, tag) in enumerate(data.stream())]

tags_count = unigram_counts(tags)
tag_words_count = pair_counts(tags, words)

starting_tag_list = [i[0] for i in data.Y]
#ending_tag_list = [i[-1] if len(i)==1 else i[-2] for i in data.Y]
#ending_tag_list = [i[-1] for i in data.Y]
ending_tag_list = [i[len(i)-2] for i in data.Y]

starting_tag_count = starting_counts(starting_tag_list) #the number of times a tag occured at the start
ending_tag_count = ending_counts(ending_tag_list)       #the number of times a tag occured at the end

tag_words_count
# Out:
# defaultdict(<function __main__.pair_counts.<locals>.<lambda>()>,
#             {'Wow!': defaultdict(int, {'वाह!': 4, 'सनसनीखेज कामयाबी': 2}),
#              '.': defaultdict(int, {'.': 114}),
#              'Help!': defaultdict(int, {'बचाओ!': 4, 'मदद!': 2}),
#              'Jump.': defaultdict(int,
#                          {'उछलो.': 2,
#                           'कूदो.': 4,
#                           'छलांग.': 4,
#                           'कूद.': 2,
#                           'जम्प.': 2,
#                           'एकाएक दाम की वृद्धि.': 2,
#                           'लपक.': 2}),
#              'Hello!': defaultdict(int,
#                          {'नमस्ते।': 4,
#                           'नमस्कार।': 4,
#                           'हलो!': 2,
#                           'नमस्कार!': 2}),
#              'Cheers!': defaultdict(int, {'वाह-वाह!': 6, 'चियर्स!': 6}),
#              'Got it?': defaultdict(int, {'समझे कि नहीं?': 4, 'समझ गया?': 2}),
#              "I'm OK.": defaultdict(int, {'मैं ठीक हूँ।': 6}),
#              'Awesome!': defaultdict(int, {'बहुत बढ़िया!': 4, 'भयानक': 2}),
#              'Come in.': defaultdict(int, {'अंदर आ जाओ।': 4, 'अन्दर आइए': 2}),
#              'Get out!': defaultdict(int,
#                          {'बाहर निकल जाओ!': 4, 'बाहर जाओ!': 2}),
#              'Go away!': defaultdict(int, {'चले जाओ!': 6}),
#              'Goodbye!': defaultdict(int,
#                          {'ख़ुदा हाफ़िज़।': 4, 'नमस्कार!': 2}),
#              "What's your name?": defaultdict(int, {'आपका नाम क्या है?': 1}),
#              "Don't touch it.": defaultdict(int,
#                          {'से छूना मत।': 1, 'उसे छूना मत।': 1}),
#              'Happy New Year!': defaultdict(int,
#                          {'नव वर्ष की शुभकामनाएं!': 1}),
#              'Clean the room.': defaultdict(int, {'कमरे को साफ़ करो।': 1}),
#              'Get out of bed!': defaultdict(int, {'बिस्तर से बाहर निकलो!': 1}),
#              'I like history.': defaultdict(int, {'मुझे इतिहास पसंद है।': 1}),
#              'I like the dog.': defaultdict(int,
#                          {'मुझे यह कुत्ता अच्छा लगता है।': 1}),
#              'I must buy one.': defaultdict(int,
#                          {'मुझे एक तो खरीदना ही होगा।': 1}),
#              'I feel nauseous.': defaultdict(int, {'मुझे उल्टी आ रही है।': 1}),
#              'I go every year.': defaultdict(int, {'मैं हर साल जाता हूँ।': 1}),
#              'Congratulations!': defaultdict(int,
#                          {'बधाई हो!': 1, 'मुबारक हो!': 1}),
#              'I want a guitar.': defaultdict(int, {'मुझे गिटार चाहिए।': 1}),
#              'I was assaulted.': defaultdict(int, {'मुझपर हमला किया गया।': 1}),
#              "I'm a good cook.": defaultdict(int,
#                          {'मैं अच्छा रसोइया हूँ।': 1,
#                           'मैं अच्छा बावर्ची हूँ।': 1}),
#              "I'm lucky today.": defaultdict(int,
#                          {'आज मेरा नसीब अच्छा है।': 1}),
#              'Is anybody here?': defaultdict(int, {'कोई है क्या?': 1}),
#              "I don't know him.": defaultdict(int, {'मैं उसे नहीं जानता।': 1}),
#              'I have a problem.': defaultdict(int,
#                          {'मैं मुश्किल में हूँ।': 1}),
#              'I have to go now.': defaultdict(int, {'मुझे अभी जाना है।': 1}),
#              'I saw him running.': defaultdict(int,
#                          {'मैंने उसे दौड़ते हुए देखा।': 1}),
#              'I truly loved her.': defaultdict(int,
#                          {'मैं उससे सच्चा प्यार करता था।': 1}),
#              'I listen to music.': defaultdict(int,
#                          {'मैं संगीत सुनता हूँ।': 1}),
#              "I haven't met him.": defaultdict(int,
#                          {'मेरी उससे मुलाकात नहीं हुई है।': 1})})

# %%
ending_tag_list
# Out:
# ['Wow!',
#  'Help!',
#  'Jump.',
#  'Jump.',
#  'Jump.',
#  'Hello!',
#  'Hello!',
#  'Cheers!',
#  'Cheers!',
#  'Got it?',
#  "I'm OK.",
#  'Awesome!',
#  'Come in.',
#  'Get out!',
#  'Go away!',
#  'Goodbye!',
#  "What's your name?",
#  "Don't touch it.",
#  'Happy New Year!',
#  'Clean the room.',
#  'Get out of bed!',
#  'I must buy one.',
#  'Wow!',
#  'Help!',
#  'Jump.',
#  'Jump.',
#  'Jump.',
#  'Hello!',
#  'Hello!',
#  'Cheers!',
#  'Cheers!',
#  'Cheers!',
#  'I go every year.',
#  'Got it?',
#  "I'm OK.",
#  'Awesome!',
#  'Come in.',
#  'Get out!',
#  'Go away!',
#  'Goodbye!',
#  'Wow!',
#  'Help!',
#  'Jump.',
#  'Jump.',
#  'Jump.',
#  'Hello!',
#  'Congratulations!',
#  'Hello!',
#  'Cheers!',
#  'Got it?',
#  "I'm OK.",
#  'Awesome!',
#  'Awesome!',
#  'Come in.',
#  'Get out!',
#  'Get out!',
#  'Go away!',
#  'Goodbye!',
#  'Wow!',
#  'Help!',
#  'Jump.',
#  'I was assaulted.',
#  'Jump.',
#  'Jump.',
#  'Hello!',
#  'Hello!',
#  "I'm a good cook.",
#  "I'm a good cook.",
#  'Cheers!',
#  'Cheers!',
#  'Got it?',
#  "I'm lucky today.",
#  'Is anybody here?',
#  "I'm OK.",
#  'Come in.',
#  "I don't know him.",
#  'I have a problem.',
#  'I have to go now.',
#  'Go away!',
#  'Goodbye!',
#  'Wow!',
#  'Help!',
#  'Jump.',
#  'Jump.',
#  'Jump.',
#  'Hello!',
#  'Hello!',
#  'Cheers!',
#  'Cheers!',
#  'Got it?',
#  "I'm OK.",
#  'Awesome!',
#  'Come in.',
#  'Get out!',
#  'Go away!',
#  'Goodbye!',
#  'Wow!',
#  'Help!',
#  'Jump.',
#  'Jump.',
#  'Jump.',
#  'Hello!',
#  'Hello!',
#  'Cheers!',
#  'Cheers!',
#  'Got it?',
#  "I'm OK.",
#  'Awesome!',
#  'Come in.',
#  'I saw him running.',
#  'Get out!',
#  'Go away!',
#  'Goodbye!',
#  'I truly loved her.',
#  'I listen to music.',
#  "I haven't met him."]

# %%
to_pass_states = []
for tag, words_dict in tag_words_count.items():
    total = float(sum(words_dict.values()))
    distribution = {word: count/total for word, count in words_dict.items()}
    tag_emissions = DiscreteDistribution(distribution)
    tag_state = State(tag_emissions, name=tag)
    to_pass_states.append(tag_state)

# %%
to_pass_states
# Out:
# [{
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0935\u093e\u0939!" : 0.6666666666666666,
#                  "\u0938\u0928\u0938\u0928\u0940\u0916\u0947\u091c \u0915\u093e\u092e\u092f\u093e\u092c\u0940" : 0.3333333333333333
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Wow!",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "." : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : ".",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092c\u091a\u093e\u0913!" : 0.6666666666666666,
#                  "\u092e\u0926\u0926!" : 0.3333333333333333
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Help!",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0909\u091b\u0932\u094b." : 0.1111111111111111,
#                  "\u0915\u0942\u0926\u094b." : 0.2222222222222222,
#                  "\u091b\u0932\u093e\u0902\u0917." : 0.2222222222222222,
#                  "\u0915\u0942\u0926." : 0.1111111111111111,
#                  "\u091c\u092e\u094d\u092a." : 0.1111111111111111,
#                  "\u090f\u0915\u093e\u090f\u0915 \u0926\u093e\u092e \u0915\u0940 \u0935\u0943\u0926\u094d\u0927\u093f." : 0.1111111111111111,
#                  "\u0932\u092a\u0915." : 0.1111111111111111
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Jump.",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0928\u092e\u0938\u094d\u0924\u0947\u0964" : 0.3333333333333333,
#                  "\u0928\u092e\u0938\u094d\u0915\u093e\u0930\u0964" : 0.3333333333333333,
#                  "\u0939\u0932\u094b!" : 0.16666666666666666,
#                  "\u0928\u092e\u0938\u094d\u0915\u093e\u0930!" : 0.16666666666666666
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Hello!",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0935\u093e\u0939-\u0935\u093e\u0939!" : 0.5,
#                  "\u091a\u093f\u092f\u0930\u094d\u0938!" : 0.5
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Cheers!",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0938\u092e\u091d\u0947 \u0915\u093f \u0928\u0939\u0940\u0902?" : 0.6666666666666666,
#                  "\u0938\u092e\u091d \u0917\u092f\u093e?" : 0.3333333333333333
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Got it?",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092e\u0948\u0902 \u0920\u0940\u0915 \u0939\u0942\u0901\u0964" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "I'm OK.",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092c\u0939\u0941\u0924 \u092c\u0922\u093c\u093f\u092f\u093e!" : 0.6666666666666666,
#                  "\u092d\u092f\u093e\u0928\u0915" : 0.3333333333333333
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Awesome!",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0905\u0902\u0926\u0930 \u0906 \u091c\u093e\u0913\u0964" : 0.6666666666666666,
#                  "\u0905\u0928\u094d\u0926\u0930 \u0906\u0907\u090f" : 0.3333333333333333
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Come in.",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092c\u093e\u0939\u0930 \u0928\u093f\u0915\u0932 \u091c\u093e\u0913!" : 0.6666666666666666,
#                  "\u092c\u093e\u0939\u0930 \u091c\u093e\u0913!" : 0.3333333333333333
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Get out!",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u091a\u0932\u0947 \u091c\u093e\u0913!" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Go away!",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0916\u093c\u0941\u0926\u093e \u0939\u093e\u092b\u093c\u093f\u091c\u093c\u0964" : 0.6666666666666666,
#                  "\u0928\u092e\u0938\u094d\u0915\u093e\u0930!" : 0.3333333333333333
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Goodbye!",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0906\u092a\u0915\u093e \u0928\u093e\u092e \u0915\u094d\u092f\u093e \u0939\u0948?" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "What's your name?",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0938\u0947 \u091b\u0942\u0928\u093e \u092e\u0924\u0964" : 0.5,
#                  "\u0909\u0938\u0947 \u091b\u0942\u0928\u093e \u092e\u0924\u0964" : 0.5
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Don't touch it.",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0928\u0935 \u0935\u0930\u094d\u0937 \u0915\u0940 \u0936\u0941\u092d\u0915\u093e\u092e\u0928\u093e\u090f\u0902!" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Happy New Year!",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0915\u092e\u0930\u0947 \u0915\u094b \u0938\u093e\u092b\u093c \u0915\u0930\u094b\u0964" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Clean the room.",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092c\u093f\u0938\u094d\u0924\u0930 \u0938\u0947 \u092c\u093e\u0939\u0930 \u0928\u093f\u0915\u0932\u094b!" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Get out of bed!",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092e\u0941\u091d\u0947 \u0907\u0924\u093f\u0939\u093e\u0938 \u092a\u0938\u0902\u0926 \u0939\u0948\u0964" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "I like history.",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092e\u0941\u091d\u0947 \u092f\u0939 \u0915\u0941\u0924\u094d\u0924\u093e \u0905\u091a\u094d\u091b\u093e \u0932\u0917\u0924\u093e \u0939\u0948\u0964" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "I like the dog.",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092e\u0941\u091d\u0947 \u090f\u0915 \u0924\u094b \u0916\u0930\u0940\u0926\u0928\u093e \u0939\u0940 \u0939\u094b\u0917\u093e\u0964" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "I must buy one.",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092e\u0941\u091d\u0947 \u0909\u0932\u094d\u091f\u0940 \u0906 \u0930\u0939\u0940 \u0939\u0948\u0964" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "I feel nauseous.",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092e\u0948\u0902 \u0939\u0930 \u0938\u093e\u0932 \u091c\u093e\u0924\u093e \u0939\u0942\u0901\u0964" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "I go every year.",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092c\u0927\u093e\u0908 \u0939\u094b!" : 0.5,
#                  "\u092e\u0941\u092c\u093e\u0930\u0915 \u0939\u094b!" : 0.5
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Congratulations!",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092e\u0941\u091d\u0947 \u0917\u093f\u091f\u093e\u0930 \u091a\u093e\u0939\u093f\u090f\u0964" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "I want a guitar.",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092e\u0941\u091d\u092a\u0930 \u0939\u092e\u0932\u093e \u0915\u093f\u092f\u093e \u0917\u092f\u093e\u0964" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "I was assaulted.",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092e\u0948\u0902 \u0905\u091a\u094d\u091b\u093e \u0930\u0938\u094b\u0907\u092f\u093e \u0939\u0942\u0901\u0964" : 0.5,
#                  "\u092e\u0948\u0902 \u0905\u091a\u094d\u091b\u093e \u092c\u093e\u0935\u0930\u094d\u091a\u0940 \u0939\u0942\u0901\u0964" : 0.5
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "I'm a good cook.",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0906\u091c \u092e\u0947\u0930\u093e \u0928\u0938\u0940\u092c \u0905\u091a\u094d\u091b\u093e \u0939\u0948\u0964" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "I'm lucky today.",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0915\u094b\u0908 \u0939\u0948 \u0915\u094d\u092f\u093e?" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Is anybody here?",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092e\u0948\u0902 \u0909\u0938\u0947 \u0928\u0939\u0940\u0902 \u091c\u093e\u0928\u0924\u093e\u0964" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "I don't know him.",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092e\u0948\u0902 \u092e\u0941\u0936\u094d\u0915\u093f\u0932 \u092e\u0947\u0902 \u0939\u0942\u0901\u0964" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "I have a problem.",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092e\u0941\u091d\u0947 \u0905\u092d\u0940 \u091c\u093e\u0928\u093e \u0939\u0948\u0964" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "I have to go now.",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092e\u0948\u0902\u0928\u0947 \u0909\u0938\u0947 \u0926\u094c\u0921\u093c\u0924\u0947 \u0939\u0941\u090f \u0926\u0947\u0916\u093e\u0964" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "I saw him running.",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092e\u0948\u0902 \u0909\u0938\u0938\u0947 \u0938\u091a\u094d\u091a\u093e \u092a\u094d\u092f\u093e\u0930 \u0915\u0930\u0924\u093e \u0925\u093e\u0964" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "I truly loved her.",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092e\u0948\u0902 \u0938\u0902\u0917\u0940\u0924 \u0938\u0941\u0928\u0924\u093e \u0939\u0942\u0901\u0964" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "I listen to music.",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092e\u0947\u0930\u0940 \u0909\u0938\u0938\u0947 \u092e\u0941\u0932\u093e\u0915\u093e\u0924 \u0928\u0939\u0940\u0902 \u0939\u0941\u0908 \u0939\u0948\u0964" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "I haven't met him.",
#      "weight" : 1.0
#  }]

# %%
hmm_model.add_states()

# %%
start_prob={}

for tag in tags:
    start_prob[tag] = starting_tag_count[tag] / tags_count[tag]

for tag_state in to_pass_states :
    hmm_model.add_transition(hmm_model.start, tag_state, start_prob[tag_state.name])

# %%
end_prob={}

for tag in tags:
    end_prob[tag] = ending_tag_count[tag]/tags_count[tag]
    
for tag_state in to_pass_states :
    hmm_model.add_transition(tag_state, hmm_model.end, end_prob[tag_state.name])

# %%
transition_prob_pair={}

for key in tag_bigrams.keys():
    transition_prob_pair[key] = tag_bigrams.get(key)/tags_count[key[0]]
    
for tag_state in to_pass_states:
    for next_tag_state in to_pass_states:
        hmm_model.add_transition(tag_state, next_tag_state, transition_prob_pair[(tag_state.name, next_tag_state.name)])

# %% [markdown]
# # Bake the HMM

# %%
hmm_model.bake()

# %% [markdown]
# # HMM Accuracy

# %%
hmm_model
# Out:
# {
#     "class" : "HiddenMarkovModel",
#     "name" : "base-hmm-tagger",
#     "start" : {
#         "class" : "State",
#         "distribution" : null,
#         "name" : "base-hmm-tagger-start",
#         "weight" : 1.0
#     },
#     "end" : {
#         "class" : "State",
#         "distribution" : null,
#         "name" : "base-hmm-tagger-end",
#         "weight" : 1.0
#     },
#     "states" : [
#         {
#             "class" : "State",
#             "distribution" : {
#                 "class" : "Distribution",
#                 "dtype" : "str",
#                 "name" : "DiscreteDistribution",
#                 "parameters" : [
#                     {
#                         "." : 1.0
#                     }
#                 ],
#                 "frozen" : false
#             },
#             "name" : ".",
#             "weight" : 1.0
#         },
#         {
#             "class" : "State",
#             "distribution" : {
#                 "class" : "Distribution",
#                 "dtype" : "str",
#                 "name" : "DiscreteDistribution",
#                 "parameters" : [
#                     {
#                         "\u092c\u0939\u0941\u0924 \u092c\u0922\u093c\u093f\u092f\u093e!" : 0.6666666666666666,
#                         "\u092d\u092f\u093e\u0928\u0915" : 0.3333333333333333
#                     }
#                 ],
#                 "frozen" : false
#             },
#             "name" : "Awesome!",
#             "weight" : 1.0
#         },
#         {
#             "class" : "State",
#             "distribution" : {
#                 "class" : "Distribution",
#                 "dtype" : "str",
#                 "name" : "DiscreteDistribution",
#                 "parameters" : [
#                     {
#                         "\u0935\u093e\u0939-\u0935\u093e\u0939!" : 0.5,
#                         "\u091a\u093f\u092f\u0930\u094d\u0938!" : 0.5
#                     }
#                 ],
#                 "frozen" : false
#             },
#             "name" : "Cheers!",
#             "weight" : 1.0
#         },
#         {
#             "class" : "State",
#             "distribution" : {
#                 "class" : "Distribution",
#                 "dtype" : "str",
#                 "name" : "DiscreteDistribution",
#                 "parameters" : [
#                     {
#                         "\u0915\u092e\u0930\u0947 \u0915\u094b \u0938\u093e\u092b\u093c \u0915\u0930\u094b\u0964" : 1.0
#                     }
#                 ],
#                 "frozen" : false
#             },
#             "name" : "Clean the room.",
#             "weight" : 1.0
#         },
#         {
#             "class" : "State",
#             "distribution" : {
#                 "class" : "Distribution",
#                 "dtype" : "str",
#                 "name" : "DiscreteDistribution",
#                 "parameters" : [
#                     {
#                         "\u0905\u0902\u0926\u0930 \u0906 \u091c\u093e\u0913\u0964" : 0.6666666666666666,
#                         "\u0905\u0928\u094d\u0926\u0930 \u0906\u0907\u090f" : 0.3333333333333333
#                     }
#                 ],
#                 "frozen" : false
#             },
#             "name" : "Come in.",
#             "weight" : 1.0
#         },
#         {
#             "class" : "State",
#             "distribution" : {
#                 "class" : "Distribution",
#                 "dtype" : "str",
#                 "name" : "DiscreteDistribution",
#                 "parameters" : [
#                     {
#                         "\u092c\u0927\u093e\u0908 \u0939\u094b!" : 0.5,
#                         "\u092e\u0941\u092c\u093e\u0930\u0915 \u0939\u094b!" : 0.5
#                     }
#                 ],
#                 "frozen" : false
#             },
#             "name" : "Congratulations!",
#             "weight" : 1.0
#         },
#         {
#             "class" : "State",
#             "distribution" : {
#                 "class" : "Distribution",
#                 "dtype" : "str",
#                 "name" : "DiscreteDistribution",
#                 "parameters" : [
#                     {
#                         "\u0938\u0947 \u091b\u0942\u0928\u093e \u092e\u0924\u0964" : 0.5,
#                         "\u0909\u0938\u0947 \u091b\u0942\u0928\u093e \u092e\u0924\u0964" : 0.5
#                     }
#                 ],
#                 "frozen" : false
#             },
#             "name" : "Don't touch it.",
#             "weight" : 1.0
#         },
#         {
#             "class" : "State",
#             "distribution" : {
#                 "class" : "Distribution",
#                 "dtype" : "str",
#                 "name" : "DiscreteDistribution",
#                 "parameters" : [
#                     {
#                         "\u092c\u093f\u0938\u094d\u0924\u0930 \u0938\u0947 \u092c\u093e\u0939\u0930 \u0928\u093f\u0915\u0932\u094b!" : 1.0
#                     }
#                 ],
#                 "frozen" : false
#             },
#             "name" : "Get out of bed!",
#             "weight" : 1.0
#         },
#         {
#             "class" : "State",
#             "distribution" : {
#                 "class" : "Distribution",
#                 "dtype" : "str",
#                 "name" : "DiscreteDistribution",
#                 "parameters" : [
#                     {
#                         "\u092c\u093e\u0939\u0930 \u0928\u093f\u0915\u0932 \u091c\u093e\u0913!" : 0.6666666666666666,
#                         "\u092c\u093e\u0939\u0930 \u091c\u093e\u0913!" : 0.3333333333333333
#                     }
#                 ],
#                 "frozen" : false
#             },
#             "name" : "Get out!",
#             "weight" : 1.0
#         },
#         {
#             "class" : "State",
#             "distribution" : {
#                 "class" : "Distribution",
#                 "dtype" : "str",
#                 "name" : "DiscreteDistribution",
#                 "parameters" : [
#                     {
#                         "\u091a\u0932\u0947 \u091c\u093e\u0913!" : 1.0
#                     }
#                 ],
#                 "frozen" : false
#             },
#             "name" : "Go away!",
#             "weight" : 1.0
#         },
#         {
#             "class" : "State",
#             "distribution" : {
#                 "class" : "Distribution",
#                 "dtype" : "str",
#                 "name" : "DiscreteDistribution",
#                 "parameters" : [
#                     {
#                         "\u0916\u093c\u0941\u0926\u093e \u0939\u093e\u092b\u093c\u093f\u091c\u093c\u0964" : 0.6666666666666666,
#                         "\u0928\u092e\u0938\u094d\u0915\u093e\u0930!" : 0.3333333333333333
#                     }
#                 ],
#                 "frozen" : false
#             },
#             "name" : "Goodbye!",
#             "weight" : 1.0
#         },
#         {
#             "class" : "State",
#             "distribution" : {
#                 "class" : "Distribution",
#                 "dtype" : "str",
#                 "name" : "DiscreteDistribution",
#                 "parameters" : [
#                     {
#                         "\u0938\u092e\u091d\u0947 \u0915\u093f \u0928\u0939\u0940\u0902?" : 0.6666666666666666,
#                         "\u0938\u092e\u091d \u0917\u092f\u093e?" : 0.3333333333333333
#                     }
#                 ],
#                 "frozen" : false
#             },
#             "name" : "Got it?",
#             "weight" : 1.0
#         },
#         {
#             "class" : "State",
#             "distribution" : {
#                 "class" : "Distribution",
#                 "dtype" : "str",
#                 "name" : "DiscreteDistribution",
#                 "parameters" : [
#                     {
#                         "\u0928\u0935 \u0935\u0930\u094d\u0937 \u0915\u0940 \u0936\u0941\u092d\u0915\u093e\u092e\u0928\u093e\u090f\u0902!" : 1.0
#                     }
#                 ],
#                 "frozen" : false
#             },
#             "name" : "Happy New Year!",
#             "weight" : 1.0
#         },
#         {
#             "class" : "State",
#             "distribution" : {
#                 "class" : "Distribution",
#                 "dtype" : "str",
#                 "name" : "DiscreteDistribution",
#                 "parameters" : [
#                     {
#                         "\u0928\u092e\u0938\u094d\u0924\u0947\u0964" : 0.3333333333333333,
#                         "\u0928\u092e\u0938\u094d\u0915\u093e\u0930\u0964" : 0.3333333333333333,
#                         "\u0939\u0932\u094b!" : 0.16666666666666666,
#                         "\u0928\u092e\u0938\u094d\u0915\u093e\u0930!" : 0.16666666666666666
#                     }
#                 ],
#                 "frozen" : false
#             },
#             "name" : "Hello!",
#             "weight" : 1.0
#         },
#         {
#             "class" : "State",
#             "distribution" : {
#                 "class" : "Distribution",
#                 "dtype" : "str",
#                 "name" : "DiscreteDistribution",
#                 "parameters" : [
#                     {
#                         "\u092c\u091a\u093e\u0913!" : 0.6666666666666666,
#                         "\u092e\u0926\u0926!" : 0.3333333333333333
#                     }
#                 ],
#                 "frozen" : false
#             },
#             "name" : "Help!",
#             "weight" : 1.0
#         },
#         {
#             "class" : "State",
#             "distribution" : {
#                 "class" : "Distribution",
#                 "dtype" : "str",
#                 "name" : "DiscreteDistribution",
#                 "parameters" : [
#                     {
#                         "\u092e\u0948\u0902 \u0909\u0938\u0947 \u0928\u0939\u0940\u0902 \u091c\u093e\u0928\u0924\u093e\u0964" : 1.0
#                     }
#                 ],
#                 "frozen" : false
#             },
#             "name" : "I don't know him.",
#             "weight" : 1.0
#         },
#         {
#             "class" : "State",
#             "distribution" : {
#                 "class" : "Distribution",
#                 "dtype" : "str",
#                 "name" : "DiscreteDistribution",
#                 "parameters" : [
#                     {
#                         "\u092e\u0941\u091d\u0947 \u0909\u0932\u094d\u091f\u0940 \u0906 \u0930\u0939\u0940 \u0939\u0948\u0964" : 1.0
#                     }
#                 ],
#                 "frozen" : false
#             },
#             "name" : "I feel nauseous.",
#             "weight" : 1.0
#         },
#         {
#             "class" : "State",
#             "distribution" : {
#                 "class" : "Distribution",
#                 "dtype" : "str",
#                 "name" : "DiscreteDistribution",
#                 "parameters" : [
#                     {
#                         "\u092e\u0948\u0902 \u0939\u0930 \u0938\u093e\u0932 \u091c\u093e\u0924\u093e \u0939\u0942\u0901\u0964" : 1.0
#                     }
#                 ],
#                 "frozen" : false
#             },
#             "name" : "I go every year.",
#             "weight" : 1.0
#         },
#         {
#             "class" : "State",
#             "distribution" : {
#                 "class" : "Distribution",
#                 "dtype" : "str",
#                 "name" : "DiscreteDistribution",
#                 "parameters" : [
#                     {
#                         "\u092e\u0948\u0902 \u092e\u0941\u0936\u094d\u0915\u093f\u0932 \u092e\u0947\u0902 \u0939\u0942\u0901\u0964" : 1.0
#                     }
#                 ],
#                 "frozen" : false
#             },
#             "name" : "I have a problem.",
#             "weight" : 1.0
#         },
#         {
#             "class" : "State",
#             "distribution" : {
#                 "class" : "Distribution",
#                 "dtype" : "str",
#                 "name" : "DiscreteDistribution",
#                 "parameters" : [
#                     {
#                         "\u092e\u0941\u091d\u0947 \u0905\u092d\u0940 \u091c\u093e\u0928\u093e \u0939\u0948\u0964" : 1.0
#                     }
#                 ],
#                 "frozen" : false
#             },
#             "name" : "I have to go now.",
#             "weight" : 1.0
#         },
#         {
#             "class" : "State",
#             "distribution" : {
#                 "class" : "Distribution",
#                 "dtype" : "str",
#                 "name" : "DiscreteDistribution",
#                 "parameters" : [
#                     {
#                         "\u092e\u0947\u0930\u0940 \u0909\u0938\u0938\u0947 \u092e\u0941\u0932\u093e\u0915\u093e\u0924 \u0928\u0939\u0940\u0902 \u0939\u0941\u0908 \u0939\u0948\u0964" : 1.0
#                     }
#                 ],
#                 "frozen" : false
#             },
#             "name" : "I haven't met him.",
#             "weight" : 1.0
#         },
#         {
#             "class" : "State",
#             "distribution" : {
#                 "class" : "Distribution",
#                 "dtype" : "str",
#                 "name" : "DiscreteDistribution",
#                 "parameters" : [
#                     {
#                         "\u092e\u0941\u091d\u0947 \u0907\u0924\u093f\u0939\u093e\u0938 \u092a\u0938\u0902\u0926 \u0939\u0948\u0964" : 1.0
#                     }
#                 ],
#                 "frozen" : false
#             },
#             "name" : "I like history.",
#             "weight" : 1.0
#         },
#         {
#             "class" : "State",
#             "distribution" : {
#                 "class" : "Distribution",
#                 "dtype" : "str",
#                 "name" : "DiscreteDistribution",
#                 "parameters" : [
#                     {
#                         "\u092e\u0941\u091d\u0947 \u092f\u0939 \u0915\u0941\u0924\u094d\u0924\u093e \u0905\u091a\u094d\u091b\u093e \u0932\u0917\u0924\u093e \u0939\u0948\u0964" : 1.0
#                     }
#                 ],
#                 "frozen" : false
#             },
#             "name" : "I like the dog.",
#             "weight" : 1.0
#         },
#         {
#             "class" : "State",
#             "distribution" : {
#                 "class" : "Distribution",
#                 "dtype" : "str",
#                 "name" : "DiscreteDistribution",
#                 "parameters" : [
#                     {
#                         "\u092e\u0948\u0902 \u0938\u0902\u0917\u0940\u0924 \u0938\u0941\u0928\u0924\u093e \u0939\u0942\u0901\u0964" : 1.0
#                     }
#                 ],
#                 "frozen" : false
#             },
#             "name" : "I listen to music.",
#             "weight" : 1.0
#         },
#         {
#             "class" : "State",
#             "distribution" : {
#                 "class" : "Distribution",
#                 "dtype" : "str",
#                 "name" : "DiscreteDistribution",
#                 "parameters" : [
#                     {
#                         "\u092e\u0941\u091d\u0947 \u090f\u0915 \u0924\u094b \u0916\u0930\u0940\u0926\u0928\u093e \u0939\u0940 \u0939\u094b\u0917\u093e\u0964" : 1.0
#                     }
#                 ],
#                 "frozen" : false
#             },
#             "name" : "I must buy one.",
#             "weight" : 1.0
#         },
#         {
#             "class" : "State",
#             "distribution" : {
#                 "class" : "Distribution",
#                 "dtype" : "str",
#                 "name" : "DiscreteDistribution",
#                 "parameters" : [
#                     {
#                         "\u092e\u0948\u0902\u0928\u0947 \u0909\u0938\u0947 \u0926\u094c\u0921\u093c\u0924\u0947 \u0939\u0941\u090f \u0926\u0947\u0916\u093e\u0964" : 1.0
#                     }
#                 ],
#                 "frozen" : false
#             },
#             "name" : "I saw him running.",
#             "weight" : 1.0
#         },
#         {
#             "class" : "State",
#             "distribution" : {
#                 "class" : "Distribution",
#                 "dtype" : "str",
#                 "name" : "DiscreteDistribution",
#                 "parameters" : [
#                     {
#                         "\u092e\u0948\u0902 \u0909\u0938\u0938\u0947 \u0938\u091a\u094d\u091a\u093e \u092a\u094d\u092f\u093e\u0930 \u0915\u0930\u0924\u093e \u0925\u093e\u0964" : 1.0
#                     }
#                 ],
#                 "frozen" : false
#             },
#             "name" : "I truly loved her.",
#             "weight" : 1.0
#         },
#         {
#             "class" : "State",
#             "distribution" : {
#                 "class" : "Distribution",
#                 "dtype" : "str",
#                 "name" : "DiscreteDistribution",
#                 "parameters" : [
#                     {
#                         "\u092e\u0941\u091d\u0947 \u0917\u093f\u091f\u093e\u0930 \u091a\u093e\u0939\u093f\u090f\u0964" : 1.0
#                     }
#                 ],
#                 "frozen" : false
#             },
#             "name" : "I want a guitar.",
#             "weight" : 1.0
#         },
#         {
#             "class" : "State",
#             "distribution" : {
#                 "class" : "Distribution",
#                 "dtype" : "str",
#                 "name" : "DiscreteDistribution",
#                 "parameters" : [
#                     {
#                         "\u092e\u0941\u091d\u092a\u0930 \u0939\u092e\u0932\u093e \u0915\u093f\u092f\u093e \u0917\u092f\u093e\u0964" : 1.0
#                     }
#                 ],
#                 "frozen" : false
#             },
#             "name" : "I was assaulted.",
#             "weight" : 1.0
#         },
#         {
#             "class" : "State",
#             "distribution" : {
#                 "class" : "Distribution",
#                 "dtype" : "str",
#                 "name" : "DiscreteDistribution",
#                 "parameters" : [
#                     {
#                         "\u092e\u0948\u0902 \u0920\u0940\u0915 \u0939\u0942\u0901\u0964" : 1.0
#                     }
#                 ],
#                 "frozen" : false
#             },
#             "name" : "I'm OK.",
#             "weight" : 1.0
#         },
#         {
#             "class" : "State",
#             "distribution" : {
#                 "class" : "Distribution",
#                 "dtype" : "str",
#                 "name" : "DiscreteDistribution",
#                 "parameters" : [
#                     {
#                         "\u092e\u0948\u0902 \u0905\u091a\u094d\u091b\u093e \u0930\u0938\u094b\u0907\u092f\u093e \u0939\u0942\u0901\u0964" : 0.5,
#                         "\u092e\u0948\u0902 \u0905\u091a\u094d\u091b\u093e \u092c\u093e\u0935\u0930\u094d\u091a\u0940 \u0939\u0942\u0901\u0964" : 0.5
#                     }
#                 ],
#                 "frozen" : false
#             },
#             "name" : "I'm a good cook.",
#             "weight" : 1.0
#         },
#         {
#             "class" : "State",
#             "distribution" : {
#                 "class" : "Distribution",
#                 "dtype" : "str",
#                 "name" : "DiscreteDistribution",
#                 "parameters" : [
#                     {
#                         "\u0906\u091c \u092e\u0947\u0930\u093e \u0928\u0938\u0940\u092c \u0905\u091a\u094d\u091b\u093e \u0939\u0948\u0964" : 1.0
#                     }
#                 ],
#                 "frozen" : false
#             },
#             "name" : "I'm lucky today.",
#             "weight" : 1.0
#         },
#         {
#             "class" : "State",
#             "distribution" : {
#                 "class" : "Distribution",
#                 "dtype" : "str",
#                 "name" : "DiscreteDistribution",
#                 "parameters" : [
#                     {
#                         "\u0915\u094b\u0908 \u0939\u0948 \u0915\u094d\u092f\u093e?" : 1.0
#                     }
#                 ],
#                 "frozen" : false
#             },
#             "name" : "Is anybody here?",
#             "weight" : 1.0
#         },
#         {
#             "class" : "State",
#             "distribution" : {
#                 "class" : "Distribution",
#                 "dtype" : "str",
#                 "name" : "DiscreteDistribution",
#                 "parameters" : [
#                     {
#                         "\u0909\u091b\u0932\u094b." : 0.1111111111111111,
#                         "\u0915\u0942\u0926\u094b." : 0.2222222222222222,
#                         "\u091b\u0932\u093e\u0902\u0917." : 0.2222222222222222,
#                         "\u0915\u0942\u0926." : 0.1111111111111111,
#                         "\u091c\u092e\u094d\u092a." : 0.1111111111111111,
#                         "\u090f\u0915\u093e\u090f\u0915 \u0926\u093e\u092e \u0915\u0940 \u0935\u0943\u0926\u094d\u0927\u093f." : 0.1111111111111111,
#                         "\u0932\u092a\u0915." : 0.1111111111111111
#                     }
#                 ],
#                 "frozen" : false
#             },
#             "name" : "Jump.",
#             "weight" : 1.0
#         },
#         {
#             "class" : "State",
#             "distribution" : {
#                 "class" : "Distribution",
#                 "dtype" : "str",
#                 "name" : "DiscreteDistribution",
#                 "parameters" : [
#                     {
#                         "\u0906\u092a\u0915\u093e \u0928\u093e\u092e \u0915\u094d\u092f\u093e \u0939\u0948?" : 1.0
#                     }
#                 ],
#                 "frozen" : false
#             },
#             "name" : "What's your name?",
#             "weight" : 1.0
#         },
#         {
#             "class" : "State",
#             "distribution" : {
#                 "class" : "Distribution",
#                 "dtype" : "str",
#                 "name" : "DiscreteDistribution",
#                 "parameters" : [
#                     {
#                         "\u0935\u093e\u0939!" : 0.6666666666666666,
#                         "\u0938\u0928\u0938\u0928\u0940\u0916\u0947\u091c \u0915\u093e\u092e\u092f\u093e\u092c\u0940" : 0.3333333333333333
#                     }
#                 ],
#                 "frozen" : false
#             },
#             "name" : "Wow!",
#             "weight" : 1.0
#         },
#         {
#             "class" : "State",
#             "distribution" : null,
#             "name" : "base-hmm-tagger-start",
#             "weight" : 1.0
#         },
#         {
#             "class" : "State",
#             "distribution" : null,
#             "name" : "base-hmm-tagger-end",
#             "weight" : 1.0
#         }
#     ],
#     "end_index" : 37,
#     "start_index" : 36,
#     "silent_index" : 36,
#     "edges" : [
#         [
#             36,
#             35,
#             0.03389830508474576,
#             1.0,
#             null
#         ],
#         [
#             36,
#             0,
#             0.0,
#             0.0,
#             null
#         ],
#         [
#             36,
#             14,
#             0.03389830508474576,
#             1.0,
#             null
#         ],
#         [
#             36,
#             33,
#             0.03389830508474576,
#             1.0,
#             null
#         ],
#         [
#             36,
#             13,
#             0.03389830508474576,
#             1.0,
#             null
#         ],
#         [
#             36,
#             2,
#             0.03389830508474576,
#             1.0,
#             null
#         ],
#         [
#             36,
#             11,
#             0.03389830508474576,
#             1.0,
#             null
#         ],
#         [
#             36,
#             29,
#             0.03389830508474576,
#             1.0,
#             null
#         ],
#         [
#             36,
#             1,
#             0.03389830508474576,
#             1.0,
#             null
#         ],
#         [
#             36,
#             4,
#             0.03389830508474576,
#             1.0,
#             null
#         ],
#         [
#             36,
#             8,
#             0.03389830508474576,
#             1.0,
#             null
#         ],
#         [
#             36,
#             9,
#             0.03389830508474576,
#             1.0,
#             null
#         ],
#         [
#             36,
#             10,
#             0.03389830508474576,
#             1.0,
#             null
#         ],
#         [
#             36,
#             34,
#             0.03389830508474576,
#             1.0,
#             null
#         ],
#         [
#             36,
#             6,
#             0.03389830508474576,
#             1.0,
#             null
#         ],
#         [
#             36,
#             12,
#             0.03389830508474576,
#             1.0,
#             null
#         ],
#         [
#             36,
#             3,
#             0.03389830508474576,
#             1.0,
#             null
#         ],
#         [
#             36,
#             7,
#             0.0,
#             0.0,
#             null
#         ],
#         [
#             36,
#             21,
#             0.03389830508474576,
#             1.0,
#             null
#         ],
#         [
#             36,
#             22,
#             0.0,
#             0.0,
#             null
#         ],
#         [
#             36,
#             24,
#             0.0,
#             0.0,
#             null
#         ],
#         [
#             36,
#             16,
#             0.03389830508474576,
#             1.0,
#             null
#         ],
#         [
#             36,
#             17,
#             0.0,
#             0.0,
#             null
#         ],
#         [
#             36,
#             5,
#             0.01694915254237288,
#             0.5,
#             null
#         ],
#         [
#             36,
#             27,
#             0.03389830508474576,
#             1.0,
#             null
#         ],
#         [
#             36,
#             28,
#             0.0,
#             0.0,
#             null
#         ],
#         [
#             36,
#             30,
#             0.03389830508474576,
#             1.0,
#             null
#         ],
#         [
#             36,
#             31,
#             0.03389830508474576,
#             1.0,
#             null
#         ],
#         [
#             36,
#             32,
#             0.03389830508474576,
#             1.0,
#             null
#         ],
#         [
#             36,
#             15,
#             0.03389830508474576,
#             1.0,
#             null
#         ],
#         [
#             36,
#             18,
#             0.03389830508474576,
#             1.0,
#             null
#         ],
#         [
#             36,
#             19,
#             0.03389830508474576,
#             1.0,
#             null
#         ],
#         [
#             36,
#             25,
#             0.03389830508474576,
#             1.0,
#             null
#         ],
#         [
#             36,
#             26,
#             0.03389830508474576,
#             1.0,
#             null
#         ],
#         [
#             36,
#             23,
#             0.03389830508474576,
#             1.0,
#             null
#         ],
#         [
#             36,
#             20,
#             0.03389830508474576,
#             1.0,
#             null
#         ],
#         [
#             35,
#             37,
#             1.0,
#             1.0,
#             null
#         ],
#         [
#             0,
#             37,
#             NaN,
#             0.0,
#             null
#         ],
#         [
#             14,
#             37,
#             1.0,
#             1.0,
#             null
#         ],
#         [
#             33,
#             37,
#             1.0,
#             1.0,
#             null
#         ],
#         [
#             13,
#             37,
#             1.0,
#             1.0,
#             null
#         ],
#         [
#             2,
#             37,
#             1.0,
#             1.0,
#             null
#         ],
#         [
#             11,
#             37,
#             1.0,
#             1.0,
#             null
#         ],
#         [
#             29,
#             37,
#             1.0,
#             1.0,
#             null
#         ],
#         [
#             1,
#             37,
#             1.0,
#             1.0,
#             null
#         ],
#         [
#             4,
#             37,
#             1.0,
#             1.0,
#             null
#         ],
#         [
#             8,
#             37,
#             1.0,
#             1.0,
#             null
#         ],
#         [
#             9,
#             37,
#             1.0,
#             1.0,
#             null
#         ],
#         [
#             10,
#             37,
#             1.0,
#             1.0,
#             null
#         ],
#         [
#             34,
#             37,
#             1.0,
#             1.0,
#             null
#         ],
#         [
#             6,
#             37,
#             1.0,
#             0.5,
#             null
#         ],
#         [
#             12,
#             37,
#             1.0,
#             1.0,
#             null
#         ],
#         [
#             3,
#             37,
#             1.0,
#             1.0,
#             null
#         ],
#         [
#             7,
#             37,
#             1.0,
#             1.0,
#             null
#         ],
#         [
#             21,
#             37,
#             NaN,
#             0.0,
#             null
#         ],
#         [
#             22,
#             37,
#             NaN,
#             0.0,
#             null
#         ],
#         [
#             24,
#             37,
#             1.0,
#             1.0,
#             null
#         ],
#         [
#             16,
#             37,
#             NaN,
#             0.0,
#             null
#         ],
#         [
#             17,
#             37,
#             1.0,
#             1.0,
#             null
#         ],
#         [
#             5,
#             37,
#             1.0,
#             0.5,
#             null
#         ],
#         [
#             27,
#             37,
#             NaN,
#             0.0,
#             null
#         ],
#         [
#             28,
#             37,
#             1.0,
#             1.0,
#             null
#         ],
#         [
#             30,
#             37,
#             1.0,
#             1.0,
#             null
#         ],
#         [
#             31,
#             37,
#             1.0,
#             1.0,
#             null
#         ],
#         [
#             32,
#             37,
#             1.0,
#             1.0,
#             null
#         ],
#         [
#             15,
#             37,
#             1.0,
#             1.0,
#             null
#         ],
#         [
#             18,
#             37,
#             1.0,
#             1.0,
#             null
#         ],
#         [
#             19,
#             37,
#             1.0,
#             1.0,
#             null
#         ],
#         [
#             25,
#             37,
#             1.0,
#             1.0,
#             null
#         ],
#         [
#             26,
#             37,
#             1.0,
#             1.0,
#             null
#         ],
#         [
#             23,
#             37,
#             1.0,
#             1.0,
#             null
#         ],
#         [
#             20,
#             37,
#             1.0,
#             1.0,
#             null
#         ]
#     ],
#     "distribution ties" : []
# }

# %%
hmm_training_acc = accuracy(data.training_set.X, data.training_set.Y, hmm_model)
print("training accuracy basic hmm model: {:.2f}%".format(100 * hmm_training_acc))

hmm_testing_acc = accuracy(data.testing_set.X, data.testing_set.Y, hmm_model)
print("testing accuracy basic hmm model: {:.2f}%".format(100 * hmm_testing_acc))
