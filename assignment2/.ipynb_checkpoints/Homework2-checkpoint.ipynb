# %%
# !pwd
# Out:
# /Users/aelinadas/Anaconda-Data Science-Jupyter/Jupyter Notebook/02_001050895_AelinaDas

# %%
# Better do this in an anaconda terminal on windows or bash shell on mac
# !pip install pandas_datareader
# Out:
# Requirement already satisfied: pandas_datareader in /Users/aelinadas/opt/anaconda3/lib/python3.7/site-packages (0.8.1)
# Requirement already satisfied: pandas>=0.21 in /Users/aelinadas/opt/anaconda3/lib/python3.7/site-packages (from pandas_datareader) (0.25.1)
# Requirement already satisfied: lxml in /Users/aelinadas/opt/anaconda3/lib/python3.7/site-packages (from pandas_datareader) (4.4.1)
# Requirement already satisfied: requests>=2.3.0 in /Users/aelinadas/opt/anaconda3/lib/python3.7/site-packages (from pandas_datareader) (2.22.0)
# Requirement already satisfied: numpy>=1.13.3 in /Users/aelinadas/opt/anaconda3/lib/python3.7/site-packages (from pandas>=0.21->pandas_datareader) (1.17.2)
# Requirement already satisfied: python-dateutil>=2.6.1 in /Users/aelinadas/opt/anaconda3/lib/python3.7/site-packages (from pandas>=0.21->pandas_datareader) (2.8.0)
# Requirement already satisfied: pytz>=2017.2 in /Users/aelinadas/opt/anaconda3/lib/python3.7/site-packages (from pandas>=0.21->pandas_datareader) (2019.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/aelinadas/opt/anaconda3/lib/python3.7/site-packages (from requests>=2.3.0->pandas_datareader) (2019.9.11)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Users/aelinadas/opt/anaconda3/lib/python3.7/site-packages (from requests>=2.3.0->pandas_datareader) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /Users/aelinadas/opt/anaconda3/lib/python3.7/site-packages (from requests>=2.3.0->pandas_datareader) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/aelinadas/opt/anaconda3/lib/python3.7/site-packages (from requests>=2.3.0->pandas_datareader) (1.24.2)
# Requirement already satisfied: six>=1.5 in /Users/aelinadas/opt/anaconda3/lib/python3.7/site-packages (from python-dateutil>=2.6.1->pandas>=0.21->pandas_datareader) (1.12.0)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
vol = bac['High']
vol.plot()

# %%
close = bac['Close']
close.plot()

# %%
# From pandas_datareader import data, wb
import pandas as pd
# the line below is the fix for is_list_like lub
pd.core.common.is_list_like = pd.api.types.is_list_like

import pandas_datareader as web
import datetime
start = datetime.datetime(2016, 1, 1)
end = datetime.datetime(2020, 1, 30)
bac = web.DataReader('NFLX', 'yahoo', start, end)
bac.head(10)
# Out:
#                   High         Low        Open       Close    Volume  \
# Date
# 2016-01-04  110.000000  105.209999  109.000000  109.959999  20794800
# 2016-01-05  110.580002  105.849998  110.449997  107.660004  17664600
# 2016-01-06  117.910004  104.959999  105.290001  117.680000  33045700
# 2016-01-07  122.180000  112.290001  116.360001  114.559998  33636700
# 2016-01-08  117.720001  111.099998  116.330002  111.389999  18067100
# 2016-01-11  116.790001  111.199997  112.129997  114.970001  21920400
# 2016-01-12  117.779999  115.080002  116.110001  116.580002  15133500
# 2016-01-13  114.480003  104.529999  114.430000  106.559998  24921600
# 2016-01-14  109.250000  101.209999  105.650002  107.059998  23664800
# 2016-01-15  105.500000  101.720001  102.430000  104.040001  19775100
#
#              Adj Close
# Date
# 2016-01-04  109.959999
# 2016-01-05  107.660004
# 2016-01-06  117.680000
# 2016-01-07  114.559998
# 2016-01-08  111.389999
# 2016-01-11  114.970001
# 2016-01-12  116.580002
# 2016-01-13  106.559998
# 2016-01-14  107.059998
# 2016-01-15  104.040001

# %%
import numpy as np
returns = np.diff(close)
plt.plot(returns)

# %%
import numpy as np
returns = np.diff(np.log(close))
plt.plot(returns)

# %%
vol.corr(close)
# Out:
# 0.9994360379697459

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
nflx = pd.read_csv('data/NFLX.csv',index_col=['Date'], parse_dates=['Date'])
nflx.head(10)
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2002-05-23  1.156429  1.242857  1.145714  1.196429   1.196429  104790000
# 2002-05-24  1.214286  1.225000  1.197143  1.210000   1.210000   11104800
# 2002-05-28  1.213571  1.232143  1.157143  1.157143   1.157143    6609400
# 2002-05-29  1.164286  1.164286  1.085714  1.103571   1.103571    6757800
# 2002-05-30  1.107857  1.107857  1.071429  1.071429   1.071429   10154200
# 2002-05-31  1.078571  1.078571  1.071429  1.076429   1.076429    8464400
# 2002-06-03  1.080000  1.149286  1.076429  1.128571   1.128571    3151400
# 2002-06-04  1.135714  1.140000  1.110714  1.117857   1.117857    3105200
# 2002-06-05  1.110714  1.159286  1.107143  1.147143   1.147143    1531600
# 2002-06-06  1.150000  1.232143  1.148571  1.182143   1.182143    2305800

# %%
drop_cols = ['Adj Close','Volume']
nflx.drop(drop_cols, axis=1, inplace=True)

# %%
nflx.head()
# Out:
#                 Open      High       Low     Close
# Date
# 2002-05-23  1.156429  1.242857  1.145714  1.196429
# 2002-05-24  1.214286  1.225000  1.197143  1.210000
# 2002-05-28  1.213571  1.232143  1.157143  1.157143
# 2002-05-29  1.164286  1.164286  1.085714  1.103571
# 2002-05-30  1.107857  1.107857  1.071429  1.071429

# %%
# Plot closing price

plt.figure(figsize=(12, 4))
plt.plot(nflx.Close)
plt.title('Closing price of Netflix')
plt.ylabel('Closing price in($)')
plt.xlabel('Trading day')
plt.grid(False)
plt.show()

# %%
def plot_moving_average(series, window, plot_intervals=False, scale=1.96):
    rolling_mean = series.rolling(window=window).mean()
 
    plt.figure(figsize=(17,8))
    plt.title('Moving average\n window size = {}'.format(window))
    plt.plot(rolling_mean, 'g', label='Rolling mean trend')

    #Plot confidence intervals for smoothed values
    if plot_intervals:
        mae = mean_absolute_error(series[window:], rolling_mean[window:])
        deviation = np.std(series[window:] - rolling_mean[window:])
        lower_bound = rolling_mean - (mae + scale * deviation)
        upper_bound = rolling_mean + (mae + scale * deviation)
        plt.plot(upper_bound, 'r--', label='Upper bound / Lower bound')
        plt.plot(lower_bound, 'r--')

    plt.plot(series[window:], label='Actual values')
    plt.legend(loc='best')
    plt.grid(True)

#Smooth by the previous 5 days (by week)
plot_moving_average(nflx.Close, 5)

# %%
#Smooth by previous quarter (90 days)
plot_moving_average(nflx.Close, 90)

# %%
def exponential_smoothing(series, alpha):
    result = [series[0]] # first value is same as series
    for n in range(1, len(series)):
        result.append(alpha * series[n] + (1 - alpha) * result[n-1])
    return result

def plot_exponential_smoothing(series, alphas):
    plt.figure(figsize=(17, 8))
    for alpha in alphas:
        plt.plot(exponential_smoothing(series, alpha), label="Alpha {}".format(alpha))
    plt.plot(series.values, "c", label = "Actual")
    plt.legend(loc="best")
    plt.axis('tight')
    plt.title("Exponential Smoothing")
    plt.grid(True);
        
plot_exponential_smoothing(nflx.Close, [0.1, 0.3])

# %%
def double_exponential_smoothing(series, alpha, beta):
    result = [series[0]]
    
    for n in range(1, len(series)+1):
        if n == 1:
            level, trend = series[0], series[1] - series[0]
        if n >= len(series): # forecasting
            value = result[-1]
        else:
            value = series[n]
        
        last_level, level = level, alpha * value + (1 - alpha) * (level + trend)
        trend = beta * (level - last_level) + (1 - beta) * trend
        result.append(level + trend)
    return result

def plot_double_exponential_smoothing(series, alphas, betas):
    plt.figure(figsize=(17, 8))
    for alpha in alphas:
        for beta in betas:
            plt.plot(double_exponential_smoothing(series, alpha, beta), label="Alpha {}, beta {}".format(alpha, beta))
    plt.plot(series.values, label = "Actual")
    plt.legend(loc="best")
    plt.axis('tight')
    plt.title("Double Exponential Smoothing")
    plt.grid(True)

plot_double_exponential_smoothing(nflx.Close, alphas=[0.9, 0.02], betas=[0.9, 0.02])

# %%
import statsmodels.api as sm
import statsmodels as smt
def tsplot(y, lags=None, figsize=(12, 7), syle='bmh'):
    
    if not isinstance(y, pd.Series):
        y = pd.Series(y)
        
    with plt.style.context(style='bmh'):
        fig = plt.figure(figsize=figsize)
        layout = (2,2)
        ts_ax = plt.subplot2grid(layout, (0,0), colspan=2)
        acf_ax = plt.subplot2grid(layout, (1,0))
        pacf_ax = plt.subplot2grid(layout, (1,1))
        
        y.plot(ax=ts_ax)
        p_value = sm.tsa.stattools.adfuller(y)[1]
        ts_ax.set_title('Time Series Analysis Plots\n Dickey-Fuller: p={0:.5f}'.format(p_value))
        smt.graphics.tsaplots.plot_acf(y, lags=lags, ax=acf_ax)
        smt.graphics.tsaplots.plot_pacf(y, lags=lags, ax=pacf_ax)
        plt.tight_layout()
        
tsplot(nflx.Close, lags=30)

# %%
# Take the first difference to remove to make the process stationary
nflx_diff = nflx.Close - nflx.Close.shift(1)

tsplot(nflx_diff[1:], lags=30)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics
from sklearn.model_selection import train_test_split

# %%
pd.concat([nflx.Close, nflx.Close.shift(-1)], axis=1)
# Out:
#                  Close       Close
# Date
# 2002-05-23    1.196429    1.210000
# 2002-05-24    1.210000    1.157143
# 2002-05-28    1.157143    1.103571
# 2002-05-29    1.103571    1.071429
# 2002-05-30    1.071429    1.076429
# ...                ...         ...
# 2020-01-13  338.920013  338.690002
# 2020-01-14  338.690002  339.070007
# 2020-01-15  339.070007  338.619995
# 2020-01-16  338.619995  339.670013
# 2020-01-17  339.670013         NaN
#
# [4445 rows x 2 columns]

# %%
nflx.head()
# Out:
#                 Open      High       Low     Close
# Date
# 2002-05-23  1.156429  1.242857  1.145714  1.196429
# 2002-05-24  1.214286  1.225000  1.197143  1.210000
# 2002-05-28  1.213571  1.232143  1.157143  1.157143
# 2002-05-29  1.164286  1.164286  1.085714  1.103571
# 2002-05-30  1.107857  1.107857  1.071429  1.071429

# %%
nflx.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close'], dtype='object')

# %%
# Need to remove NA
nflx = nflx.dropna()
# Regression - Try to predict closing value of stocks (y) from remaining columns (X)
X = nflx[[x for x in nflx.columns]].iloc[:-1]
# Get training set (X_train)
y = nflx.Close.shift(-1).dropna()

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Create a model 
rf_model = RandomForestRegressor()

# Train the model
rf_model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False)

# %%
# Get R2 measure (indicator of accuracy 1 is perfect 0 is horrible)
rf_model.score(X_test, y_test)
# Out:
# 0.9988373400389129

# %%
y_pred = rf_model.predict(X_test)

# %%
type(y_pred)
# Out:
# numpy.ndarray

# %%
y_pred[0:10]
# Out:
# array([ 17.9829996, 261.4550018, 108.6560004, 199.3859987,   0.7692143,
#         93.3978561,   9.3844284,  36.6927142,   4.1592142,  19.8547143])

# %%
import matplotlib.pyplot as plt
plt.plot(y_pred)

# %%
type(y_test)
# Out:
# pandas.core.series.Series

# %%
y_test2 = y_test.as_matrix()
type(y_test2)
# Out:
# numpy.ndarray

# %%
y_test2[0:10]
# Out:
# array([ 17.325714, 265.720001, 107.660004, 198.369995,   0.71    ,
#         94.742859,   9.435715,  37.67857 ,   4.138571,  17.957144])

# %%
import matplotlib.pyplot as plt
plt.plot(y_test2)

# %%
import matplotlib.pyplot as plt
plt.plot(y_pred)
plt.plot(y_test2)

# %%
import matplotlib.pyplot as plt
plt.plot(y_test2)
plt.plot(y_pred)

# %%
pd.concat([pd.Series(rf_model.predict(X_test)), y_test.reset_index(
drop=True)], axis=1)
# Out:
#                0       Close
# 0      17.983000   17.325714
# 1     261.455002  265.720001
# 2     108.656000  107.660004
# 3     199.385999  198.369995
# 4       0.769214    0.710000
# ...          ...         ...
# 1106   17.059143   16.977142
# 1107   15.357143   15.925714
# 1108   61.799286   60.349998
# 1109   25.548429   24.248571
# 1110    0.637071    0.685714
#
# [1111 rows x 2 columns]

# %%
sorted(zip(X.columns, rf_model.feature_importances_),
        key=lambda x: x[1], reverse=True)
# Out:
# [('High', 0.45710747262303164),
#  ('Close', 0.27992536437827675),
#  ('Low', 0.2607027577196067),
#  ('Open', 0.0022644052790848643)]
